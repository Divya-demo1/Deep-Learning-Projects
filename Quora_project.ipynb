# %% [markdown]
# <a href="https://colab.research.google.com/github/Divya-demo1/Deep-Learning-Projects/blob/master/Quora_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
tf.test.gpu_device_name()
import os
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %% [markdown]
# **Loading file from dropbox**

# %%
# !wget https://www.dropbox.com/sh/kpf9z73woodfssv/AAAw1_JIzpuVvwteJCma0xMla?dl=0
# Out:
# --2020-02-06 22:55:00--  https://www.dropbox.com/sh/kpf9z73woodfssv/AAAw1_JIzpuVvwteJCma0xMla?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.9.1, 2620:100:601b:1::a27d:801
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.9.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /sh/raw/kpf9z73woodfssv/AAAw1_JIzpuVvwteJCma0xMla [following]
# --2020-02-06 22:55:00--  https://www.dropbox.com/sh/raw/kpf9z73woodfssv/AAAw1_JIzpuVvwteJCma0xMla
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uce2b6abbbe64ac9f77f4160d64d.dl.dropboxusercontent.com/zip_download_get/AVDRF7Z9zoEOpkUYVCVcLoSpZI4ielprOvDnjWmaQIrteuSdWWQfehy3uLvO7tIo11G_ww1VJpQroUHP_x9eZeCrvTYoQXst_wQEkU_9KeNpIQ [following]
# --2020-02-06 22:55:00--  https://uce2b6abbbe64ac9f77f4160d64d.dl.dropboxusercontent.com/zip_download_get/AVDRF7Z9zoEOpkUYVCVcLoSpZI4ielprOvDnjWmaQIrteuSdWWQfehy3uLvO7tIo11G_ww1VJpQroUHP_x9eZeCrvTYoQXst_wQEkU_9KeNpIQ
# Resolving uce2b6abbbe64ac9f77f4160d64d.dl.dropboxusercontent.com (uce2b6abbbe64ac9f77f4160d64d.dl.dropboxusercontent.com)... 162.125.9.6, 2620:100:601f:6::a27d:906
# Connecting to uce2b6abbbe64ac9f77f4160d64d.dl.dropboxusercontent.com (uce2b6abbbe64ac9f77f4160d64d.dl.dropboxusercontent.com)|162.125.9.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 124206982 (118M) [application/zip]
# Saving to: ‘AAAw1_JIzpuVvwteJCma0xMla?dl=0’
#
# AAAw1_JIzpuVvwteJCm 100%[===================>] 118.45M  50.5MB/s    in 2.3s
#
# 2020-02-06 22:55:03 (50.5 MB/s) - ‘AAAw1_JIzpuVvwteJCma0xMla?dl=0’ saved [124206982/124206982]

# %%
# !unzip AAAw1_JIzpuVvwteJCma0xMla?dl=0
# Out:
# Archive:  AAAw1_JIzpuVvwteJCma0xMla?dl=0
# warning:  stripped absolute path spec from /
# mapname:  conversion of  failed
#  extracting: train.csv
#
# 1 archive had fatal errors.

# %%
os.listdir()
# Out:
# ['.config', 'AAAw1_JIzpuVvwteJCma0xMla?dl=0', 'train.csv', 'sample_data']

# %%
import sklearn.datasets as skds
from pathlib import Path
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from nltk import word_tokenize
from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence
from keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding
from keras.models import Model
from keras.layers.normalization import BatchNormalization
# Out:
# Using TensorFlow backend.

# %%
quora = pd.read_csv('train.csv',encoding = 'ISO-8859-1')

# %%
quora.head()

# %%
quora.shape
# Out:
# (1306122, 3)

# %%
quora.drop(['qid'],inplace=True,axis=1)

# %%
quora.head()
# Out:
#                                        question_text  target
# 0  How did Quebec nationalists see their province...       0
# 1  Do you have an adopted dog, how would you enco...       0
# 2  Why does velocity affect time? Does velocity a...       0
# 3  How did Otto von Guericke used the Magdeburg h...       0
# 4  Can I convert montra helicon D to a mountain b...       0

# %%
quora_train,quora_test=train_test_split(quora,test_size=0.2,random_state=2)

# %%
x_train=quora_train['question_text']
y_train=quora_train['target']
x_test=quora_test['question_text']
y_test=quora_test['target']

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
sent_lens=[]
for sent in quora_train['question_text']:
    sent_lens.append(len(word_tokenize(sent)))

# %%
max(sent_lens)
# Out:
# 412

# %%
max_quant_len=np.quantile(sent_lens,0.95)

# %%
max_quant_len=int(max_quant_len)
max_quant_len
# Out:
# 30

# %%
max_len =max_quant_len
tok = Tokenizer(char_level=False,split=' ')
tok.fit_on_texts(x_train)
sequences_train = tok.texts_to_sequences(x_train)

# %%
sequences_train
# Out:
# [[2, 3, 1, 34, 79, 5, 3375, 4, 1702, 5916, 44, 242],
#  [9, 11, 14, 91, 1, 2532, 5, 1602, 3144],
#  [16,
#   3,
#   18,
#   1239,
#   549,
#   11352,
#   10,
#   697,
#   111,
#   1165,
#   114,
#   135,
#   21,
#   413,
#   66,
#   136,
#   18,
#   296],
#  [9, 26, 1772, 377, 28, 296, 59, 4, 103],
#  [9, 72, 31, 8, 311, 13, 261, 412],
#  [2, 3, 6000, 79, 5, 2288, 484, 2797, 411, 13, 17644, 59, 3736, 44, 611, 1886],
#  [9, 3, 3708, 11121, 4083],
#  [2, 48, 1, 634, 67, 7, 7187, 3746, 2089, 32, 122, 5375],
#  [3, 17, 109, 13, 75, 21, 87981, 73, 845, 5, 24, 4, 845, 1115],
#  [2, 3, 1, 34, 1332, 247, 5298],
#  [40, 3, 1, 3586, 7, 87982],
#  [16, 3, 2813, 3109, 9878, 6, 1517, 1039, 2, 510, 26, 17, 1137],
#  [16, 126, 2786, 207, 100, 57, 44, 1, 70, 7, 155, 2398],
#  [2,
#   31,
#   75,
#   11,
#   32,
#   154,
#   22,
#   77,
#   4715,
#   78,
#   19,
#   1,
#   98,
#   46,
#   1700,
#   10,
#   4588,
#   13,
#   114,
#   6926,
#   87,
#   10,
#   1315,
#   66,
#   55,
#   128,
#   264,
#   43,
#   111,
#   45,
#   1,
#   128,
#   64,
#   45,
#   1,
#   859],
#  [12, 39, 50, 243, 1818, 3187, 7, 1, 87983, 10695, 100, 1, 5299, 6, 5941],
#  [2,
#   49,
#   16973,
#   87984,
#   41904,
#   579,
#   6043,
#   6,
#   1,
#   18351,
#   1039,
#   2,
#   2437,
#   170,
#   5,
#   568,
#   61,
#   10,
#   21,
#   1405],
#  [6, 3718, 1763, 157, 2161, 1067, 3, 252, 95, 484, 239, 23, 9, 15, 8, 174, 17],
#  [3, 39, 50, 7933, 1056, 3307, 2154, 6, 57, 6, 369, 6516],
#  [40, 3, 197, 11122, 9266],
#  [2, 12, 38, 53, 7437, 13, 10806],
#  [2, 11, 14, 67, 45, 1, 2240, 221],
#  [3, 39, 50, 102, 3510, 1491, 29, 3376],
#  [2, 12, 38, 7, 12246, 87985, 293, 1002],
#  [16,
#   248,
#   18,
#   560,
#   461,
#   19,
#   17,
#   1542,
#   46697,
#   18,
#   2221,
#   36,
#   118,
#   2291,
#   619,
#   2683,
#   14596,
#   23,
#   112,
#   52,
#   68,
#   431,
#   16,
#   206,
#   154,
#   33,
#   17],
#  [16, 26, 27184, 85, 14818, 5, 1236, 1, 94],
#  [2, 986, 18004, 64420, 5, 93, 29, 2880],
#  [11, 14, 67, 29, 148, 180, 31, 546, 1415, 44, 768, 56, 70],
#  [24, 14, 89, 1147, 19, 56, 53, 851, 5106, 40, 49, 28, 742, 207, 203],
#  [16,
#   3,
#   1,
#   283,
#   3562,
#   655,
#   1790,
#   36,
#   4,
#   839,
#   32,
#   17,
#   3,
#   8181,
#   43,
#   118,
#   29,
#   2039,
#   64,
#   99,
#   36,
#   566,
#   1,
#   283,
#   3562,
#   3,
#   105,
#   65,
#   729,
#   22,
#   3096,
#   71,
#   1,
#   16035,
#   655],
#  [15, 8, 33, 669, 853, 6, 12247, 163, 867, 1188, 21, 21283, 337],
#  [6, 2, 224, 12, 14, 83, 5769, 19, 14, 12, 43, 1970, 7],
#  [2, 35, 188, 20, 4, 192, 263, 5718, 1, 758, 399, 23, 4, 200, 263],
#  [8, 24, 4, 214, 64421, 64422, 830, 10, 8, 120, 5, 63, 4, 108, 78, 7, 17, 9],
#  [9, 306, 15, 41905, 1714, 239, 980, 102, 71, 1557, 25993],
#  [2, 12, 1, 217, 6097, 6, 1, 3609, 256],
#  [2, 3, 1, 7888, 19, 3699, 8923, 58, 1992, 1048, 6, 1090, 13051],
#  [2, 3, 1, 190, 7, 1, 773, 7, 7934, 10, 87986],
#  [15, 8, 804, 18, 305, 21, 916, 18760],
#  [9, 15, 8, 1363, 18, 742, 7, 83, 4, 7281, 9195, 10, 503, 3383, 35609],
#  [9, 574, 12, 35610, 6436, 13, 452, 1160],
#  [26, 173, 86, 18761, 1032, 6, 2694],
#  [41906, 3, 102, 18352, 4267, 1735, 22, 21880, 28433],
#  [15, 4, 1060, 103, 135, 1798, 5, 513, 901],
#  [2,
#   11,
#   14,
#   11,
#   32,
#   4,
#   7582,
#   7,
#   1,
#   141,
#   944,
#   1529,
#   3164,
#   45,
#   73,
#   3491,
#   8,
#   80,
#   43,
#   4,
#   2201,
#   7,
#   17,
#   44,
#   66,
#   64,
#   8,
#   101,
#   81,
#   9,
#   5,
#   7074,
#   226,
#   112,
#   5,
#   174],
#  [16,
#   11,
#   38,
#   37,
#   76,
#   2346,
#   36,
#   1,
#   34,
#   2475,
#   13,
#   55,
#   2294,
#   131,
#   414,
#   15,
#   156,
#   1,
#   141,
#   45,
#   7583,
#   248,
#   19,
#   115,
#   2346,
#   3,
#   96,
#   4,
#   225,
#   7,
#   486,
#   604,
#   71,
#   4,
#   7075,
#   1590],
#  [2, 3, 29, 635, 7, 87987, 116, 9556],
#  [9,
#   133,
#   4,
#   98,
#   179,
#   20,
#   77,
#   121,
#   428,
#   938,
#   13,
#   3050,
#   59,
#   374,
#   103,
#   7,
#   177,
#   3050],
#  [2, 3, 1, 1025, 7, 5244, 1916, 13, 29, 1468, 180],
#  [41,
#   17,
#   25,
#   458,
#   5,
#   371,
#   65,
#   71,
#   2211,
#   6,
#   28,
#   680,
#   1107,
#   6,
#   370,
#   5,
#   187,
#   988,
#   920,
#   6,
#   193,
#   42,
#   521],
#  [3, 57, 1684, 6, 1, 178, 2117, 7, 745],
#  [16, 12, 165, 52, 1971, 21, 19190, 103, 135, 124],
#  [9,
#   11,
#   8,
#   226,
#   13,
#   1207,
#   20,
#   18,
#   500,
#   3,
#   1851,
#   3285,
#   5,
#   54,
#   77,
#   248,
#   613,
#   42,
#   17,
#   22,
#   297,
#   17,
#   20,
#   344,
#   77,
#   5824,
#   1,
#   1738,
#   64,
#   77,
#   1745,
#   1007,
#   77,
#   26,
#   9,
#   15,
#   8,
#   226],
#  [35,
#   14,
#   604,
#   688,
#   6,
#   16036,
#   16037,
#   29,
#   267,
#   1299,
#   1813,
#   3084,
#   1421,
#   22,
#   314,
#   30,
#   41,
#   1714,
#   102,
#   136,
#   70],
#  [16, 3, 17, 52, 288, 13, 545, 5, 2339, 19, 55, 1318, 7, 64423],
#  [8,
#   80,
#   1,
#   1119,
#   1121,
#   7,
#   41907,
#   274,
#   10,
#   36,
#   652,
#   6301,
#   8,
#   231,
#   175,
#   4,
#   742,
#   7,
#   18,
#   1932,
#   1121,
#   177,
#   646,
#   8,
#   2299,
#   82,
#   751,
#   6189,
#   237,
#   70,
#   16,
#   3,
#   62,
#   10,
#   9,
#   15,
#   8,
#   174,
#   17],
#  [2,
#   16,
#   11,
#   87988,
#   275,
#   19,
#   66,
#   722,
#   731,
#   25,
#   3795,
#   158,
#   46,
#   12,
#   28434,
#   10,
#   55,
#   10591,
#   15,
#   43,
#   1056,
#   1148,
#   722,
#   12,
#   1809,
#   3795,
#   24,
#   1042,
#   17,
#   28435],
#  [2, 12, 1174, 7114, 64424, 293, 1002, 36, 29, 1357],
#  [2, 3, 76, 7, 1466, 259],
#  [2, 12, 1, 736, 7, 29, 202, 1746, 84, 6, 2524],
#  [3,
#   17,
#   441,
#   5,
#   15269,
#   10,
#   76,
#   18353,
#   2626,
#   59,
#   237,
#   2715,
#   22,
#   31,
#   14,
#   1525,
#   29,
#   1534,
#   96,
#   42,
#   21,
#   10052],
#  [15,
#   1,
#   22544,
#   182,
#   3135,
#   1365,
#   13,
#   8230,
#   76,
#   10,
#   242,
#   2373,
#   59,
#   1,
#   441,
#   613,
#   15,
#   46,
#   129,
#   76,
#   394,
#   1365,
#   59,
#   3173],
#  [2, 3, 1, 60, 3145, 2202, 46, 935, 14, 6, 134, 10, 16],
#  [3, 22545, 879, 1243, 71, 8031, 2955],
#  [2, 12, 38, 728, 14, 35, 156, 105, 5, 4, 7637, 110, 681],
#  [2, 41, 14, 11, 32, 14, 12, 43, 667, 21, 4, 110, 19, 14, 319, 4, 742, 110],
#  [1, 4943, 7, 1377, 10, 209, 3, 22546, 22, 64425],
#  [8, 1941, 18, 27185, 9, 15, 8, 1921, 21, 87],
#  [12, 39, 50, 1987, 69, 5694, 12577, 10, 997, 3076],
#  [16, 3, 4655, 102, 5, 76, 71, 5265, 1063, 105, 1040],
#  [11, 14, 120, 4, 1435, 5, 562, 2233, 152],
#  [16, 3, 201, 1, 3065, 137, 6, 1, 94],
#  [409,
#   23,
#   1847,
#   53553,
#   845,
#   2,
#   12,
#   1,
#   923,
#   19,
#   97,
#   63,
#   170,
#   501,
#   64426,
#   87989,
#   268],
#  [2,
#   392,
#   11,
#   8,
#   120,
#   6,
#   9879,
#   6,
#   370,
#   5,
#   2122,
#   4,
#   3924,
#   19,
#   49,
#   43,
#   4329,
#   247,
#   18,
#   190],
#  [31, 8, 111, 11, 2, 118, 53, 44, 146, 566, 118, 5607, 45, 194, 538],
#  [3, 17, 109, 5, 156, 87990, 6, 135, 53554],
#  [2, 3, 4, 22547, 79, 5, 2836, 18, 435],
#  [26, 165, 42, 124, 21, 15049, 22, 43],
#  [2, 3, 1, 34, 184, 5, 86, 13, 7321],
#  [2,
#   12,
#   1,
#   34,
#   7485,
#   5,
#   1595,
#   6,
#   1,
#   3301,
#   600,
#   10,
#   2,
#   282,
#   7,
#   1595,
#   12,
#   1,
#   1655,
#   5,
#   2710,
#   6,
#   290,
#   1135,
#   21,
#   527,
#   45,
#   1,
#   28,
#   476,
#   1412,
#   6,
#   1595,
#   6,
#   290,
#   4260],
#  [2, 15, 14, 226, 54, 45, 3302, 87991],
#  [16, 11, 28, 1567, 14819, 149, 1436],
#  [9, 887, 31, 56, 162, 2376, 1292, 3007, 6, 57, 5, 33, 53, 9339],
#  [30,
#   1678,
#   3,
#   34,
#   13,
#   1916,
#   460,
#   3754,
#   3165,
#   10,
#   1286,
#   430,
#   73,
#   71,
#   2438,
#   157,
#   158,
#   17,
#   248,
#   84,
#   21,
#   894],
#  [16, 11, 37, 6, 57, 7935, 639, 50, 446, 526, 1820, 788, 5678, 5, 55, 1675],
#  [9,
#   207,
#   4300,
#   37,
#   15,
#   756,
#   6,
#   1074,
#   244,
#   33343,
#   198,
#   131,
#   810,
#   10,
#   1304,
#   1141,
#   37,
#   24,
#   8182,
#   2888,
#   32,
#   46,
#   466,
#   6,
#   198],
#  [2, 12, 1, 955, 224, 5, 150, 414],
#  [9, 11, 6437, 873, 1330, 271, 1, 94],
#  [16, 11, 2515, 85, 5, 1685, 634, 5300, 7, 169, 870, 266],
#  [3,
#   173,
#   797,
#   4410,
#   6,
#   2527,
#   4103,
#   1283,
#   6927,
#   62,
#   103,
#   48,
#   2527,
#   4494,
#   50,
#   2157,
#   3457,
#   10,
#   87992,
#   2339,
#   411,
#   13,
#   17],
#  [2, 3, 1, 1679, 10, 34, 79, 5, 3104, 4, 1863],
#  [11, 14, 748, 307, 4, 955, 74, 16, 22, 16, 43],
#  [73, 71, 87993, 2, 12, 73, 145, 19, 38343, 28436, 2665, 26],
#  [16, 3, 1, 1168, 7, 521, 6574, 23, 183, 350, 2511],
#  [3,
#   39,
#   4,
#   2265,
#   5589,
#   61,
#   14,
#   33,
#   1409,
#   44,
#   194,
#   2711,
#   1016,
#   382,
#   1013,
#   4,
#   710,
#   6,
#   4,
#   362,
#   22,
#   1753,
#   7,
#   355,
#   136,
#   70],
#  [12, 4344, 10, 2171, 253],
#  [2, 3, 1, 34, 162, 14, 15, 281, 13, 2881, 565],
#  [2, 3, 1, 341, 1500, 926, 11007],
#  [36,
#   29,
#   1736,
#   8793,
#   9,
#   35,
#   14,
#   2611,
#   678,
#   10,
#   1,
#   2533,
#   27,
#   1,
#   2889,
#   3543,
#   17,
#   58,
#   41908,
#   27,
#   2276,
#   40,
#   1465,
#   55,
#   1957,
#   6,
#   678],
#  [2, 3, 1, 433, 7, 4, 10902, 1251],
#  [2, 3, 1, 8138],
#  [26, 50, 3925, 718, 303, 210, 23, 367, 3151],
#  [49,
#   2262,
#   64427,
#   520,
#   687,
#   7,
#   2995,
#   5107,
#   87994,
#   64427,
#   7584,
#   13,
#   615,
#   5,
#   33,
#   65,
#   128,
#   78,
#   7,
#   112,
#   2031,
#   6641,
#   22,
#   49,
#   154,
#   3909,
#   13,
#   17],
#  [15,
#   4,
#   2019,
#   182,
#   4,
#   15050,
#   8,
#   85,
#   5,
#   182,
#   4,
#   15050,
#   64,
#   8,
#   85,
#   5,
#   81,
#   1,
#   1289,
#   10,
#   8,
#   179,
#   6,
#   1,
#   387],
#  [2, 31, 8, 11, 20, 8, 1220, 5, 1363, 18, 1955, 6, 74],
#  [52,
#   68,
#   1533,
#   2279,
#   7,
#   629,
#   225,
#   19,
#   46,
#   126,
#   3391,
#   29,
#   668,
#   6,
#   3853,
#   126,
#   46,
#   3391,
#   4,
#   134,
#   13,
#   2046,
#   10,
#   680,
#   6,
#   3853,
#   36,
#   306],
#  [61, 3, 1, 64428, 3110, 1036, 527],
#  [6,
#   7115,
#   15499,
#   1475,
#   53555,
#   9,
#   3,
#   17,
#   19,
#   1,
#   66,
#   4353,
#   1254,
#   8677,
#   48,
#   43,
#   24,
#   1,
#   1852,
#   652,
#   32,
#   1,
#   1852,
#   49,
#   5301,
#   100,
#   1,
#   211,
#   2508,
#   1,
#   1852,
#   49,
#   654,
#   5,
#   795,
#   19682,
#   1,
#   372],
#  [41, 8, 25, 18354, 946, 1069, 10, 7149, 17],
#  [9, 26, 1, 317, 5266, 1330, 27, 3308, 5266],
#  [9, 26, 56, 3880, 13239],
#  [30, 3, 1, 34, 2215, 3796, 13, 1410, 367, 3151],
#  [11, 243, 37, 99, 3992, 5, 31426, 4423],
#  [8,
#   91,
#   17307,
#   11239,
#   27,
#   1165,
#   728,
#   16,
#   8358,
#   10,
#   4,
#   703,
#   7638,
#   3,
#   17,
#   96,
#   54],
#  [9, 15, 14, 14138, 4, 9413, 152, 6607, 69, 37, 21, 130, 2406],
#  [143,
#   19,
#   453,
#   123,
#   3,
#   309,
#   16,
#   248,
#   77,
#   1895,
#   1442,
#   7,
#   11465,
#   7002,
#   38344,
#   976,
#   296],
#  [2, 12, 1, 635, 7, 168, 95, 571, 1267],
#  [2,
#   20,
#   14,
#   12,
#   1467,
#   1135,
#   21,
#   539,
#   37,
#   5,
#   29,
#   2340,
#   425,
#   7,
#   7003,
#   1398,
#   5188,
#   10,
#   5917,
#   1135,
#   21,
#   64429,
#   22548,
#   5,
#   392,
#   4,
#   2695],
#  [2, 12, 1, 779, 301, 735, 7, 717],
#  [2, 3, 6642],
#  [2,
#   853,
#   7,
#   369,
#   58,
#   1,
#   34,
#   2476,
#   21881,
#   1885,
#   38345,
#   22,
#   752,
#   21881,
#   7,
#   280,
#   1,
#   3043,
#   6928,
#   76,
#   1885,
#   21881],
#  [12, 6302, 5395, 316, 59, 4, 18762],
#  [2, 3, 34, 79, 5, 33, 23, 127, 2341, 27, 28437, 5, 9196, 5803],
#  [16,
#   11,
#   192,
#   37,
#   613,
#   42,
#   46,
#   234,
#   88,
#   343,
#   4138,
#   24,
#   46,
#   1042,
#   7,
#   1,
#   21882,
#   613,
#   88,
#   2641,
#   7,
#   13946,
#   7,
#   195,
#   823,
#   61,
#   343,
#   5,
#   192,
#   37],
#  [2, 3, 1, 34, 261, 5, 76, 5, 121, 28, 186, 233, 897, 23],
#  [3, 17, 109, 5, 76, 6713, 691, 6, 4, 13752, 3466],
#  [2,
#   12,
#   1,
#   2001,
#   1255,
#   119,
#   6,
#   1,
#   162,
#   1144,
#   414,
#   1144,
#   565,
#   74,
#   536,
#   47,
#   7401,
#   19683],
#  [2, 3, 1, 84, 13, 12739, 407, 6, 29, 1981],
#  [2, 3, 1, 125, 69, 25994, 211, 10, 1189, 211],
#  [2, 3, 1, 1726, 5, 87995, 20179, 87996],
#  [16, 12, 14, 43, 1183, 54, 44, 104],
#  [1892, 17, 42, 5, 13947, 21, 4, 771, 181, 14, 142, 6, 28, 850],
#  [2, 3, 1, 522, 7, 1, 1230, 637, 116, 752],
#  [16, 4, 723, 15, 43, 25, 1042, 23, 1138],
#  [18,
#   6820,
#   49,
#   1004,
#   2240,
#   10,
#   1004,
#   5075,
#   90,
#   642,
#   49,
#   2240,
#   64,
#   77,
#   48,
#   43,
#   24,
#   1,
#   2240,
#   2494,
#   44,
#   1,
#   70,
#   97,
#   8,
#   129,
#   4016,
#   1,
#   2240,
#   2494,
#   47,
#   6161],
#  [12, 57, 512, 201, 10, 1294, 3881, 7116, 29, 5076],
#  [12, 2296, 2860, 458, 5, 1578, 4, 53, 163, 6, 1, 92],
#  [3,
#   12896,
#   10,
#   12094,
#   7,
#   1428,
#   2391,
#   132,
#   109,
#   101,
#   60,
#   37,
#   33344,
#   10,
#   24972,
#   1799,
#   5,
#   151,
#   10310,
#   65,
#   38346,
#   10,
#   6026,
#   5,
#   37,
#   21,
#   4139,
#   1280,
#   10,
#   4366,
#   71,
#   5,
#   424,
#   40,
#   12,
#   16330,
#   7,
#   394,
#   3926],
#  [2, 3, 1, 5608, 884, 7, 4, 8794, 5034],
#  [3,
#   17,
#   203,
#   19,
#   20,
#   14,
#   4213,
#   82,
#   14,
#   24,
#   5,
#   121,
#   136,
#   27,
#   1,
#   2324,
#   10,
#   546,
#   488],
#  [15, 4, 180, 11, 183, 315, 3563, 6, 57],
#  [16, 3, 18, 949, 2388, 44, 54, 158, 154, 499, 2617, 54],
#  [224, 9, 43, 5, 1698, 18, 832, 2336, 10, 1852],
#  [2, 41, 25, 1, 471, 7, 29, 1783, 2420, 27, 176, 11353],
#  [15, 51, 76, 4603, 691, 36, 16331, 5, 33, 169, 3993],
#  [30, 1802, 1421, 3, 102, 5, 688],
#  [3,
#   39,
#   4,
#   1016,
#   479,
#   221,
#   19,
#   2566,
#   7980,
#   19191,
#   239,
#   3491,
#   32,
#   1684,
#   2962,
#   1333],
#  [16, 11, 202, 124, 2031, 55, 4639, 136, 2090],
#  [2, 12, 1, 3492, 7, 116, 752],
#  [3,
#   39,
#   4,
#   5770,
#   19,
#   7188,
#   1321,
#   2702,
#   1442,
#   10,
#   167,
#   1348,
#   4,
#   7004,
#   372,
#   27186,
#   409,
#   23,
#   4,
#   1413,
#   2342,
#   6044],
#  [15, 29, 454, 180, 11, 6464, 6, 308],
#  [6,
#   2,
#   224,
#   26,
#   392,
#   8,
#   6162,
#   377,
#   1,
#   724,
#   7,
#   177,
#   392,
#   8,
#   64430,
#   4149,
#   47,
#   1,
#   12897,
#   322,
#   8,
#   64430,
#   3,
#   517,
#   5,
#   392,
#   8,
#   28438,
#   32,
#   5358,
#   13,
#   4,
#   998,
#   411],
#  [26, 6070, 10592, 5422, 115, 65, 1640],
#  [30,
#   1101,
#   901,
#   4716,
#   10493,
#   2103,
#   1,
#   60,
#   3562,
#   13,
#   28,
#   13398,
#   1,
#   18355,
#   106,
#   22,
#   1,
#   4656,
#   25995,
#   3340],
#  [16, 11, 4875, 1723, 7790, 294],
#  [2,
#   833,
#   11,
#   10053,
#   10,
#   24973,
#   16038,
#   24088,
#   24,
#   32,
#   17,
#   825,
#   5,
#   1094,
#   10,
#   2776,
#   32,
#   2374,
#   435,
#   10,
#   971,
#   575],
#  [6,
#   370,
#   5,
#   93,
#   4,
#   87997,
#   1760,
#   14,
#   24,
#   5,
#   2288,
#   29,
#   4673,
#   6,
#   594,
#   7,
#   354,
#   435,
#   22,
#   3415,
#   11590],
#  [2, 3, 52, 18763, 6, 1888, 5651],
#  [11,
#   8,
#   120,
#   781,
#   150,
#   1008,
#   8,
#   80,
#   66,
#   3051,
#   36,
#   20,
#   1,
#   94,
#   3,
#   2027,
#   5,
#   5267,
#   10,
#   38,
#   279,
#   8,
#   101,
#   146,
#   99,
#   42,
#   177,
#   78,
#   7,
#   1444,
#   3,
#   62,
#   96,
#   20717,
#   6,
#   18,
#   64431,
#   22,
#   11,
#   8,
#   339,
#   120,
#   354,
#   1569],
#  [9, 11, 8, 81, 20, 18, 16039, 238, 21, 493, 126, 707, 1092, 13, 54],
#  [32, 10, 61, 10, 30, 14139, 41909, 2918, 24, 1671],
#  [11, 66, 2736, 275, 6, 87998],
#  [2,
#   11,
#   14,
#   33,
#   32,
#   14,
#   2426,
#   4,
#   3945,
#   288,
#   87999,
#   10,
#   4,
#   4846,
#   7,
#   2240,
#   13948,
#   2360],
#  [2, 3, 1, 654, 1130, 20, 1, 2720, 38347, 24, 4242, 46698],
#  [2, 3, 33345],
#  [9, 12, 1, 2378, 6, 4, 2134, 5077, 878, 2342],
#  [97, 8302, 1837, 106, 5, 1, 5867, 6, 212],
#  [3, 17, 5590, 5, 562, 18, 6097, 27, 171, 134],
#  [9,
#   68,
#   114,
#   11,
#   8,
#   120,
#   5,
#   1525,
#   144,
#   8,
#   1714,
#   29,
#   3302,
#   5,
#   18,
#   507,
#   36,
#   154,
#   126,
#   169,
#   21,
#   112,
#   520,
#   6,
#   3622],
#  [16, 60, 116, 545, 101, 561, 55, 4261, 144, 598],
#  [3, 480, 667, 21, 55, 74],
#  [3,
#   39,
#   50,
#   240,
#   19,
#   35,
#   795,
#   54,
#   5,
#   16332,
#   1944,
#   23,
#   73,
#   37,
#   10,
#   63,
#   128,
#   78,
#   7,
#   17],
#  [16, 11, 12578, 1240, 23, 18, 2071],
#  [9, 11, 53556, 64432, 1, 776],
#  [7438, 8, 67, 7, 13052, 8, 67, 7, 3946, 3197, 3, 19, 1287],
#  [2, 3, 6364, 10, 16, 4622, 51, 578, 5, 146, 661],
#  [9, 48, 24974, 88000, 93, 4, 3286],
#  [967,
#   1,
#   34,
#   79,
#   5,
#   333,
#   28,
#   242,
#   13,
#   4,
#   107,
#   4073,
#   2,
#   145,
#   31,
#   8,
#   182,
#   10,
#   2,
#   31,
#   8,
#   25,
#   208,
#   5,
#   63,
#   1,
#   340,
#   106,
#   36,
#   13053,
#   36,
#   109,
#   39,
#   12,
#   105,
#   73,
#   3719],
#  [2, 6, 28, 555, 31, 25, 1, 2050, 657, 7, 4, 163, 22, 147],
#  [41, 18, 3673, 5771, 24975, 93, 401],
#  [15,
#   75,
#   375,
#   13,
#   2091,
#   2407,
#   64433,
#   1487,
#   952,
#   1814,
#   7,
#   2020,
#   10,
#   1129,
#   148,
#   44,
#   23269,
#   163,
#   4897],
#  [9, 15, 8, 991, 18, 9557, 3788, 740, 19, 3, 360, 4, 2201, 2967],
#  [2, 3, 1, 383, 376, 13, 2461, 31427, 3246],
#  [9, 11, 490, 1213, 5446, 84],
#  [2,
#   282,
#   7,
#   5652,
#   31,
#   51,
#   199,
#   13,
#   32,
#   2263,
#   4,
#   2266,
#   13,
#   29,
#   4604,
#   875,
#   524,
#   5,
#   647,
#   10,
#   7733],
#  [12, 497, 22549, 42, 88001, 88002, 1, 2324, 7, 4, 107, 678],
#  [21,
#   52,
#   72,
#   128,
#   475,
#   16,
#   3,
#   19,
#   51,
#   6542,
#   1597,
#   4,
#   65,
#   952,
#   455,
#   2166,
#   22,
#   1196,
#   2415,
#   100,
#   455,
#   3392],
#  [9, 11, 8, 93, 4, 1558, 1952, 44, 1, 274, 7, 436],
#  [2, 3, 435, 1116, 10, 5496, 1209, 10, 9, 12, 46, 119],
#  [2, 3, 319, 1, 693, 389, 6, 513],
#  [2, 12, 1, 240, 2642, 13, 4, 8540, 3426],
#  [16, 12, 60, 7, 1, 7229, 6, 57, 135, 10, 856],
#  [3, 1, 35611, 292, 129, 1930],
#  [16, 11, 372, 585, 232, 24, 10903, 2018, 604, 71, 88003, 913],
#  [26, 15757, 88004, 380, 1, 2398, 7, 7981],
#  [2, 3, 1, 376, 13, 2328, 8085, 6, 22550],
#  [16, 3, 1624, 2743, 10147, 157, 1624, 2743, 32, 208, 1571, 4657],
#  [9, 15, 8, 397, 18, 1221, 23, 1945, 10, 33, 7685, 1384],
#  [9, 15, 14, 63, 27187, 95, 24089],
#  [8,
#   80,
#   177,
#   1,
#   29845,
#   2477,
#   59,
#   8139,
#   4,
#   88005,
#   1290,
#   409,
#   261,
#   23,
#   285,
#   23270,
#   1402,
#   2,
#   3,
#   1,
#   376,
#   13,
#   62,
#   15,
#   173,
#   150,
#   54,
#   4751,
#   62,
#   434],
#  [967, 1, 34, 79, 5, 33, 6365, 13240, 78, 7, 1, 1266, 27188, 7, 29, 754, 6098],
#  [2, 3, 1, 3247, 70, 28, 494, 58, 13054, 14, 6, 4, 4536],
#  [9, 15, 8, 880, 6, 239, 673, 852, 47, 1429, 100, 88006],
#  [2, 3, 1, 4640, 6190, 7, 4, 10054],
#  [61, 15, 8, 684, 281, 152, 6163, 7, 15758, 19192, 1039, 324, 108],
#  [2, 11, 14, 67, 7, 1, 107, 726, 3555, 338, 6, 2384],
#  [9, 72, 3, 1, 310, 7, 1, 1251, 13, 15270, 6, 1, 92],
#  [16, 48, 14, 93, 4, 1443],
#  [16, 31, 929, 2112, 25, 6668],
#  [143, 19, 2512, 12, 4, 2986, 6, 15271, 9, 58, 1568, 828, 15271],
#  [117, 1, 34, 79, 5, 416, 18, 1439, 536, 10, 63, 1278, 7, 18, 186],
#  [2, 188, 32, 2337, 9880, 3, 5804],
#  [2, 3, 28, 334, 563, 23, 258, 243],
#  [3,
#   5150,
#   5942,
#   2365,
#   1681,
#   158,
#   90,
#   1511,
#   12,
#   52,
#   366,
#   10,
#   42,
#   1581,
#   4,
#   2006,
#   7,
#   209,
#   77,
#   1181,
#   314,
#   7,
#   87,
#   2361],
#  [2, 12, 53, 13572, 19, 4, 4829, 694, 168, 41, 25, 4, 334, 168, 6, 1, 251],
#  [16, 3, 22551, 3332, 5, 25, 1822, 152, 61, 11, 14, 91, 1, 1679, 3046, 152],
#  [2, 58, 88007, 6071],
#  [61, 3, 1, 11591, 13, 12579, 3780],
#  [2, 3, 1, 125, 69, 88008, 10, 647],
#  [15, 8, 11240, 4, 20180, 3346, 4, 420, 4605, 27, 1, 13, 4465, 6, 391],
#  [9, 35, 14, 662, 1, 31428, 7, 1, 1039, 7, 1, 12095],
#  [2, 49, 1, 125, 69, 88009, 1141, 27, 25996, 1141],
#  [15, 14, 935, 54, 9, 5, 6303],
#  [2, 3, 64434, 2420, 53557, 88010],
#  [9, 133, 48, 17, 86, 11354, 5, 1452, 3347, 21, 55, 186, 3528],
#  [2, 1082, 437, 12, 8990, 271, 1, 535, 22, 762, 13055],
#  [3, 39, 50, 280, 517, 5, 355, 10, 3097, 4559, 6, 57],
#  [3, 39, 4, 16040, 3130, 13, 584, 33346],
#  [9, 3, 28, 74, 59, 23271],
#  [6, 372, 585, 462, 16, 11, 135, 2347, 492, 3, 65, 1694, 8541],
#  [2, 3, 1, 957, 1, 2497, 44, 1, 328, 7, 1, 7230, 47, 6971, 41910, 45],
#  [8, 96, 10148, 78, 1, 235, 944, 9, 11, 8, 156, 3651],
#  [16,
#   26,
#   17,
#   651,
#   42,
#   68,
#   350,
#   638,
#   5014,
#   1791,
#   21,
#   1,
#   989,
#   2282,
#   382,
#   1013,
#   88011],
#  [11,
#   14,
#   67,
#   1,
#   2369,
#   7,
#   1046,
#   2462,
#   231,
#   13056,
#   23,
#   90,
#   1859,
#   30,
#   6270,
#   1705,
#   170,
#   83,
#   18764,
#   10,
#   38348],
#  [9,
#   133,
#   26,
#   17,
#   86,
#   13,
#   4,
#   4129,
#   5,
#   25,
#   88012,
#   59,
#   4,
#   1204,
#   7,
#   7043,
#   58,
#   113,
#   4989],
#  [9, 68, 8991, 193, 12, 6669, 47, 1087, 4227, 10, 424, 7, 90, 687],
#  [3, 17, 316, 5, 24, 6191, 8599, 59, 3708, 7734],
#  [20,
#   8,
#   151,
#   4,
#   539,
#   2534,
#   1126,
#   5,
#   4,
#   12898,
#   1542,
#   18,
#   88013,
#   25,
#   4170,
#   36,
#   195,
#   1211,
#   36,
#   49,
#   33347,
#   47,
#   1,
#   2728,
#   1083,
#   6,
#   5772,
#   36,
#   139,
#   4698,
#   834,
#   1881,
#   4,
#   20181,
#   831,
#   58,
#   113,
#   38349,
#   13,
#   28,
#   229,
#   2421,
#   7439,
#   28,
#   105,
#   1264,
#   3246],
#  [9, 11, 8, 187, 2135, 95, 177, 1576, 47, 104, 22, 28, 257],
#  [3,
#   17,
#   1387,
#   5,
#   156,
#   19,
#   143,
#   111,
#   1149,
#   21,
#   1974,
#   2379,
#   1142,
#   3556,
#   10,
#   3528,
#   15,
#   2978,
#   1,
#   6366,
#   585,
#   508,
#   5,
#   171,
#   310],
#  [48, 14, 99, 503, 59, 177, 28, 88014, 10, 468],
#  [16, 3, 1, 38350, 454, 571, 614, 2329, 5078],
#  [3, 5477, 4, 1869, 5719, 22, 3, 17, 4, 3198, 1085, 7, 9123],
#  [2, 12, 1, 632, 5, 661, 6, 611, 36, 306, 36, 6, 937],
#  [9, 11, 8, 63, 384, 1021, 10, 12580, 258, 1, 383, 5318, 6, 18, 74],
#  [15,
#   4909,
#   150,
#   21,
#   10149,
#   2596,
#   7402,
#   1311,
#   47,
#   6643,
#   10,
#   22,
#   3440,
#   12581,
#   14820,
#   46699,
#   88015,
#   209,
#   11241,
#   954,
#   826,
#   10,
#   1567,
#   66,
#   1478,
#   517,
#   5,
#   1,
#   8359,
#   20,
#   4909,
#   97,
#   150,
#   2,
#   35,
#   25,
#   1,
#   938],
#  [2, 35, 188, 20, 1, 20182, 48, 2737, 3641, 53558],
#  [20, 6099, 3, 52, 53, 16, 11, 37, 505, 6099],
#  [16, 26, 84, 86, 82, 52, 72, 7, 139, 153],
#  [2, 3, 1, 542, 7, 1, 245, 420, 7, 183, 631, 6, 1, 213, 5720, 21284],
#  [4,
#   1104,
#   3085,
#   759,
#   27,
#   29,
#   5075,
#   606,
#   163,
#   1102,
#   5,
#   1091,
#   553,
#   10,
#   252,
#   6,
#   1,
#   387,
#   2,
#   12,
#   1,
#   1459],
#  [9, 15, 8, 33, 7189, 359, 2833],
#  [6, 2, 79, 48, 1, 29846, 2807, 2002, 227, 442],
#  [2,
#   569,
#   7,
#   6132,
#   35,
#   84,
#   34,
#   23,
#   2516,
#   21,
#   2416,
#   1621,
#   954,
#   1291,
#   12899,
#   417],
#  [118,
#   1670,
#   10,
#   11,
#   43,
#   159,
#   351,
#   793,
#   7438,
#   1404,
#   8,
#   111,
#   33,
#   829,
#   6,
#   4,
#   263,
#   13,
#   543,
#   279,
#   167,
#   2183,
#   170,
#   443,
#   3,
#   62,
#   316,
#   9,
#   15,
#   8,
#   379,
#   21,
#   62,
#   1017],
#  [3, 1870, 1, 141, 137, 36, 1205, 10, 521],
#  [20,
#   66,
#   126,
#   27189,
#   10,
#   7361,
#   12,
#   1,
#   122,
#   1426,
#   13,
#   509,
#   16,
#   26,
#   83,
#   4,
#   2210,
#   949,
#   63,
#   14,
#   2996],
#  [61, 26, 46700, 1784, 6, 1, 46701],
#  [9, 133, 31429, 10494],
#  [26,
#   1,
#   221,
#   14,
#   756,
#   805,
#   4,
#   426,
#   7,
#   1244,
#   623,
#   27,
#   198,
#   13,
#   635,
#   8,
#   485,
#   1334,
#   198,
#   623,
#   6,
#   997,
#   16,
#   22,
#   16,
#   43],
#  [2, 12, 1, 34, 195, 9794, 4479, 13, 152, 1865, 140],
#  [2, 3, 15500, 7440],
#  [16, 12, 1, 2542, 257, 7231, 27, 88016, 12, 1548, 10, 130, 6, 213, 7, 6892],
#  [9, 15, 51, 465, 139, 1659, 5, 1369],
#  [9, 3, 1188, 74, 44, 1090, 6517],
#  [3, 31430, 2689, 10, 35612, 88017, 564],
#  [3,
#   17,
#   109,
#   5,
#   1045,
#   6,
#   1,
#   647,
#   9713,
#   21,
#   96,
#   4,
#   2175,
#   3433,
#   4171,
#   4062,
#   10,
#   4,
#   31431],
#  [2, 12, 1, 60, 217, 145, 25997, 1426, 101, 138, 6, 55, 28439, 280],
#  [2, 493, 26, 4184, 25998, 24],
#  [20, 14, 3144, 6518, 775, 6436, 35, 14, 226, 28, 871, 16, 22, 16, 43],
#  [2, 3, 1, 1679, 79, 5, 321, 29, 454, 3674],
#  [8,
#   24,
#   272,
#   4,
#   337,
#   7,
#   64435,
#   6,
#   5525,
#   2234,
#   256,
#   64,
#   8,
#   24,
#   4,
#   8303,
#   6,
#   18,
#   892,
#   256,
#   15,
#   8,
#   129,
#   33,
#   100,
#   550,
#   42,
#   16333,
#   22,
#   15759],
#  [40, 11, 38, 37, 300, 83, 9558, 9558, 47, 6821],
#  [2, 11, 14, 2949, 27, 4, 110],
#  [9, 48, 5302, 8992, 171, 134, 688, 6, 2051, 95, 83, 29, 9639, 3709],
#  [9, 68, 2378, 31, 8, 121, 78, 716, 5, 561, 452],
#  [16,
#   26,
#   2768,
#   231,
#   7536,
#   155,
#   11008,
#   5,
#   11,
#   50,
#   197,
#   4640,
#   455,
#   3663,
#   160,
#   1,
#   4508,
#   7,
#   4,
#   1434,
#   7,
#   2729,
#   32,
#   2768,
#   1300,
#   196,
#   5844,
#   237,
#   103,
#   10,
#   61,
#   26,
#   19,
#   128,
#   106],
#  [16,
#   88,
#   1,
#   1304,
#   3384,
#   1,
#   722,
#   20183,
#   10,
#   1155,
#   289,
#   52,
#   2798,
#   117,
#   284,
#   21,
#   87],
#  [3, 17, 388, 5, 11, 1946, 53559, 27, 64436, 611],
#  [12, 39, 50, 1105, 438, 6241, 6, 1460],
#  [32, 26, 20184, 393, 406],
#  [20, 108, 108, 230, 10, 16, 230, 108, 108, 16, 46, 43, 230, 108, 157],
#  [20, 128, 7585, 695, 30, 3, 4, 102, 182, 656, 7486, 22, 5943],
#  [15, 51, 156, 24090, 41, 25, 1, 141],
#  [2, 3, 1, 34, 79, 5, 359, 265, 12096, 4, 5569],
#  [9, 53, 3, 1125, 6, 595],
#  [26, 7190, 228, 47, 1, 6100, 723, 42, 265, 625],
#  [2, 12, 1, 130, 569, 7, 1520, 2188, 6, 1030],
#  [2, 3, 1, 34, 79, 5, 416, 7440],
#  [16, 3, 3910, 52, 23272],
#  [2,
#   3,
#   1,
#   1706,
#   19,
#   105,
#   183,
#   24,
#   1,
#   141,
#   403,
#   420,
#   6,
#   4,
#   5695,
#   826,
#   7,
#   185,
#   1641],
#  [9,
#   12,
#   29847,
#   1258,
#   6893,
#   9414,
#   6133,
#   2342,
#   21,
#   111,
#   183,
#   10696,
#   2,
#   45,
#   1,
#   531,
#   10696],
#  [30, 3, 1, 34, 4093, 245, 6, 21883],
#  [9, 952, 3, 1, 676, 1039, 9559, 1446, 924, 5, 1, 38351, 1494],
#  [9, 11, 14, 91, 2240, 2347, 2888, 32, 46, 756, 198],
#  [2, 3, 1, 34, 1049, 59, 6271, 18, 299, 382, 534, 315],
#  [24,
#   14,
#   89,
#   113,
#   9714,
#   10,
#   22,
#   2321,
#   6,
#   17645,
#   20,
#   52,
#   9,
#   48,
#   14,
#   1191,
#   1,
#   1017],
#  [2, 3, 1, 34, 1213, 10, 17308, 730, 575],
#  [31, 8, 33, 4, 3622, 2890, 1124, 22, 176, 2890, 1124],
#  [2, 3, 1, 1696, 69, 2777, 1966, 10, 7005, 1966],
#  [16,
#   3,
#   17,
#   32,
#   8,
#   49,
#   21,
#   18,
#   520,
#   154,
#   119,
#   5,
#   24,
#   520,
#   7076,
#   19,
#   1492,
#   154,
#   499,
#   85,
#   5,
#   25,
#   21,
#   170,
#   144,
#   46,
#   1492,
#   154,
#   4572,
#   443],
#  [2, 35, 17, 115, 20, 51, 1996, 73, 235, 7044, 23, 73, 361, 42, 2516],
#  [16, 26, 1, 3515, 209, 33, 52, 1143, 32, 75, 35613, 1, 3031],
#  [9, 48, 3710, 88018, 707, 1, 1197, 10, 14821, 7, 155, 350, 297, 64437],
#  [2,
#   3,
#   1,
#   376,
#   13,
#   177,
#   41911,
#   789,
#   71,
#   430,
#   1200,
#   5804,
#   3516,
#   1100,
#   27,
#   4,
#   4466,
#   2904,
#   9560],
#  [3, 41912, 6304, 15760, 3, 1, 1726, 190, 7, 757, 6304, 15760],
#  [2, 37, 136, 420, 111, 158, 264, 1256],
#  [16, 3, 1208, 4752, 52, 5059],
#  [20, 14, 5222, 28, 863, 15, 14, 129, 33, 180, 3587],
#  [2, 3, 1, 779, 184, 14, 1705, 356],
#  [2, 3, 1, 34, 968, 13, 258, 1097],
#  [15, 14, 616, 29, 635, 7, 1626, 24091, 6, 721, 3684],
#  [118, 4, 227, 189, 1664, 9, 5, 3761, 4, 875],
#  [9,
#   15,
#   123,
#   25,
#   4,
#   5376,
#   22,
#   146,
#   4,
#   5107,
#   20,
#   77,
#   3588,
#   6742,
#   44,
#   768,
#   1327,
#   431],
#  [2,
#   31,
#   14,
#   199,
#   78,
#   13,
#   6,
#   4,
#   147,
#   32,
#   14,
#   12,
#   1102,
#   5,
#   882,
#   3066,
#   6,
#   140,
#   1129],
#  [9, 15, 8, 63, 351, 187, 1060, 665, 631, 4, 153, 13, 318, 952, 212],
#  [2, 3, 1, 2712, 125, 69, 690, 19, 101, 24, 4185, 10, 690, 19, 11],
#  [15, 8, 25, 13399, 10, 129, 506, 4367, 2807],
#  [2, 940, 3, 841, 6608],
#  [30,
#   11,
#   14,
#   67,
#   3,
#   1,
#   1681,
#   434,
#   10394,
#   1993,
#   22,
#   1,
#   2641,
#   7,
#   37,
#   19,
#   231,
#   3110,
#   87,
#   100,
#   754],
#  [2, 3008, 1338, 48, 8924, 6045, 11466, 76, 6, 1, 16641, 9881],
#  [2, 5396, 6, 2247, 48, 1, 18005, 2463, 27, 88019, 788],
#  [30, 12, 424, 270, 185, 19193, 19, 151, 1, 1241, 6743],
#  [11, 244, 547, 2028, 129, 567],
#  [2, 320, 7, 1354, 48, 1, 4658, 76, 5, 4573, 41913, 3434, 1292, 33348],
#  [2, 12, 38, 2618, 45, 1, 8542, 7982],
#  [16, 11, 6543, 1922, 6, 104, 551, 22552, 59, 360, 11592, 5, 28, 336],
#  [9, 68, 88020, 24, 39, 113],
#  [30, 3, 1, 34, 2154, 6, 62, 883, 94],
#  [3, 22553, 15761, 6, 11467, 10, 5169],
#  [2, 12, 574, 224, 5, 654, 18765],
#  [8, 14380, 2605, 1705, 7686, 356, 2, 35, 77, 67],
#  [2, 3, 1, 1923, 10, 6101, 537, 7, 290, 7, 1, 2516, 6, 1, 1246, 211],
#  [30, 362, 11, 14, 42, 1, 60],
#  [15, 8, 33, 530, 6, 24976, 44, 337, 88021],
#  [32, 49, 1, 304, 70, 14, 499, 63, 17, 5, 1, 4368, 23, 70],
#  [3,
#   50,
#   354,
#   22,
#   2075,
#   103,
#   1204,
#   459,
#   44,
#   1,
#   70,
#   7,
#   530,
#   6,
#   5696,
#   10,
#   3009,
#   20,
#   8,
#   24,
#   3309,
#   56,
#   103],
#  [1008,
#   56,
#   7,
#   18,
#   7834,
#   3572,
#   7790,
#   294,
#   4390,
#   131,
#   6670,
#   2106,
#   10,
#   24977,
#   18,
#   1897,
#   22,
#   96,
#   13,
#   105,
#   376,
#   44,
#   66,
#   3,
#   62,
#   316,
#   105,
#   557,
#   10,
#   1150,
#   17,
#   24978,
#   1425,
#   20,
#   8,
#   1392,
#   294,
#   155,
#   472,
#   5,
#   314,
#   64,
#   234,
#   44,
#   1,
#   141,
#   70],
#  [31, 8, 33, 1468, 44, 2766, 11973, 22, 1468, 1090, 10593],
#  [61, 8, 15, 91, 1, 34, 187, 1051, 152, 13, 148],
#  [11,
#   14,
#   67,
#   3213,
#   352,
#   35,
#   24,
#   254,
#   4,
#   102,
#   110,
#   71,
#   6001,
#   1917,
#   6,
#   1502,
#   1,
#   168,
#   6,
#   201,
#   35,
#   352,
#   25,
#   2127,
#   5,
#   7117,
#   21,
#   243,
#   5944,
#   23,
#   911,
#   5627,
#   22,
#   43],
#  [11, 124, 4439, 1, 34, 169, 13, 55, 6487, 10, 1, 641, 13, 55, 4639],
#  [2, 12, 1, 854, 7, 1, 64438, 1867],
#  [9,
#   15,
#   8,
#   1827,
#   2729,
#   22,
#   380,
#   13,
#   18,
#   152,
#   17646,
#   559,
#   19,
#   28440,
#   29,
#   982,
#   137,
#   21,
#   833,
#   45,
#   6778,
#   438,
#   10,
#   1378],
#  [16,
#   11,
#   38,
#   1046,
#   3287,
#   24,
#   200,
#   10,
#   192,
#   22,
#   699,
#   10,
#   192,
#   46702,
#   23,
#   55,
#   6102],
#  [2, 49, 64439, 88022, 2738, 5, 93, 4, 1687],
#  [2, 3, 1, 522, 7, 4, 1046, 31432],
#  [41, 14, 3238, 28, 1121, 20, 154, 11, 4, 2096],
#  [16, 11, 414, 41914, 136, 28, 33349, 10, 20185, 1766, 28, 12097],
#  [9, 11, 14, 81, 20, 14, 24, 1640, 29848],
#  [2, 12, 1, 34, 11713, 6, 1561],
#  [16, 35, 14, 848, 75, 5, 525, 1, 350, 437, 1174, 27, 13573],
#  [118, 769, 6, 1754, 52, 31, 8, 106, 13, 249, 148],
#  [16, 11, 2132, 33, 11714, 65, 167, 2696, 13, 208, 780, 284],
#  [31, 8, 783, 82, 21, 18, 500, 158, 18, 268, 760, 54, 5],
#  [16,
#   206,
#   8,
#   1698,
#   4,
#   181,
#   1405,
#   8,
#   1700,
#   64,
#   1012,
#   154,
#   126,
#   1092,
#   13,
#   265,
#   98,
#   146,
#   59,
#   8,
#   300,
#   712,
#   45,
#   112,
#   3,
#   39,
#   50,
#   79,
#   5,
#   891,
#   17],
#  [2,
#   12,
#   1,
#   1149,
#   6,
#   1,
#   14140,
#   19,
#   8,
#   31,
#   661,
#   61,
#   14,
#   15,
#   129,
#   24,
#   4,
#   751,
#   7,
#   229,
#   3358,
#   22,
#   19,
#   2979,
#   2332,
#   652,
#   8543,
#   27,
#   1,
#   88023,
#   7,
#   1,
#   229,
#   314,
#   6,
#   37,
#   4451,
#   10,
#   4017,
#   4018],
#  [16, 12, 14597, 65, 1256, 71, 4, 2884],
#  [2, 26, 2495, 6, 1, 878, 3125],
#  [30, 137, 73, 71, 341, 277, 1353, 2512, 22, 634, 10904, 149, 2582],
#  [2, 12, 1, 1430, 145, 14, 120, 5, 81, 45, 1, 269, 14, 349],
#  [2, 49, 1, 3136, 32, 14, 48, 194, 10807, 6, 401],
#  [9, 15, 8, 81, 1152, 18, 12098, 213, 3214, 21, 18, 257, 213],
#  [2, 3, 1, 1696, 69, 1582, 7, 269, 10, 1, 9340, 21285],
#  [2, 3, 1, 125, 69, 1, 1908, 7, 57, 10, 1699],
#  [61, 35, 8, 33, 530, 21, 62, 457, 371, 7, 5548, 6, 18, 680, 1898, 6, 3111],
#  [16, 46703, 129, 2482],
#  [2, 3, 1, 76, 64440, 2093],
#  [3, 139, 4969, 1, 197, 1733],
#  [3, 261, 6103, 109, 21, 29, 3376, 22, 3510],
#  [11, 5805, 10, 6714, 1709, 269],
#  [3, 1870, 4, 3967, 137],
#  [2, 3, 1, 34, 1211, 5, 916, 916, 5, 1211, 3239, 3125, 13, 460],
#  [26,
#   1589,
#   8140,
#   968,
#   84,
#   13,
#   107,
#   875,
#   291,
#   22,
#   73,
#   8140,
#   968,
#   3,
#   459,
#   5,
#   420,
#   107,
#   875,
#   291],
#  [3, 39, 4, 190, 13, 4, 7441, 13057, 5, 3700, 55, 186, 287, 136, 4, 1230],
#  [15, 88024, 46704, 4291, 2410, 28, 1257, 8, 80, 665, 114, 135],
#  [16,
#   11,
#   60,
#   37,
#   3365,
#   2314,
#   21,
#   128,
#   145,
#   5591,
#   10,
#   37,
#   101,
#   394,
#   1101,
#   6,
#   1,
#   79,
#   7,
#   2314],
#  [58, 173, 89, 113, 2158, 495, 44, 1132, 44, 242],
#  [15, 50, 56, 11, 21884, 1251, 13, 195],
#  [2, 3, 1, 1241, 105, 7, 7639, 2151, 47, 29, 116, 1687],
#  [3,
#   17,
#   3220,
#   13,
#   54,
#   5,
#   43,
#   81,
#   66,
#   1,
#   277,
#   7,
#   18,
#   137,
#   20,
#   8,
#   101,
#   447,
#   458],
#  [2, 12, 1, 1337, 7, 713, 4399],
#  [2, 12, 1, 130, 224, 8, 15, 660, 31433, 23, 6, 18, 2890, 1124],
#  [16,
#   48,
#   104,
#   733,
#   62,
#   2113,
#   5,
#   10150,
#   92,
#   32,
#   75,
#   3348,
#   4,
#   305,
#   59,
#   1284,
#   139,
#   5015],
#  [41,
#   39,
#   25,
#   29,
#   587,
#   5,
#   3467,
#   1,
#   12248,
#   1280,
#   23,
#   18,
#   998,
#   411,
#   6,
#   1,
#   225,
#   7,
#   1058],
#  [26, 1, 2680, 1389, 3349, 37],
#  [2, 12, 223, 19, 41, 63, 14, 159, 381, 6, 130, 2549],
#  [16,
#   11,
#   146,
#   2540,
#   2670,
#   275,
#   6,
#   3190,
#   2618,
#   5,
#   616,
#   1054,
#   205,
#   36,
#   685,
#   704,
#   10,
#   1,
#   611,
#   2107],
#  [16, 3, 1, 104, 382, 1854, 1728, 43, 5697, 2264, 356],
#  [9,
#   818,
#   14,
#   601,
#   82,
#   4,
#   46705,
#   14598,
#   3664,
#   4,
#   5976,
#   5,
#   173,
#   40,
#   15,
#   1271,
#   4,
#   123,
#   88025,
#   372],
#  [2, 12, 38, 330, 7, 6134, 15762],
#  [9, 15, 4, 385, 321, 128],
#  [2, 3, 1, 5653, 79, 5, 449, 3755],
#  [11, 2666, 745, 76, 4, 1256, 2930, 36, 4382, 47, 38, 840],
#  [117, 1, 3188, 184, 12249, 472, 5, 14, 252, 44, 4, 46706],
#  [18,
#   1515,
#   24092,
#   21,
#   18,
#   949,
#   136,
#   703,
#   145,
#   167,
#   32,
#   77,
#   2033,
#   77,
#   3,
#   284,
#   77,
#   248,
#   1710,
#   3486,
#   18,
#   949,
#   298,
#   54,
#   174,
#   2,
#   31,
#   8,
#   11],
#  [26, 29, 12900, 6863, 834, 90, 112, 186, 5825, 27, 1, 153, 7, 1356],
#  [20,
#   1,
#   7835,
#   1231,
#   7,
#   1893,
#   743,
#   1747,
#   166,
#   16,
#   26,
#   1,
#   737,
#   202,
#   1878,
#   3044,
#   1,
#   1173],
#  [16, 48, 17, 86, 52, 133, 13, 1024, 873, 5, 25, 444, 88026],
#  [16, 3, 1, 88027, 1, 15051, 3597, 12740],
#  [2, 12, 38, 7, 28, 476, 31434, 4301],
#  [1491,
#   201,
#   2,
#   73,
#   193,
#   1685,
#   22,
#   41,
#   1685,
#   1,
#   1079,
#   69,
#   3105,
#   10,
#   11355,
#   128],
#  [16, 41915, 1678, 119],
#  [9, 133, 26, 17, 86, 5, 24093, 53560, 88028, 389, 17, 6, 1, 9795],
#  [30, 12, 53, 152, 110, 9715, 5, 1009, 352, 6, 308],
#  [24, 14, 89, 113, 12901, 47, 116, 547, 380],
#  [2, 3, 1, 393, 7, 208, 4, 8853, 280, 27, 4162, 131, 208, 8993],
#  [18,
#   107,
#   3318,
#   740,
#   1745,
#   10695,
#   237,
#   70,
#   8,
#   546,
#   5,
#   504,
#   11009,
#   3,
#   39,
#   344,
#   8,
#   15,
#   11,
#   5,
#   991,
#   62],
#  [2, 48, 14, 138, 27, 28, 423, 318, 772, 1676, 806],
#  [40, 58, 1245, 14, 10, 20, 14, 97, 466, 5, 87, 2, 35, 14, 156],
#  [2, 3, 88029, 46707, 1332, 1469],
#  [9,
#   26,
#   56,
#   1921,
#   21,
#   4,
#   1666,
#   24094,
#   7,
#   43,
#   52,
#   3511,
#   1387,
#   2475,
#   45,
#   10905,
#   5096],
#  [2456,
#   58,
#   183,
#   8742,
#   56,
#   3,
#   25999,
#   10,
#   73,
#   56,
#   3,
#   27190,
#   1,
#   950,
#   69,
#   1,
#   183,
#   8742,
#   3,
#   22554,
#   167,
#   2,
#   3,
#   1,
#   3711,
#   7,
#   1,
#   2456],
#  [16, 11, 1, 10151, 1240, 38352, 23, 4876],
#  [41, 12902, 24, 4, 3573],
#  [2, 12, 686, 145, 5245, 33350, 120, 5, 81, 45, 2343],
#  [2, 11, 14, 32, 1, 98, 14, 4588, 3572, 78, 5, 25, 4, 6242],
#  [3, 17, 161, 20, 56, 7, 18, 3487, 3, 1681, 71, 1, 73, 118, 532],
#  [30, 3, 4, 102, 147, 13, 468, 1748, 422, 88030, 22, 5977, 668, 7, 1939, 3037],
#  [2, 3, 1, 358, 1604, 7, 1792, 31435],
#  [11,
#   244,
#   16974,
#   10,
#   244,
#   7537,
#   295,
#   42,
#   9561,
#   1595,
#   8478,
#   10,
#   1815,
#   8478,
#   21,
#   5845],
#  [2,
#   3,
#   614,
#   13,
#   8479,
#   346,
#   1218,
#   588,
#   5609,
#   6929,
#   14599,
#   601,
#   14599,
#   4877,
#   1444,
#   10,
#   56,
#   1512],
#  [16, 3, 17, 19, 415, 1059, 3720, 4, 171, 2716],
#  [15, 8, 33, 4, 110, 59, 29, 468, 6, 57],
#  [2, 320, 7, 921, 8, 24, 5, 11, 13, 3198, 6863, 88031],
#  [2,
#   782,
#   7,
#   4,
#   19684,
#   3319,
#   310,
#   7836,
#   47,
#   4,
#   366,
#   140,
#   31,
#   25,
#   777,
#   5,
#   4,
#   3366,
#   252,
#   13,
#   1,
#   366,
#   140],
#  [58, 173, 670, 1, 27191, 1413, 1389, 5478, 317, 2, 15, 14, 226, 54, 45, 17],
#  [16, 24, 8, 232, 113, 52, 6544],
#  [31, 8, 4354, 62, 666, 1128, 896, 1089, 1724],
#  [48, 173, 12408, 45, 344, 19, 97, 111, 188, 6, 462],
#  [30, 213, 3, 363, 36, 1, 19194, 213],
#  [6,
#   1,
#   2652,
#   20,
#   1038,
#   1583,
#   4,
#   3,
#   2191,
#   71,
#   299,
#   10,
#   299,
#   2191,
#   71,
#   391,
#   26,
#   17,
#   639,
#   19,
#   4,
#   3,
#   2191,
#   71,
#   391],
#  [2, 12, 38, 3077, 1054, 19, 31, 25, 2297, 6, 2487, 64441, 1352],
#  [15, 8, 76, 11010, 1539],
#  [15,
#   1,
#   296,
#   3947,
#   19,
#   580,
#   1761,
#   506,
#   25,
#   8544,
#   10,
#   9483,
#   47,
#   1,
#   1761,
#   19,
#   76,
#   87,
#   22,
#   11,
#   46,
#   1787,
#   23,
#   1910,
#   55,
#   1379,
#   2411],
#  [9, 11, 8, 348, 9197, 905, 23, 438],
#  [2, 12, 38, 7, 1, 60, 35614, 1833, 577, 88032, 31, 2949, 78],
#  [9, 88033, 898],
#  [9, 12, 33351, 52, 1088],
#  [16, 11, 68, 3320, 437, 24, 55, 29849, 83, 864, 5268],
#  [2,
#   26,
#   17,
#   115,
#   5,
#   742,
#   19,
#   8,
#   80,
#   21,
#   4,
#   263,
#   10,
#   2720,
#   1511,
#   10,
#   83,
#   15052,
#   10,
#   2299,
#   82,
#   751,
#   38,
#   320,
#   7,
#   79,
#   8,
#   101,
#   146,
#   81,
#   1,
#   263],
#  [9, 11, 8, 8417, 104, 4623],
#  [31, 14, 5331, 144, 14, 2094, 6, 4, 1997],
#  [2, 12, 1, 11242, 658, 13, 121, 3165, 62, 103],
#  [16, 11, 17647, 485, 156, 19, 5651, 3, 2659],
#  [2, 12, 38, 635, 7, 41916, 4818, 1195],
#  [3, 671, 3393, 131, 8678, 318],
#  [3, 39, 4, 79, 5, 1018, 82, 13, 3206, 95, 4, 7936, 213],
#  [30, 15501, 162, 35, 56, 540, 1, 15501, 1199],
#  [9, 97, 24, 1, 1878, 129, 172, 1, 373, 586, 7118, 188],
#  [48, 10055, 6331, 89, 969, 19, 1624, 2267, 7, 2348, 1384, 41, 207, 27, 57],
#  [9, 11, 14, 321, 4, 4830, 16642, 296, 6, 898, 7, 2037],
#  [2, 11, 14, 67, 45, 1, 2268, 69, 453, 123, 10, 2262, 3207, 1614],
#  [2, 12, 38, 224, 5, 33, 674, 7, 18766, 23, 28, 403],
#  [3, 39, 50, 261, 13, 4659, 3754, 317],
#  [2, 12, 38, 7, 1, 34, 462, 45, 14822],
#  [9, 958, 347, 872, 5, 5748, 256],
#  [16, 11, 66, 10594, 2317, 82, 27, 1755, 2149],
#  [2, 11, 9970, 67, 7, 8743],
#  [41, 1, 9267, 18356, 89, 25, 53, 488],
#  [9, 15, 8, 1074, 18, 198, 95, 307, 6, 29, 198, 1141, 137],
#  [2, 12, 330, 7, 1129, 9057],
#  [2, 3, 1, 4084, 1605, 7, 6192, 6575],
#  [3, 17, 109, 5, 321, 1505, 1423, 6609, 160, 14141],
#  [2,
#   12,
#   33352,
#   10,
#   26000,
#   8231,
#   6,
#   324,
#   1627,
#   2068,
#   4,
#   568,
#   4624,
#   6519,
#   90,
#   2612,
#   2,
#   26,
#   5610,
#   85,
#   5,
#   11,
#   6,
#   324,
#   11243,
#   4624,
#   248,
#   85,
#   5,
#   501],
#  [12, 6027, 216, 373, 586, 252],
#  [9, 11, 14, 430, 4, 88034, 3450],
#  [16, 3, 1, 801, 7, 714, 52, 12582],
#  [26, 11244, 129, 2482, 6, 1, 3416, 44, 8304, 38, 12, 1007, 17, 129, 2482],
#  [1,
#   17648,
#   31,
#   43,
#   25,
#   21885,
#   10,
#   18,
#   1688,
#   43,
#   1387,
#   10,
#   43,
#   864,
#   52,
#   5016,
#   31,
#   8,
#   11],
#  [26, 480, 6, 1, 1885, 106, 5, 1749],
#  [16, 816, 418, 9971, 119, 6, 24095, 1068],
#  [2, 3, 29, 88035],
#  [6, 30, 16975, 26, 4, 5570, 7, 88036, 1392],
#  [2, 12, 38, 7, 1, 477, 21, 1, 617, 617, 41917, 46708, 3, 17, 388, 946],
#  [117,
#   1,
#   498,
#   483,
#   20718,
#   2955,
#   6576,
#   1,
#   2643,
#   1357,
#   8994,
#   6744,
#   16976,
#   6,
#   4,
#   15502,
#   522,
#   7,
#   20719,
#   64442,
#   6,
#   1,
#   917,
#   88037,
#   13753,
#   64443],
#  [8,
#   1467,
#   4,
#   1281,
#   5,
#   4,
#   238,
#   6,
#   5463,
#   17,
#   49,
#   4,
#   426,
#   7,
#   1553,
#   10,
#   8,
#   1220,
#   5,
#   1437,
#   38,
#   7,
#   17,
#   52,
#   8,
#   48,
#   41,
#   77,
#   129,
#   25,
#   286,
#   5,
#   281,
#   1,
#   1281,
#   8,
#   2097],
#  [9, 3, 139, 1908, 130, 27, 21286, 137, 57],
#  [3, 39, 4, 79, 8, 15, 91, 78, 2, 233, 323, 152, 868, 18, 500, 805, 13, 195],
#  [9, 15, 8, 1642, 29, 3665, 8418, 5, 4, 440, 2535],
#  [26,
#   453,
#   123,
#   2778,
#   863,
#   13,
#   373,
#   7937,
#   1104,
#   829,
#   5,
#   5035,
#   6,
#   3164,
#   21,
#   1,
#   395,
#   10,
#   92,
#   10,
#   863,
#   13,
#   1,
#   1104,
#   1895,
#   7,
#   202,
#   5592,
#   6,
#   13949],
#  [16, 11, 37, 21, 607, 1074, 628, 375, 2665],
#  [2, 386, 4, 4944, 6465, 23, 29, 3047, 7232],
#  [11, 14, 129, 67, 1112, 3, 19, 72, 53, 13, 57],
#  [9, 72, 26, 17, 310, 187, 1272, 7, 22555, 6, 57],
#  [20, 722, 15, 24, 55, 225, 16, 206, 5108, 3021, 24, 55, 186, 225],
#  [16,
#   80,
#   8,
#   7586,
#   7,
#   1,
#   445,
#   7,
#   83,
#   4,
#   642,
#   43,
#   111,
#   1,
#   13574,
#   64,
#   66,
#   4268,
#   953,
#   59,
#   19],
#  [9, 68, 302, 225, 6, 94, 47, 190],
#  [9, 35, 14, 1045, 28, 609, 2659, 74, 20, 39, 49, 105, 355],
#  [11, 2229, 429, 1, 323, 218, 10, 5497, 483, 1, 4214],
#  [9, 68, 4641, 18357, 15, 8, 24, 23, 56, 1513, 1455],
#  [16, 101, 223, 24, 4, 914, 3712, 211, 42, 2269, 1366],
#  [16, 11, 8, 129, 33, 16977, 136, 4, 246, 19, 2919, 108, 114, 943],
#  [2, 12, 28, 186, 1114, 7, 7735, 532, 22, 497],
#  [6,
#   594,
#   7,
#   2348,
#   644,
#   7,
#   329,
#   2,
#   419,
#   7,
#   202,
#   1124,
#   2850,
#   4,
#   9484,
#   10808,
#   7282,
#   26,
#   1,
#   634,
#   88038,
#   1453,
#   60,
#   7322,
#   1117,
#   5],
#  [2, 12, 1, 9562, 88039, 6, 4024, 408],
#  [2, 3, 1, 10225, 433, 7, 16978],
#  [2, 35, 1, 94, 25, 42, 20, 37, 2968, 447, 45, 1, 3493, 7, 55, 1535],
#  [9, 15, 37, 179, 23, 1889],
#  [12, 51, 7233, 13, 860, 439, 235, 6930],
#  [16, 11, 38, 124, 1106, 5, 869, 4, 53561],
#  [12, 5319, 4922, 431, 65, 1256],
#  [9, 11, 8, 63, 22, 1348, 1737, 59, 22556, 18, 367, 2797, 5, 2161],
#  [9, 11, 8, 1947, 997, 2135, 13, 821],
#  [2,
#   320,
#   7,
#   515,
#   15,
#   25,
#   1,
#   102,
#   746,
#   13,
#   4,
#   98,
#   2543,
#   5,
#   449,
#   6,
#   410,
#   13,
#   4,
#   599,
#   7,
#   56,
#   464],
#  [48,
#   1187,
#   1297,
#   1,
#   37,
#   1,
#   3248,
#   637,
#   1,
#   1293,
#   158,
#   7,
#   87,
#   4353,
#   744,
#   5497,
#   205,
#   36,
#   1767,
#   10,
#   1,
#   323],
#  [2, 3, 1, 246, 69, 1871, 18767, 10, 46709],
#  [2, 5749, 31, 25, 670, 5, 803, 7487],
#  [9, 14, 15, 156, 19, 17, 3, 4411, 7, 70, 22, 161, 48, 14, 24, 50, 1001],
#  [9,
#   11,
#   8,
#   1109,
#   18,
#   288,
#   794,
#   5,
#   35615,
#   95,
#   1462,
#   239,
#   32,
#   18,
#   1159,
#   3,
#   43,
#   16643,
#   82],
#  [26, 428, 4104, 6, 436, 1080, 111, 4, 240, 36, 4, 871],
#  [15, 8, 12250, 18, 7736, 1756, 21, 3098],
#  [30, 415, 4970, 44, 53562, 163, 12, 1, 3882, 5, 84, 44, 136, 1, 1026],
#  [16,
#   11,
#   200,
#   37,
#   226,
#   54,
#   5,
#   35616,
#   13,
#   18,
#   3564,
#   5109,
#   4227,
#   6894,
#   32,
#   18,
#   266,
#   3701,
#   10,
#   1492,
#   13,
#   1,
#   1480,
#   149,
#   1,
#   496,
#   229,
#   248,
#   19,
#   63,
#   87,
#   1,
#   6520,
#   13,
#   2667,
#   18,
#   266,
#   3701,
#   13,
#   1,
#   814,
#   5,
#   186,
#   3215],
#  [2, 1245, 2366, 29850, 5, 250, 1, 162, 9, 88040, 10395, 48, 4, 9058],
#  [11, 51, 33, 88041, 1094, 111, 59, 3557, 1356, 432, 6, 2483],
#  [52,
#   50,
#   245,
#   6,
#   11356,
#   61,
#   8,
#   15,
#   633,
#   18,
#   242,
#   172,
#   269,
#   5,
#   18,
#   88042,
#   6,
#   112,
#   1863,
#   43,
#   870,
#   273,
#   4262,
#   50,
#   1750,
#   51,
#   41,
#   96,
#   349,
#   1843,
#   17],
#  [2, 3, 17, 42, 5, 1764, 14600, 29851, 64444],
#  [2, 49, 1, 60, 11468, 599, 6, 1, 301, 7, 1, 9882],
#  [16, 48, 1896, 33, 1, 190, 7150],
#  [11,
#   14,
#   24,
#   5,
#   76,
#   4,
#   911,
#   1248,
#   7,
#   4537,
#   5,
#   4606,
#   17,
#   36,
#   4,
#   179,
#   5036,
#   10,
#   33,
#   5679],
#  [9, 15, 8, 63, 145, 178, 21, 18, 520, 507],
#  [2, 3, 1, 2638, 13, 716, 1899, 924, 5, 929, 3476, 7, 24096, 11245],
#  [16, 3, 17, 288, 13, 922, 5, 707, 47, 155, 186],
#  [2980,
#   10,
#   64445,
#   37,
#   16,
#   12,
#   14,
#   545,
#   52,
#   981,
#   3427,
#   210,
#   45,
#   1,
#   7362,
#   12,
#   43,
#   4,
#   283,
#   379,
#   295,
#   40,
#   4847,
#   20,
#   64446,
#   3,
#   5359,
#   1949,
#   22,
#   43,
#   43,
#   4,
#   283,
#   379],
#  [2, 3, 1, 34, 1948, 13, 5477, 2744],
#  [2, 12, 1, 873, 6190, 136, 1, 2891, 17309, 6, 1, 278],
#  [9, 26, 1, 53563, 663, 2085, 377, 1, 5498, 4574, 17],
#  [2, 3, 1, 1104, 2362, 6, 1246, 209, 7488],
#  [23,
#   2,
#   1935,
#   26,
#   23273,
#   2103,
#   12409,
#   5,
#   29852,
#   219,
#   2,
#   12,
#   38,
#   5340,
#   40,
#   272,
#   12409,
#   44,
#   23273],
#  [9, 48, 8232, 31436, 63, 90, 128],
#  [3, 17, 654, 5, 76, 64447, 144, 4, 798, 6, 12583, 1228],
#  [15, 57, 159, 4, 2547, 3286, 42, 15763, 20720, 21886, 6, 251],
#  [11, 14, 67, 192, 37, 40, 300, 55, 186, 4575, 12, 88043, 22, 88044],
#  [18, 900, 248, 42, 54, 164, 9, 11, 8, 33, 136, 62],
#  [9, 11, 12741, 88045, 33, 1682, 4971],
#  [32,
#   9198,
#   35617,
#   49,
#   13058,
#   12099,
#   90,
#   9059,
#   124,
#   14823,
#   88046,
#   14,
#   786,
#   120,
#   5,
#   11,
#   19,
#   96,
#   727,
#   4,
#   3994,
#   3468,
#   3,
#   62,
#   4,
#   10226,
#   5,
#   16,
#   235,
#   2300,
#   11,
#   43,
#   24,
#   14601],
#  [2, 3, 1, 958, 70, 1759, 13, 4, 874, 7, 799, 5, 25, 319, 5593],
#  [2, 3, 1, 471, 7, 29, 26001],
#  [16, 31, 8, 24, 4, 385, 259, 6, 606, 1767],
#  [9,
#   11,
#   868,
#   42,
#   88047,
#   84,
#   9,
#   11,
#   46,
#   24,
#   1094,
#   5,
#   2029,
#   10,
#   88048,
#   7,
#   658,
#   27,
#   130,
#   868,
#   5,
#   1117],
#  [3, 39, 4, 369, 19, 2536, 200, 37, 660, 55, 628, 192],
#  [9,
#   31,
#   8,
#   187,
#   1449,
#   5,
#   33,
#   11469,
#   347,
#   6,
#   629,
#   1600,
#   20,
#   8,
#   7323,
#   3391,
#   50,
#   4588,
#   671,
#   4006],
#  [3, 3059, 243, 2129, 47, 302, 1018, 7, 8419],
#  [9, 3, 4263, 12251, 7045, 1353],
#  [2,
#   35,
#   14,
#   11,
#   20,
#   1187,
#   11465,
#   7002,
#   11974,
#   10,
#   453,
#   123,
#   11470,
#   23,
#   28,
#   2203,
#   10,
#   491,
#   46,
#   35,
#   449,
#   21,
#   14,
#   13,
#   127,
#   103],
#  [16, 11, 220, 503, 6644, 10, 23274, 1855, 3841, 91, 17, 603, 5, 91, 88049],
#  [9, 1, 2597, 41, 88050, 19195, 9883, 209, 95, 368, 191, 10, 4660, 1, 9884],
#  [31, 2184, 4331, 25, 119, 5, 1103, 1, 7489, 7, 1, 4467, 7, 401, 972],
#  [58, 39, 89, 113, 29, 8305, 19685, 218],
#  [2, 12, 28, 1522, 10, 2, 12, 14, 208, 5, 63, 87, 4, 1198],
#  [9,
#   68,
#   623,
#   15,
#   25,
#   172,
#   27,
#   1,
#   2464,
#   7,
#   1,
#   399,
#   977,
#   6,
#   30,
#   66,
#   12584,
#   12,
#   234,
#   765],
#  [20, 51, 764, 27, 1, 3451, 7, 11471, 41, 39, 25, 65, 11471, 22, 105, 11471],
#  [61, 15, 8, 91, 171, 644, 1444, 22557, 13, 4, 6895],
#  [2, 29853, 292, 58, 4, 710, 2412, 31437, 7119, 23, 1, 292],
#  [2, 3, 29, 398, 1968, 6, 1894],
#  [2, 12, 1, 217, 1874, 459, 5, 182, 4, 12585, 1725, 346],
#  [16,
#   3,
#   39,
#   2505,
#   27,
#   2670,
#   6,
#   17649,
#   10809,
#   1280,
#   5,
#   8854,
#   322,
#   17,
#   58,
#   1178,
#   5,
#   16979,
#   524,
#   5,
#   8183,
#   10,
#   15053,
#   10,
#   15,
#   2226,
#   65,
#   5,
#   38353,
#   876,
#   11,
#   37,
#   7,
#   410,
#   786,
#   42,
#   88051,
#   11472],
#  [2, 3, 17, 42, 5, 25, 4, 448, 8855, 6, 714],
#  [2, 3, 64448, 13059, 4, 5202, 98, 3, 869, 5, 4, 2657, 98],
#  [16,
#   11,
#   368,
#   1027,
#   19,
#   15272,
#   88,
#   1120,
#   32,
#   46,
#   101,
#   146,
#   199,
#   42,
#   1120,
#   1120,
#   12,
#   864,
#   1689,
#   37],
#  [2, 3, 1, 541, 10, 2091, 301, 16, 1, 12, 13060],
#  [2, 12, 1, 842, 7, 3226, 709, 6, 140],
#  [16, 3, 105, 56, 769, 6, 2, 8, 24, 5, 156],
#  [26, 1003, 150, 465, 5110],
#  [3, 17, 109, 13, 4, 3002, 98, 5, 25, 12586, 11593, 131, 83, 16334, 43, 11593],
#  [3, 39, 29, 260, 78, 39, 19, 15, 2660, 327, 1672, 2216, 10, 4332, 253],
#  [117, 1, 34, 1082, 5, 416, 18, 634, 118, 44, 4, 1915, 419],
#  [11, 14, 67, 1, 4945, 40, 15054, 123, 13, 1, 41918, 3685, 3, 83, 1387],
#  [2, 3, 88052, 287],
#  [2, 11, 8, 11, 32, 18, 900, 10152, 73, 56, 1405, 154, 1816],
#  [2, 3, 1, 265, 18358],
#  [9, 15, 8, 63, 18, 1053, 114, 135, 3116, 1527],
#  [3, 17, 2422, 5, 106, 5, 1073, 134, 3, 19, 9, 3394, 91, 14],
#  [6, 62, 4424, 16, 816, 39, 50, 37, 40, 11, 43, 639, 774, 638],
#  [9, 217, 3, 7587, 6, 2063, 10906],
#  [3, 2721, 1540, 71, 318, 827],
#  [15, 4, 235, 25, 4, 29854, 21, 4, 130, 1038],
#  [9, 15, 8, 93, 4, 1124, 3404, 1019, 146, 59, 531, 1108, 44, 1165],
#  [2, 31, 8, 11, 357, 6, 318, 456, 20, 8, 2248, 6002, 21887, 2711, 981],
#  [30, 3, 1, 34, 266, 1635, 13, 3458, 6, 2911],
#  [41,
#   6332,
#   89,
#   2361,
#   6272,
#   6,
#   57,
#   26,
#   173,
#   81,
#   32,
#   3,
#   17,
#   191,
#   5,
#   25,
#   4831,
#   10,
#   44,
#   2,
#   614],
#  [41, 289, 25, 1998, 6, 17, 1481, 36, 368, 12],
#  [9, 15, 8, 226, 20, 118, 2060, 6577, 75],
#  [9, 11, 14, 63, 2799, 35618],
#  [16, 31, 51, 375, 27192],
#  [15, 14, 138, 1, 634, 221, 47, 1214, 4, 426, 7, 1082],
#  [9, 15, 8, 63, 4, 220, 171, 471, 6, 6243, 36, 4, 249, 407],
#  [2, 11, 14, 67, 1, 3882, 1140, 1082, 421, 964, 3, 10, 16],
#  [406,
#   1,
#   1118,
#   41919,
#   199,
#   44,
#   1,
#   178,
#   516,
#   1,
#   664,
#   7,
#   524,
#   210,
#   62,
#   3,
#   1,
#   64449,
#   8540,
#   38354,
#   7,
#   229,
#   445,
#   7,
#   1293,
#   11473,
#   16,
#   1,
#   104,
#   4623,
#   26,
#   43,
#   1000],
#  [3, 17, 698, 5, 303, 78, 265, 181, 6, 1010, 7, 28, 16039],
#  [9, 11, 14, 317, 1, 41920, 612],
#  [9, 11, 8, 730, 5, 11975, 11715, 657, 23, 4, 1573, 2283, 15055],
#  [9, 72, 3, 26, 17, 310, 13, 791, 1596, 6, 46710],
#  [9, 11, 51, 63, 374, 64450],
#  [61, 11, 1, 37, 44, 1, 1748, 397, 28, 2612, 32, 46, 33353, 17],
#  [2, 3, 28, 60, 12587, 13754, 498],
#  [59,
#   3213,
#   352,
#   878,
#   58,
#   43,
#   1454,
#   4,
#   440,
#   4302,
#   542,
#   41,
#   46,
#   93,
#   42,
#   4,
#   1573,
#   320,
#   168],
#  [2, 12, 1, 88053, 46711, 1179, 34, 363, 13],
#  [2, 26, 784, 13241, 5, 492, 935, 92, 45, 74],
#  [9,
#   17,
#   3,
#   109,
#   5,
#   2288,
#   52,
#   68,
#   315,
#   267,
#   42,
#   2677,
#   88054,
#   32,
#   6367,
#   26,
#   43,
#   795],
#  [2, 3, 13242, 7490],
#  [3,
#   17,
#   203,
#   19,
#   1,
#   37,
#   51,
#   143,
#   359,
#   2542,
#   339,
#   8480,
#   27,
#   3010,
#   22,
#   1294,
#   20,
#   52,
#   26,
#   19,
#   1028,
#   1609,
#   24,
#   38,
#   7538,
#   23,
#   367,
#   1054,
#   6,
#   1,
#   2196],
#  [9, 15, 8, 375, 13, 468, 6, 3112, 1916, 95, 50, 1283, 256],
#  [9, 68, 481, 41, 533, 6, 1, 14602, 6438, 8856, 6164],
#  [12, 1755, 124, 6, 450, 914, 21, 55, 814, 44, 737],
#  [2, 3, 1, 958, 347, 56, 31, 33, 13, 26002, 256, 5, 33, 4, 1266, 6, 423, 5423],
#  [2, 12, 1, 716, 2204, 7, 46712],
#  [30, 12, 1, 270, 550, 56, 15, 33, 27, 16644],
#  [2, 12, 1, 1638, 3325, 2956, 6, 594, 7, 213, 7, 7640],
#  [9, 35, 8, 702, 3310, 1168, 6, 62, 1228],
#  [1,
#   165,
#   22,
#   436,
#   1043,
#   15,
#   11,
#   4,
#   1753,
#   7,
#   84,
#   6,
#   807,
#   279,
#   9,
#   68,
#   15,
#   374,
#   165,
#   10,
#   704,
#   1043,
#   11,
#   17],
#  [2, 12, 38, 9796, 4699, 7, 258, 1, 1523, 22558, 7, 4084, 1449],
#  [44, 4, 140, 2268, 230, 37, 26003, 1511, 21, 290, 73, 9, 68, 31438, 13575],
#  [32, 41, 410, 174, 14381, 278],
#  [619,
#   543,
#   658,
#   1344,
#   23,
#   18,
#   261,
#   9,
#   5,
#   880,
#   65,
#   1180,
#   10,
#   2,
#   3,
#   1,
#   34,
#   412,
#   630,
#   5,
#   76],
#  [16, 11, 29855, 37, 84, 1701, 36, 53564, 4303, 10, 6439, 6, 3818, 1894],
#  [9, 15, 4, 228, 25, 4, 53, 228],
#  [35, 39, 25, 50, 1536, 5, 111, 160, 12410, 9415, 326, 7, 160, 285, 329, 803],
#  [2, 3, 1, 3188, 1526, 2292, 7837, 711, 89, 1182],
#  [3, 19196, 395, 608, 102, 71, 17650, 1460],
#  [2, 12, 1, 130, 3199, 13, 19686, 10, 4946, 1115],
#  [9, 48, 8, 935, 410, 1, 420, 7, 1372, 1211],
#  [2, 3, 28, 476, 184, 6, 74],
#  [9, 48, 1, 14142, 67, 7, 8744, 19197],
#  [3, 17, 2052, 5, 76, 406, 2417, 1063, 13, 29, 1646, 1653, 6, 147],
#  [2068,
#   4,
#   516,
#   6,
#   54,
#   30,
#   1816,
#   1293,
#   124,
#   64,
#   265,
#   516,
#   6,
#   54,
#   3,
#   43,
#   52,
#   11474,
#   7,
#   1293,
#   124,
#   30,
#   56,
#   31,
#   8,
#   516,
#   21],
#  [2, 15, 8, 11, 45, 18, 64451],
#  [49, 1093, 2270, 4, 13752, 270],
#  [9, 15, 8, 416, 18, 1477, 2202, 21, 771, 5133],
#  [2, 49, 28, 650, 2192, 393],
#  [16,
#   2968,
#   22559,
#   397,
#   82,
#   4,
#   102,
#   568,
#   216,
#   4063,
#   154,
#   49,
#   297,
#   5,
#   24,
#   1,
#   287,
#   5,
#   339,
#   1711,
#   1,
#   486,
#   2572],
#  [9, 15, 8, 63, 18, 494, 24, 169, 21, 54],
#  [2, 3, 18, 10153, 7191, 1335, 5, 54],
#  [16, 12, 1095, 908, 65, 5607, 45, 1095, 4383, 71, 55, 997, 6972],
#  [9, 11, 8, 33, 10810, 84, 44, 134],
#  [2, 12, 38, 53, 4046, 45, 9124, 22560],
#  [9, 11, 8, 2011, 1, 2217, 1366, 100, 257, 9199, 32, 51, 2217, 1366, 95, 535],
#  [16, 35, 104, 24, 54, 1927, 18, 2498, 23, 10311, 37],
#  [4,
#   2371,
#   58,
#   113,
#   14143,
#   196,
#   285,
#   13400,
#   64,
#   2021,
#   1,
#   1553,
#   3,
#   17,
#   109,
#   5,
#   1665,
#   424,
#   1553],
#  [16, 12, 22561, 13950, 10595, 217],
#  [9, 49, 1, 246, 69, 11594, 8679, 10, 18359, 7737, 27193],
#  [31, 8, 182, 4, 21888, 5, 546, 78, 4, 3085, 16980, 44, 4, 5397],
#  [9, 11, 9563, 33, 271, 1, 7983],
#  [9, 48, 24097, 23275, 121, 2793],
#  [9, 15, 8, 1109, 4947, 5, 198, 4199],
#  [9, 11, 37, 22562, 69, 55, 609, 1400, 741, 10, 233, 323],
#  [30, 3, 102, 1982, 22, 1485, 1916],
#  [9, 11, 8, 3517, 18, 6399, 23, 8184],
#  [9,
#   11,
#   8,
#   891,
#   4,
#   88055,
#   6,
#   820,
#   160,
#   21287,
#   32,
#   1,
#   211,
#   432,
#   3,
#   828,
#   5,
#   251,
#   432,
#   6,
#   370,
#   5,
#   831,
#   1152,
#   264,
#   252,
#   5060,
#   1611],
# ...
#  [2,
#   15,
#   8,
#   182,
#   5,
#   4948,
#   18,
#   5868,
#   13,
#   50,
#   4767,
#   46,
#   33356,
#   18,
#   346,
#   356,
#   10,
#   8,
#   96,
#   85,
#   5,
#   63,
#   1207],
#  [20, 39, 49, 4, 92, 2865, 1062, 2053, 356, 41, 453, 123, 129, 353],
#  [31, 8, 106, 5, 2830, 47, 1512, 22, 1389, 6104, 13, 29, 56, 605, 1101],
#  [12, 4440, 1318, 7, 576, 953, 7, 1093, 10, 18008, 23276],
#  [2, 3, 1, 1061, 463, 1438, 47, 4, 888, 2321, 69, 4, 10313],
#  [3,
#   776,
#   1201,
#   324,
#   7,
#   3002,
#   1115,
#   10,
#   20,
#   52,
#   15,
#   62,
#   986,
#   5,
#   65,
#   1416,
#   1621,
#   42,
#   64457],
#  [15, 21290, 25, 1928],
#  [3, 1762, 3247, 2585, 6746, 7, 1, 94],
#  [20, 14, 444, 78, 51, 88, 6, 839, 307, 6, 4, 227, 4832, 2, 35, 14, 11, 2353],
#  [2, 3, 1, 433, 8032, 15504, 924, 5, 1919, 685, 127, 4],
#  [16,
#   3,
#   19,
#   32,
#   4,
#   4522,
#   726,
#   7539,
#   47,
#   4,
#   313,
#   1530,
#   1572,
#   5,
#   99,
#   42,
#   264,
#   4,
#   6400],
#  [3, 39, 50, 79, 5, 1094, 1, 239, 1922, 899, 417, 7, 4, 257, 19, 3, 3574],
#  [4, 220, 1375, 98, 3, 191, 5, 533, 20, 14, 101, 150, 170, 35, 14, 150, 170],
#  [16, 12, 165, 6, 4990, 52, 2250],
#  [11,
#   46,
#   935,
#   14,
#   9,
#   5,
#   3728,
#   4,
#   88064,
#   22,
#   554,
#   6,
#   468,
#   22,
#   11,
#   46,
#   935,
#   14,
#   9,
#   5,
#   93,
#   856],
#  [3, 17, 203, 19, 1, 372, 2197, 140, 3, 220, 2354, 6, 193, 42, 6865],
#  [9, 26, 17, 99, 5, 14, 5, 24, 108, 3623],
#  [30, 223, 31, 8, 639, 13, 12414, 2338, 2500],
#  [20, 1, 218, 14604, 294, 41, 1456, 22, 966, 561, 65, 4728, 149, 1835],
#  [9, 15, 8, 199, 13, 75, 40, 15, 4642, 18, 187],
#  [2,
#   3,
#   29,
#   734,
#   128,
#   14605,
#   1204,
#   10,
#   9,
#   2016,
#   3,
#   17,
#   20,
#   8,
#   85,
#   5,
#   63,
#   3600,
#   22,
#   8995],
#  [30, 3, 1, 34, 2797, 411, 8, 31, 182, 6, 57],
#  [9, 15, 8, 6822, 1169, 27, 7234, 95, 83, 929, 22, 4717, 6, 325],
#  [9, 10314, 1225, 9201, 166, 593, 5, 13951, 457, 22, 171, 1100],
#  [11, 14, 420, 5377, 22, 169, 65],
#  [11, 116, 236, 42, 23277],
#  [2, 3, 64458, 3675, 88065, 10, 3, 1, 3675, 75, 27, 5978],
#  [3, 8234, 161],
#  [117,
#   1,
#   3227,
#   22,
#   162,
#   1843,
#   2462,
#   14,
#   60,
#   6,
#   594,
#   7,
#   35624,
#   10,
#   1,
#   340,
#   7,
#   17655,
#   4,
#   957,
#   6,
#   2370],
#  [77,
#   1110,
#   5,
#   232,
#   85,
#   1,
#   34,
#   158,
#   77,
#   2086,
#   1530,
#   1,
#   34,
#   30,
#   1080,
#   19,
#   2024,
#   77,
#   5018,
#   4,
#   313,
#   7006,
#   71,
#   54,
#   77,
#   8795,
#   139,
#   246,
#   2,
#   15,
#   8,
#   11,
#   45,
#   19],
#  [2, 12, 1, 34, 352, 13, 424, 136, 4286, 1, 60, 311, 13, 1, 768, 822, 3827],
#  [9,
#   133,
#   26,
#   17,
#   1150,
#   86,
#   13,
#   4,
#   107,
#   3616,
#   1036,
#   45,
#   4,
#   140,
#   5698,
#   5,
#   33,
#   4149,
#   13,
#   3869],
#  [3, 39, 4, 79, 5, 63, 74, 65, 7641, 146, 20, 14, 12, 271, 161, 37],
#  [11,
#   46,
#   890,
#   241,
#   72,
#   70,
#   1214,
#   2525,
#   10,
#   975,
#   372,
#   585,
#   326,
#   7,
#   428,
#   324,
#   6,
#   65,
#   3321,
#   1400],
#  [2, 3, 1, 269, 2236, 42, 6, 4, 46717, 15764],
#  [97, 1, 1885, 9342, 5267, 9485],
#  [9, 3, 1, 759, 442, 6, 227, 189, 44, 18009, 163],
#  [30, 3637, 7, 227, 189, 12, 1457, 23, 5771],
#  [2, 12, 1, 11596, 1195, 7, 4625, 1403],
#  [2, 3, 29, 635, 7, 4, 35625, 4798],
#  [9, 1356, 88066, 208, 7151, 41, 166, 92, 1933],
#  [3,
#   17,
#   388,
#   17,
#   5,
#   187,
#   16336,
#   338,
#   6,
#   8141,
#   12,
#   5774,
#   10,
#   73,
#   799,
#   19,
#   457,
#   36,
#   17,
#   3,
#   491],
#  [11,
#   14,
#   89,
#   250,
#   2464,
#   5,
#   28,
#   251,
#   384,
#   2,
#   282,
#   7,
#   430,
#   10,
#   369,
#   35,
#   14,
#   42,
#   5,
#   250,
#   2464,
#   5,
#   28,
#   251,
#   384],
#  [9, 26, 1, 17311, 1191, 46718],
#  [2, 12, 38, 1028, 137, 1037],
#  [16, 43, 501, 28, 186, 331, 5, 749, 17, 5, 2845],
#  [2, 3, 1, 34, 280, 59, 680, 1044],
#  [16, 26, 18, 560, 11011, 23, 18, 413, 32, 2478, 4371],
#  [9, 15, 88067, 150, 32, 14, 607, 81, 2, 472],
#  [2, 3, 1, 1020, 6, 2291, 23, 389, 826, 516, 7, 1373],
#  [12,
#   2613,
#   7364,
#   1457,
#   32,
#   8,
#   76,
#   73,
#   9061,
#   2613,
#   6,
#   12589,
#   8483,
#   5284,
#   20,
#   52,
#   2,
#   3198,
#   2613,
#   7047,
#   306,
#   21,
#   88068,
#   4607],
#  [30, 320, 7, 3422, 924, 11, 2487, 88069, 5134, 26, 88070, 16042, 8600, 5],
#  [16,
#   11,
#   1426,
#   4590,
#   335,
#   2224,
#   129,
#   33357,
#   10,
#   16647,
#   55,
#   26007,
#   11471,
#   27,
#   258],
#  [15, 75, 63, 2215, 273, 3834, 95, 4, 385, 259],
#  [9, 15, 8, 375, 13, 269, 10, 8796, 369, 110],
#  [26, 717, 1349, 1372, 7, 1211],
#  [78,
#   7,
#   66,
#   1,
#   3003,
#   40,
#   6273,
#   637,
#   1,
#   568,
#   216,
#   9885,
#   16,
#   3,
#   17,
#   111,
#   9418,
#   40,
#   651,
#   5,
#   67,
#   395,
#   3003,
#   8185,
#   87,
#   194],
#  [3,
#   39,
#   50,
#   3983,
#   197,
#   22,
#   6,
#   655,
#   69,
#   1,
#   15765,
#   7,
#   4,
#   1514,
#   2622,
#   10,
#   4851,
#   658,
#   7,
#   2120,
#   6,
#   73,
#   623,
#   108,
#   2162,
#   63,
#   127,
#   6823,
#   108,
#   6823,
#   63,
#   127,
#   23278,
#   22,
#   127,
#   6823,
#   10,
#   127,
#   88071,
#   63,
#   127,
#   6274,
#   10,
#   52,
#   8235],
#  [16, 31, 8, 106, 21, 16648, 260, 326, 7, 4025],
#  [2, 26, 17, 115, 32, 28, 900, 8236, 44, 14, 44, 4106, 66, 1, 70],
#  [16, 26, 50, 3597, 43, 1798, 1395, 7, 1, 5979, 2129],
#  [11, 4591, 188, 69, 38356, 10, 31441, 4400],
#  [2, 3, 1, 301, 7, 438],
#  [30, 137, 58, 105, 605],
#  [40, 3, 1, 773, 7, 556, 1273, 10699],
#  [11, 14, 748, 16982, 22, 1089, 1753],
#  [9, 11, 14, 63, 4, 3052, 1248, 7, 4, 38357, 19198],
#  [6, 28, 642, 3258, 3, 39, 50, 2544, 2573, 22, 15505, 22, 20187],
#  [3, 39, 50, 249, 5, 3713, 198, 5, 857],
#  [2, 3, 1, 522, 7, 16043, 3012, 6, 269, 8797],
#  [48, 2905, 5035, 6, 4643, 169],
#  [2, 3, 1, 531, 471, 7, 4644, 1761],
#  [20, 200, 1756, 58, 1423, 11, 192, 3232, 24, 734, 1423],
#  [16,
#   11,
#   37,
#   2626,
#   2465,
#   118,
#   4,
#   123,
#   5611,
#   96,
#   158,
#   8,
#   702,
#   177,
#   100,
#   446,
#   9343,
#   10,
#   8,
#   234,
#   1168,
#   64459,
#   32,
#   46,
#   756,
#   5061,
#   45,
#   170],
#  [8, 99, 19, 118, 4, 774, 98, 10, 8, 101, 81, 9, 5, 33, 18, 135, 384, 164],
#  [61, 15, 8, 684, 12253, 27195],
#  [16,
#   26,
#   18,
#   20188,
#   33358,
#   10,
#   46719,
#   294,
#   13,
#   480,
#   1676,
#   13,
#   54,
#   2024,
#   46,
#   813,
#   266,
#   10,
#   253,
#   546,
#   5,
#   1618,
#   170,
#   22,
#   1598,
#   170,
#   82],
#  [9, 11, 8, 250, 29, 9566, 5, 1, 5399],
#  [30, 3, 34, 142, 498, 89, 942, 6, 198],
#  [9, 68, 243, 3146, 37, 12, 307, 6, 1727],
#  [88, 39, 50, 7540, 131, 14, 88, 365, 28, 122, 498],
#  [9, 15, 8, 4923, 660, 222, 1711, 29, 6218, 2931],
#  [9, 574, 3, 16983, 4426, 9567, 13, 13577, 8548],
#  [2, 3, 53568, 33359, 34, 363, 13],
#  [8,
#   921,
#   4,
#   426,
#   64,
#   32,
#   118,
#   6,
#   4,
#   1554,
#   6,
#   1010,
#   7,
#   29,
#   9062,
#   8,
#   1698,
#   66,
#   18,
#   536,
#   10,
#   8,
#   101,
#   81,
#   2,
#   5,
#   11,
#   357,
#   16,
#   3,
#   62,
#   1930],
#  [11, 2814, 132, 67, 144, 978, 3077, 4331],
#  [16, 11, 51, 42, 10, 1941, 145],
#  [32, 41, 51, 504, 78, 7, 1779],
#  [16,
#   11,
#   289,
#   156,
#   1381,
#   12,
#   4274,
#   55,
#   352,
#   32,
#   36,
#   703,
#   36,
#   549,
#   7,
#   289,
#   1218,
#   4,
#   1033,
#   22,
#   50,
#   73,
#   738,
#   315],
#  [9, 11, 8, 81, 19, 4, 771, 1816, 14, 146, 32, 77, 3164, 45, 83, 822, 21, 14],
#  [117, 1, 34, 79, 5, 33, 4782],
#  [2, 3, 1, 1118, 69, 11247, 88072, 225, 1894, 10, 11247, 714],
#  [9, 14, 41, 447, 28, 642, 32, 154, 3, 43, 306],
#  [2,
#   3,
#   1,
#   122,
#   184,
#   19,
#   825,
#   5,
#   28,
#   486,
#   32,
#   75,
#   640,
#   14,
#   5,
#   207,
#   24,
#   4,
#   1031,
#   21,
#   87],
#  [20, 14, 126, 4, 724, 5, 179, 4, 1751, 292, 30, 56, 35, 17, 25],
#  [16,
#   11,
#   289,
#   76,
#   1,
#   439,
#   982,
#   202,
#   5,
#   2172,
#   4,
#   200,
#   98,
#   43,
#   66,
#   3003,
#   12,
#   200,
#   395,
#   3003,
#   10,
#   43,
#   66,
#   2132,
#   1145,
#   27,
#   922,
#   23279,
#   22563,
#   417,
#   17,
#   3,
#   8237,
#   96,
#   156,
#   46,
#   12,
#   200,
#   22,
#   192,
#   37],
#  [15, 8, 33, 5285, 47, 41926, 4, 1498, 65, 71, 316, 237, 605],
#  [2, 26, 1, 839, 19, 192, 37, 12, 65, 4412, 952, 71, 200, 37, 115],
#  [9, 11, 8, 3517, 18, 7541, 32, 8, 24, 5, 3144, 86, 88073, 5594],
#  [3, 39, 4, 2401, 7, 12744, 7365, 256, 13, 148, 575, 6, 176],
#  [2, 10397, 305, 15, 56, 708, 27, 15506, 215, 127, 15057, 317],
#  [2, 3, 1, 60, 6671, 110, 6, 1, 94],
#  [15,
#   171,
#   5806,
#   6,
#   57,
#   151,
#   7738,
#   5,
#   1,
#   1523,
#   218,
#   13,
#   635,
#   1,
#   4369,
#   12100,
#   15058,
#   1,
#   1480,
#   5,
#   11,
#   194],
#  [2, 26, 17, 115, 20, 8, 97, 281, 6, 18, 742],
#  [8,
#   3385,
#   3022,
#   44,
#   1003,
#   8,
#   15,
#   6003,
#   504,
#   56,
#   5699,
#   66,
#   1,
#   79,
#   196,
#   2,
#   1003,
#   442,
#   31,
#   8,
#   11,
#   5,
#   33,
#   102,
#   44,
#   1003,
#   705],
#  [2, 3, 1, 12745, 3153, 6, 3341, 34, 363, 13],
#  [9, 11, 14, 1622, 5, 75, 1983, 14, 5171, 113, 3099, 6, 1, 528],
#  [18, 34, 238, 272, 4, 8238, 1729, 220, 524, 5, 2027, 31, 8, 25, 2861],
#  [9, 11, 8, 2217, 1, 296, 7, 4, 200, 404, 228, 32, 2068, 3197, 3638],
#  [2, 103, 49, 1473, 2585, 5111, 4831],
#  [2, 3, 4, 1118, 82, 526, 9, 11, 14, 1642, 21, 87],
#  [30,
#   12,
#   1,
#   14825,
#   2800,
#   643,
#   13,
#   4,
#   503,
#   762,
#   384,
#   3869,
#   61,
#   15,
#   8,
#   91,
#   195,
#   1051,
#   5,
#   150,
#   6,
#   62,
#   5827],
#  [9, 133, 15, 14, 449, 6, 308, 144, 343, 4, 88074, 88075],
#  [2, 3, 4355, 37, 6, 714, 27, 258, 198, 6, 176],
#  [9, 26, 4, 653, 2496, 99, 131, 175, 169, 21, 4, 4799, 114, 135, 228],
#  [2, 12, 1, 53569, 459, 13, 354, 4753, 6, 1095, 2588],
#  [2,
#   3,
#   4,
#   53,
#   3096,
#   79,
#   5,
#   33,
#   674,
#   7,
#   4,
#   3558,
#   1377,
#   1901,
#   6219,
#   43,
#   4,
#   10315,
#   6219,
#   5080,
#   194,
#   2087],
#  [3, 17, 203, 19, 39, 3, 4, 4024, 570, 23, 19199, 6, 1, 92],
#  [9, 48, 3377, 29860, 583, 90, 60, 2746, 1019, 6368, 44, 1, 66, 676, 362],
#  [2, 35, 14, 85, 6, 29, 361, 6, 265, 626],
#  [9, 11, 8, 11357, 75, 45, 18, 781, 435],
#  [2, 320, 7, 845, 3, 286, 5, 25, 1871, 503, 6, 4, 1180, 1041],
#  [2, 12, 38, 53, 223, 22, 1063, 5, 138, 45, 9568, 1916],
#  [101, 14, 67, 19, 8747, 31, 25, 314, 11716, 10, 65, 1219, 10, 312, 53570],
#  [2, 3, 1, 1686, 20, 50, 7, 9202, 23280, 766, 829, 6, 13756],
#  [2, 12, 1, 11476, 6, 3233, 16044, 946, 415],
#  [26, 4305, 26008, 38358, 24, 53, 12585, 420],
#  [3, 2034, 4, 7840, 7, 57],
#  [6, 4452, 11, 37, 2193, 290, 73, 409, 23, 2, 22564, 46, 179, 6],
#  [16, 3, 21891, 64460, 3, 254],
#  [3,
#   1,
#   376,
#   16,
#   2601,
#   1242,
#   2377,
#   2981,
#   4,
#   102,
#   363,
#   1952,
#   71,
#   8033,
#   9344,
#   3,
#   158,
#   77,
#   3,
#   4,
#   8361],
#  [2, 3, 1619, 479, 10, 9, 15, 56, 93, 4, 1619, 2355],
#  [26,
#   1,
#   278,
#   300,
#   512,
#   158,
#   46,
#   4729,
#   1,
#   3545,
#   22,
#   158,
#   512,
#   6488,
#   1,
#   1380,
#   36,
#   29,
#   398,
#   2619,
#   27,
#   27196],
#  [2, 3, 1263, 47, 3518],
#  [2, 3, 1, 885, 7, 4, 474, 64461, 23281],
#  [9,
#   15,
#   8,
#   174,
#   83,
#   6046,
#   66,
#   7,
#   1,
#   70,
#   8,
#   80,
#   646,
#   10,
#   1542,
#   25,
#   712,
#   7,
#   73,
#   124,
#   64,
#   8,
#   80,
#   1462,
#   18,
#   486,
#   2,
#   15,
#   8,
#   11],
#  [61, 49, 38359, 46720, 683],
#  [9, 11, 8, 121, 3870, 1916, 1984, 44, 242, 33, 2567],
#  [2, 3, 1, 34, 721, 317, 5, 4413, 69, 15507, 10, 53571],
#  [61, 15, 56, 33, 777, 5, 6441],
#  [2, 269, 12, 969, 5, 25, 936, 64, 339, 816],
#  [9, 72, 12, 1664, 315, 5980, 27, 1719, 2932, 9797, 777],
#  [14, 24, 807, 1310, 1555, 10, 230, 114, 5, 93, 4, 5376, 9, 35, 14, 11, 17],
#  [2, 12, 1, 14826, 14, 172, 6, 28, 74],
#  [30, 814, 7, 2470, 88, 5775, 6, 3179],
#  [8,
#   24,
#   2724,
#   7,
#   677,
#   10,
#   421,
#   324,
#   79,
#   5,
#   7542,
#   87,
#   167,
#   174,
#   9,
#   11,
#   8,
#   231,
#   191],
#  [9, 68, 235, 2325, 48, 35626, 573, 1452],
#  [30, 147, 41, 8, 33, 13, 24982, 347, 6, 318, 827, 20, 8, 85, 669],
#  [16, 51, 368, 12, 52, 1971, 45, 1, 454, 2233],
#  [322, 8, 80, 29, 2039, 12, 302, 17312, 459, 5, 501, 54],
#  [2, 15, 8, 11, 20, 8, 80, 175, 2114, 5807, 23, 2447, 21, 18, 956],
#  [9, 936, 12, 5654, 6521, 5151],
#  [2, 3, 1, 34, 79, 7, 1084],
#  [1988,
#   44,
#   3308,
#   20,
#   131,
#   6,
#   1,
#   340,
#   7,
#   1471,
#   14827,
#   23,
#   1,
#   5500,
#   6,
#   9127,
#   1384,
#   265,
#   273,
#   516,
#   38360,
#   2027,
#   36,
#   4,
#   7230,
#   166,
#   49,
#   2248,
#   39,
#   49,
#   4,
#   5946,
#   6,
#   18,
#   1989,
#   19,
#   41,
#   27197,
#   5,
#   66,
#   2054,
#   3714,
#   83,
#   670],
#  [8,
#   1488,
#   5378,
#   29,
#   3376,
#   451,
#   23,
#   1513,
#   214,
#   127,
#   158,
#   155,
#   363,
#   5,
#   33,
#   6244,
#   23,
#   1513,
#   704,
#   31,
#   8,
#   1956,
#   17,
#   508,
#   5,
#   1,
#   1104,
#   15059,
#   11976],
#  [61, 15, 332, 1489, 1, 12254, 675, 88076, 568, 179, 2282, 1907, 1386, 4560],
#  [16, 11, 124, 85, 5, 869, 165, 6, 1785],
#  [9, 41, 14, 121, 28, 153],
#  [40, 3, 773, 7, 64462],
#  [2, 12, 1, 3166, 7, 6715, 1030],
#  [2, 31, 8, 81, 45, 1347, 24983, 6, 395, 586],
#  [16,
#   499,
#   1958,
#   27198,
#   743,
#   1,
#   663,
#   269,
#   709,
#   613,
#   5,
#   25,
#   2895,
#   6,
#   6105,
#   149,
#   112,
#   3854],
#  [2, 3, 1, 34, 2334, 13, 88077, 14828],
#  [88078, 10907, 1922, 106, 1135, 21, 1320, 3871, 1922],
#  [32, 3, 1, 3488, 7, 3590],
#  [12, 14, 4, 1074, 98],
#  [2, 3, 1, 383, 510, 7, 1, 13757, 3899, 7, 57],
#  [2, 3, 1, 34, 79, 5, 91, 4, 187, 482, 13, 2296, 256],
#  [51,
#   36,
#   4,
#   266,
#   24,
#   113,
#   6,
#   1936,
#   7,
#   45,
#   1813,
#   846,
#   1555,
#   508,
#   5,
#   4,
#   140,
#   3771,
#   8,
#   99,
#   42,
#   139,
#   883,
#   266,
#   58,
#   113,
#   10908,
#   21,
#   161,
#   4334,
#   9,
#   15,
#   8,
#   36,
#   4,
#   2210,
#   150,
#   18,
#   46721,
#   21,
#   766,
#   833,
#   11124],
#  [2, 5901, 150, 11125, 38361, 88079],
#  [11, 14, 42, 12746, 33360, 961],
#  [9, 15, 25, 65, 8484],
#  [2, 3, 1, 34, 79, 5, 4, 375, 13, 4, 110, 44, 28442, 3378, 168],
#  [15, 1612, 336, 1, 305],
#  [30, 137, 11, 14, 67, 41, 353, 1, 94, 1979, 62, 103],
#  [9, 15, 8, 250, 1, 3968, 7, 4, 1306],
#  [3, 17, 109, 5, 24, 29861, 6, 6931, 19, 816, 7235, 22, 8034],
#  [117, 1, 1232, 7, 16337, 6106, 10, 53572, 88080, 246],
#  [9, 133, 41, 17, 86, 5, 182, 4, 273],
#  [8,
#   186,
#   4,
#   369,
#   168,
#   17,
#   58,
#   232,
#   113,
#   18,
#   742,
#   5,
#   186,
#   4,
#   11597,
#   20,
#   8,
#   33,
#   4,
#   11597,
#   41,
#   18,
#   1275,
#   10909,
#   54,
#   20,
#   52,
#   16],
#  [8, 24, 18770, 18, 1426, 6, 134, 12, 39, 50, 1631, 7, 380, 8, 15, 660, 5],
#  [9, 4, 228, 15, 648, 23, 1526],
#  [3,
#   17,
#   109,
#   5,
#   1414,
#   4,
#   366,
#   249,
#   168,
#   21,
#   4,
#   835,
#   1391,
#   2198,
#   5612,
#   1499,
#   1936],
#  [30, 1058, 225, 7590, 3, 53, 13, 412],
#  [15,
#   129,
#   33,
#   100,
#   4,
#   7841,
#   148,
#   147,
#   42,
#   17656,
#   95,
#   428,
#   29,
#   46722,
#   18,
#   3053,
#   103],
#  [2, 15, 8, 33, 27, 62, 260],
#  [32, 48, 1, 9973, 1331, 27, 4, 230, 157, 5, 1053, 685, 2647],
#  [9486, 12, 1, 34, 110, 5501, 597, 5, 11, 59, 468, 1055],
#  [3, 201, 4, 161, 245, 13, 64463, 42, 54, 5, 179],
#  [9, 72, 70, 70, 41, 17, 86, 5, 340, 1, 1159, 53573, 6, 316, 16649],
#  [2, 12, 1, 13758, 7, 2349],
#  [11, 14, 42, 362, 427, 7739, 23, 8601],
#  [2, 12, 1, 1459, 13, 1, 3676, 1453, 755],
#  [20,
#   1,
#   2736,
#   3191,
#   1,
#   141,
#   621,
#   7,
#   70,
#   30,
#   46,
#   4439,
#   13,
#   55,
#   3248,
#   7,
#   722,
#   10,
#   717,
#   23,
#   1746,
#   4,
#   1508,
#   13,
#   1066,
#   9,
#   15060,
#   35,
#   1,
#   94,
#   25],
#  [16,
#   11,
#   4201,
#   651,
#   4140,
#   45,
#   52,
#   68,
#   13243,
#   216,
#   55,
#   137,
#   13,
#   635,
#   1,
#   380,
#   7,
#   911,
#   193,
#   7,
#   2289,
#   22,
#   4991,
#   55,
#   137,
#   21,
#   26009,
#   7048],
#  [20,
#   14,
#   88,
#   5,
#   1202,
#   3900,
#   23,
#   1,
#   1643,
#   26,
#   17,
#   63,
#   1,
#   1643,
#   1075,
#   22,
#   1,
#   3900,
#   2996],
#  [11, 14, 67, 19, 14, 24, 4, 1869, 20722, 94, 870, 28, 788, 61, 552, 3, 1074],
#  [11, 14, 81, 64464, 13, 4495],
#  [2, 49, 28, 122, 763, 6, 3310, 799],
#  [31, 8, 378, 16645, 57, 926, 575, 143, 36, 1, 168, 3, 43, 208, 53],
#  [2, 3, 4, 738, 2620, 752],
#  [16, 26, 1, 239, 6004, 1001, 556, 1443, 2076, 10, 873, 284],
#  [11, 14, 67, 602, 6166, 3, 761, 4, 434],
#  [3, 17, 478, 10, 955, 5, 3154, 8996, 335, 6, 278],
#  [2, 320, 7, 4898, 11, 8, 506, 13, 8186, 1537],
#  [32, 11, 8602, 1791],
#  [15, 29, 2880, 430, 1, 5341, 7, 55, 223],
#  [2, 26, 17, 115, 32, 4, 181, 627, 18771, 3155, 131, 2822],
#  [9, 11, 8, 159, 551, 7, 305, 645, 4608],
#  [61, 3, 1, 34, 245, 5, 375, 13, 5526],
#  [16, 53574, 3, 1871, 8308, 600],
#  [16, 3, 999, 431, 5081, 1662, 6, 57],
#  [9,
#   11,
#   8,
#   33,
#   7491,
#   1737,
#   23,
#   2161,
#   4345,
#   1168,
#   260,
#   32,
#   8,
#   80,
#   2069,
#   5,
#   2739],
#  [9, 15, 14, 430, 4, 556, 227, 5, 24, 4, 8798, 199],
#  [16, 11, 1, 5286, 15273],
#  [143,
#   19,
#   877,
#   3,
#   105,
#   1077,
#   6,
#   754,
#   15,
#   14,
#   2466,
#   2339,
#   77,
#   234,
#   339,
#   1145,
#   13,
#   66,
#   7,
#   28,
#   1411],
#  [16, 262, 4019, 10, 22565, 12, 800, 114, 5808, 610, 5, 73, 1047, 193],
#  [2, 12, 1, 16338, 7, 468, 59, 4103, 6, 57],
#  [3, 17, 1139, 13, 4, 313, 5, 24, 4, 1128, 185, 2574, 88081, 696, 3977],
#  [20,
#   8,
#   85,
#   5,
#   91,
#   4,
#   926,
#   64465,
#   7,
#   4,
#   657,
#   21,
#   4,
#   11007,
#   1757,
#   160,
#   1,
#   2416,
#   420,
#   5112,
#   9,
#   11,
#   8,
#   2495,
#   1,
#   8799,
#   7,
#   1,
#   1757,
#   36,
#   64466,
#   3686,
#   9,
#   11,
#   8,
#   88082,
#   1,
#   8799],
#  [15, 14, 25, 4, 541, 2301, 1885, 3043, 20, 14, 24, 7687],
#  [15, 8, 33, 1125, 147, 6, 1778, 13, 22566, 347, 6, 629],
#  [30, 137, 41, 1, 122, 5, 106, 425, 1246],
#  ...]

# %%
tok.index_word
# Out:
# {1: 'the',
#  2: 'what',
#  3: 'is',
#  4: 'a',
#  5: 'to',
#  6: 'in',
#  7: 'of',
#  8: 'i',
#  9: 'how',
#  10: 'and',
#  11: 'do',
#  12: 'are',
#  13: 'for',
#  14: 'you',
#  15: 'can',
#  16: 'why',
#  17: 'it',
#  18: 'my',
#  19: 'that',
#  20: 'if',
#  21: 'with',
#  22: 'or',
#  23: 'on',
#  24: 'have',
#  25: 'be',
#  26: 'does',
#  27: 'from',
#  28: 'your',
#  29: 'an',
#  30: 'which',
#  31: 'should',
#  32: 'when',
#  33: 'get',
#  34: 'best',
#  35: 'would',
#  36: 'as',
#  37: 'people',
#  38: 'some',
#  39: 'there',
#  40: 'who',
#  41: 'will',
#  42: 'like',
#  43: 'not',
#  44: 'at',
#  45: 'about',
#  46: 'they',
#  47: 'by',
#  48: 'did',
#  49: 'was',
#  50: 'any',
#  51: 'we',
#  52: 'so',
#  53: 'good',
#  54: 'me',
#  55: 'their',
#  56: 'one',
#  57: 'india',
#  58: 'has',
#  59: 'after',
#  60: 'most',
#  61: 'where',
#  62: 'this',
#  63: 'make',
#  64: 'but',
#  65: 'more',
#  66: 'all',
#  67: 'think',
#  68: 'many',
#  69: 'between',
#  70: 'time',
#  71: 'than',
#  72: 'much',
#  73: 'other',
#  74: 'life',
#  75: 'someone',
#  76: 'use',
#  77: 'he',
#  78: 'out',
#  79: 'way',
#  80: 'am',
#  81: 'know',
#  82: 'up',
#  83: 'being',
#  84: 'work',
#  85: 'want',
#  86: 'take',
#  87: 'them',
#  88: 'were',
#  89: 'ever',
#  90: 'his',
#  91: 'find',
#  92: 'us',
#  93: 'become',
#  94: 'world',
#  95: 'without',
#  96: 'just',
#  97: 'could',
#  98: 'person',
#  99: 'feel',
#  100: 'into',
#  101: "don't",
#  102: 'better',
#  103: 'year',
#  104: 'quora',
#  105: 'no',
#  106: 'go',
#  107: 'new',
#  108: '2',
#  109: 'possible',
#  110: 'job',
#  111: 'only',
#  112: 'her',
#  113: 'been',
#  114: 'years',
#  115: 'mean',
#  116: 'indian',
#  117: "what's",
#  118: "i'm",
#  119: 'used',
#  120: 'need',
#  121: 'start',
#  122: 'first',
#  123: 'trump',
#  124: 'women',
#  125: 'difference',
#  126: 'had',
#  127: '1',
#  128: 'money',
#  129: 'still',
#  130: 'different',
#  131: 'while',
#  132: 'really',
#  133: 'long',
#  134: 'school',
#  135: 'old',
#  136: 'over',
#  137: 'country',
#  138: 'learn',
#  139: 'our',
#  140: 'business',
#  141: 'same',
#  142: 'love',
#  143: 'now',
#  144: 'before',
#  145: 'things',
#  146: 'even',
#  147: 'college',
#  148: 'engineering',
#  149: 'during',
#  150: 'help',
#  151: 'give',
#  152: 'online',
#  153: 'day',
#  154: 'she',
#  155: 'its',
#  156: 'say',
#  157: '3',
#  158: 'because',
#  159: 'see',
#  160: 'using',
#  161: 'bad',
#  162: 'book',
#  163: 'university',
#  164: 'back',
#  165: 'men',
#  166: 'change',
#  167: 'then',
#  168: 'company',
#  169: 'sex',
#  170: 'him',
#  171: 'high',
#  172: 'made',
#  173: 'anyone',
#  174: 'stop',
#  175: 'having',
#  176: '2017',
#  177: 'getting',
#  178: 'right',
#  179: 'live',
#  180: 'student',
#  181: 'girl',
#  182: 'buy',
#  183: 'two',
#  184: 'thing',
#  185: '5',
#  186: 'own',
#  187: 'study',
#  188: 'happen',
#  189: 'science',
#  190: 'name',
#  191: 'going',
#  192: 'white',
#  193: 'countries',
#  194: 'something',
#  195: 'free',
#  196: 'through',
#  197: 'real',
#  198: 'english',
#  199: 'look',
#  200: 'black',
#  201: 'china',
#  202: 'american',
#  203: 'true',
#  204: 'experience',
#  205: 'such',
#  206: "can't",
#  207: 'come',
#  208: 'doing',
#  209: 'water',
#  210: 'questions',
#  211: 'system',
#  212: '2018',
#  213: 'number',
#  214: '10',
#  215: 'class',
#  216: 'against',
#  217: 'important',
#  218: 'government',
#  219: 'students',
#  220: 'very',
#  221: 'language',
#  222: 'off',
#  223: 'books',
#  224: 'ways',
#  225: 'state',
#  226: 'tell',
#  227: 'computer',
#  228: 'man',
#  229: 'war',
#  230: '4',
#  231: 'keep',
#  232: 'always',
#  233: 'social',
#  234: 'never',
#  235: 'human',
#  236: 'girls',
#  237: 'every',
#  238: 'friend',
#  239: 'data',
#  240: 'career',
#  241: 'too',
#  242: 'home',
#  243: 'chinese',
#  244: 'non',
#  245: 'place',
#  246: 'relationship',
#  247: 'under',
#  248: "doesn't",
#  249: 'software',
#  250: 'write',
#  251: 'future',
#  252: 'working',
#  253: 'friends',
#  254: 'done',
#  255: 'x',
#  256: 'exam',
#  257: 'phone',
#  258: 'learning',
#  259: 'account',
#  260: 'app',
#  261: 'website',
#  262: 'america',
#  263: 'guy',
#  264: "it's",
#  265: 'another',
#  266: 'family',
#  267: 's',
#  268: 'parents',
#  269: 'food',
#  270: 'top',
#  271: 'around',
#  272: 'got',
#  273: 'car',
#  274: 'age',
#  275: 'believe',
#  276: 'happens',
#  277: 'states',
#  278: 'usa',
#  279: 'days',
#  280: 'course',
#  281: 'read',
#  282: 'kind',
#  283: 'big',
#  284: 'wrong',
#  285: 'google',
#  286: 'able',
#  287: 'power',
#  288: 'hard',
#  289: 'americans',
#  290: 'each',
#  291: 'companies',
#  292: 'movie',
#  293: 'major',
#  294: 'down',
#  295: 'also',
#  296: 'body',
#  297: 'show',
#  298: 'makes',
#  299: 'b',
#  300: 'hate',
#  301: 'history',
#  302: 'muslims',
#  303: 'ask',
#  304: 'last',
#  305: 'question',
#  306: 'well',
#  307: 'living',
#  308: 'canada',
#  309: 'president',
#  310: 'cost',
#  311: 'pay',
#  312: 'less',
#  313: 'woman',
#  314: 'both',
#  315: 'degree',
#  316: 'normal',
#  317: 'test',
#  318: 'jee',
#  319: 'considered',
#  320: 'type',
#  321: 'create',
#  322: 'since',
#  323: 'media',
#  324: 'part',
#  325: 'god',
#  326: 'instead',
#  327: 'facebook',
#  328: 'end',
#  329: 'play',
#  330: 'examples',
#  331: 'child',
#  332: 'u',
#  333: 'prepare',
#  334: 'great',
#  335: 'children',
#  336: 'answer',
#  337: 'rank',
#  338: 'law',
#  339: 'actually',
#  340: 'process',
#  341: 'united',
#  342: 'common',
#  343: 'given',
#  344: 'anything',
#  345: 'market',
#  346: 'house',
#  347: 'marks',
#  348: 'choose',
#  349: 'eat',
#  350: 'tv',
#  351: 'myself',
#  352: 'jobs',
#  353: 'win',
#  354: 'medical',
#  355: 'music',
#  356: 'today',
#  357: 'next',
#  358: 'average',
#  359: 'call',
#  360: 'making',
#  361: 'earth',
#  362: 'game',
#  363: 'known',
#  364: 'cause',
#  365: 'writing',
#  366: 'small',
#  367: 'current',
#  368: 'indians',
#  369: 'service',
#  370: 'order',
#  371: 'score',
#  372: 'video',
#  373: 'north',
#  374: '6',
#  375: 'apply',
#  376: 'reason',
#  377: 'affect',
#  378: 'join',
#  379: 'deal',
#  380: 'support',
#  381: 'math',
#  382: 'e',
#  383: 'main',
#  384: 'self',
#  385: 'bank',
#  386: 'causes',
#  387: 'uk',
#  388: 'worth',
#  389: 'left',
#  390: 'called',
#  391: 'c',
#  392: 'form',
#  393: 'point',
#  394: 'these',
#  395: 'south',
#  396: 'tips',
#  397: 'put',
#  398: 'energy',
#  399: 'word',
#  400: 'technology',
#  401: 'public',
#  402: 'delhi',
#  403: 'face',
#  404: 'muslim',
#  405: 'months',
#  406: 'open',
#  407: 'engineer',
#  408: 'travel',
#  409: 'based',
#  410: 'pakistan',
#  411: 'card',
#  412: 'marketing',
#  413: 'hair',
#  414: 'others',
#  415: 'research',
#  416: 'improve',
#  417: 'etc',
#  418: 'light',
#  419: 'level',
#  420: 'value',
#  421: 'move',
#  422: 'management',
#  423: 'iit',
#  424: 'those',
#  425: 'full',
#  426: 'lot',
#  427: 'development',
#  428: 'taking',
#  429: 'control',
#  430: 'design',
#  431: 'times',
#  432: 'date',
#  433: 'meaning',
#  434: 'problem',
#  435: 'health',
#  436: '12',
#  437: 'series',
#  438: 'education',
#  439: 'term',
#  440: 'single',
#  441: 'safe',
#  442: 'program',
#  443: 'away',
#  444: 'found',
#  445: 'idea',
#  446: 'political',
#  447: 'care',
#  448: 'city',
#  449: 'stay',
#  450: 'general',
#  451: 'air',
#  452: 'weight',
#  453: 'donald',
#  454: 'international',
#  455: 'space',
#  456: 'physics',
#  457: 'low',
#  458: 'enough',
#  459: 'required',
#  460: 'android',
#  461: 'understand',
#  462: 'movies',
#  463: 'field',
#  464: 'month',
#  465: 'increase',
#  466: 'talk',
#  467: 'youtube',
#  468: 'mba',
#  469: "isn't",
#  470: 'popular',
#  471: 'salary',
#  472: 'happened',
#  473: 'build',
#  474: '7',
#  475: 'available',
#  476: 'favorite',
#  477: 'problems',
#  478: 'legal',
#  479: 'programming',
#  480: 'everyone',
#  481: 'humans',
#  482: 'group',
#  483: 'behind',
#  484: 'mobile',
#  485: 'often',
#  486: 'mind',
#  487: 'post',
#  488: 'again',
#  489: 'short',
#  490: 'military',
#  491: 'said',
#  492: 'death',
#  493: 'benefits',
#  494: 'dog',
#  495: 'looking',
#  496: 'civil',
#  497: 'female',
#  498: 'story',
#  499: "didn't",
#  500: 'boyfriend',
#  501: 'kill',
#  502: 'society',
#  503: 'successful',
#  504: 'run',
#  505: 'leave',
#  506: 'wear',
#  507: 'girlfriend',
#  508: 'due',
#  509: 'culture',
#  510: 'purpose',
#  511: '0',
#  512: 'russia',
#  513: 'europe',
#  514: 'mass',
#  515: 'visa',
#  516: 'side',
#  517: 'related',
#  518: 'web',
#  519: 'religion',
#  520: 'ex',
#  521: 'germany',
#  522: 'role',
#  523: 'per',
#  524: 'similar',
#  525: 'watch',
#  526: 'party',
#  527: 'information',
#  528: 'past',
#  529: 'kids',
#  530: 'admission',
#  531: 'starting',
#  532: 'male',
#  533: 'die',
#  534: 'mechanical',
#  535: 'internet',
#  536: 'skills',
#  537: 'speed',
#  538: 'else',
#  539: '100',
#  540: 'consider',
#  541: 'british',
#  542: 'product',
#  543: 'few',
#  544: 'force',
#  545: 'guys',
#  546: 'try',
#  547: 'tech',
#  548: 'training',
#  549: '8',
#  550: 'colleges',
#  551: 'answers',
#  552: 'everything',
#  553: 'studying',
#  554: 'industry',
#  555: 'opinion',
#  556: 'modern',
#  557: 'pain',
#  558: 'seen',
#  559: 'site',
#  560: 'cat',
#  561: 'lose',
#  562: 'sell',
#  563: 'advice',
#  564: 'gay',
#  565: 'yourself',
#  566: 'though',
#  567: 'exist',
#  568: 'fight',
#  569: 'types',
#  570: 'tax',
#  571: 'share',
#  572: 'blood',
#  573: 'machine',
#  574: 'effective',
#  575: 'services',
#  576: 'second',
#  577: '20',
#  578: 'allowed',
#  579: 'personal',
#  580: 'police',
#  581: 'rate',
#  582: 'foreign',
#  583: 'earn',
#  584: 'code',
#  585: 'games',
#  586: 'korea',
#  587: 'interview',
#  588: 'application',
#  589: 'paper',
#  590: 'let',
#  591: 'case',
#  592: 'project',
#  593: 'themselves',
#  594: 'terms',
#  595: 'australia',
#  596: 'famous',
#  597: 'courses',
#  598: 'marriage',
#  599: 'period',
#  600: 'area',
#  601: 'set',
#  602: 'brain',
#  603: 'difficult',
#  604: 'rather',
#  605: 'night',
#  606: 'private',
#  607: 'already',
#  608: 'bangalore',
#  609: 'daily',
#  610: 'compared',
#  611: 'mumbai',
#  612: 'effect',
#  613: 'act',
#  614: 'price',
#  615: 'trying',
#  616: 'explain',
#  617: 'm',
#  618: 'middle',
#  619: "i've",
#  620: 'liberals',
#  621: 'amount',
#  622: 'easy',
#  623: 'words',
#  624: 'team',
#  625: 'song',
#  626: 'universe',
#  627: 'says',
#  628: 'skin',
#  629: 'neet',
#  630: 'plan',
#  631: 'hours',
#  632: 'places',
#  633: 'treat',
#  634: 'japanese',
#  635: 'example',
#  636: 'useful',
#  637: 'towards',
#  638: 'news',
#  639: 'follow',
#  640: 'wants',
#  641: 'worst',
#  642: 'mother',
#  643: 'knowledge',
#  644: 'quality',
#  645: 'asked',
#  646: 'married',
#  647: 'amazon',
#  648: 'sleep',
#  649: 'once',
#  650: 'biggest',
#  651: 'seem',
#  652: 'yet',
#  653: 'young',
#  654: 'correct',
#  655: 'theory',
#  656: 'iphone',
#  657: 'function',
#  658: 'products',
#  659: 'prevent',
#  660: 'turn',
#  661: 'visit',
#  662: 'describe',
#  663: 'national',
#  664: 'list',
#  665: '15',
#  666: 'may',
#  667: 'happy',
#  668: 'institute',
#  669: 'cse',
#  670: 'taken',
#  671: 'coaching',
#  672: 'started',
#  673: 'model',
#  674: 'rid',
#  675: 'vs',
#  676: 'star',
#  677: 'ideas',
#  678: 'islam',
#  679: 'lost',
#  680: '12th',
#  681: 'offer',
#  682: 'effects',
#  683: 'gun',
#  684: 'download',
#  685: '9',
#  686: 'three',
#  687: 'wife',
#  688: 'invest',
#  689: 'differences',
#  690: 'animals',
#  691: 'oil',
#  692: 'view',
#  693: 'far',
#  694: 'stock',
#  695: 'matter',
#  696: 'line',
#  697: 'iâ\x80\x99m',
#  698: 'okay',
#  699: 'red',
#  700: 'week',
#  701: 'instagram',
#  702: 'avoid',
#  703: 'little',
#  704: '11',
#  705: 'fast',
#  706: 'natural',
#  707: 'develop',
#  708: 'expect',
#  709: 'security',
#  710: 'character',
#  711: "you've",
#  712: 'thinking',
#  713: 'negative',
#  714: 'japan',
#  715: 'necessary',
#  716: 'eating',
#  717: 'israel',
#  718: 'exams',
#  719: 'provide',
#  720: 'com',
#  721: 'chemical',
#  722: 'jews',
#  723: 'sound',
#  724: 'chance',
#  725: 'board',
#  726: 'sexual',
#  727: 'grow',
#  728: 'reasons',
#  729: 'likely',
#  730: 'remove',
#  731: 'must',
#  732: 'depression',
#  733: 'add',
#  734: 'anti',
#  735: 'facts',
#  736: 'chances',
#  737: 'present',
#  738: 'professional',
#  739: 'size',
#  740: 'laptop',
#  741: 'reading',
#  742: 'dream',
#  743: 'accept',
#  744: 'large',
#  745: 'modi',
#  746: 'option',
#  747: 'cut',
#  748: 'prefer',
#  749: 'send',
#  750: 'within',
#  751: 'feeling',
#  752: 'army',
#  753: 'apps',
#  754: 'office',
#  755: 'schools',
#  756: 'speak',
#  757: 'moving',
#  758: 'n',
#  759: 'graduate',
#  760: 'told',
#  761: 'becoming',
#  762: 'digital',
#  763: 'investment',
#  764: 'fall',
#  765: 'together',
#  766: 'financial',
#  767: 'european',
#  768: 'least',
#  769: 'interested',
#  770: 'phd',
#  771: 'boy',
#  772: 'preparation',
#  773: 'father',
#  774: 'fake',
#  775: 'illegal',
#  776: 'poor',
#  777: 'paid',
#  778: 'outside',
#  779: 'interesting',
#  780: 'nothing',
#  781: 'mental',
#  782: 'percentage',
#  783: 'break',
#  784: 'close',
#  785: 'western',
#  786: 'donâ\x80\x99t',
#  787: 'options',
#  788: 'head',
#  789: 'higher',
#  790: 'thoughts',
#  791: 'impact',
#  792: 'basic',
#  793: 'dating',
#  794: 'drive',
#  795: 'allow',
#  796: 'nuclear',
#  797: 'here',
#  798: 'subject',
#  799: 'income',
#  800: '30',
#  801: 'population',
#  802: 'contact',
#  803: 'store',
#  804: 'style',
#  805: 'uses',
#  806: 'studies',
#  807: '50',
#  808: 'chemistry',
#  809: "you're",
#  810: 'french',
#  811: 'born',
#  812: 'languages',
#  813: 'husband',
#  814: 'rights',
#  815: '18',
#  816: "aren't",
#  817: 'gain',
#  818: 'might',
#  819: 'universities',
#  820: 'java',
#  821: 'upsc',
#  822: 'physical',
#  823: 'land',
#  824: 'special',
#  825: 'comes',
#  826: 'hand',
#  827: 'mains',
#  828: 'changed',
#  829: 'interest',
#  830: 'solution',
#  831: 'check',
#  832: 'email',
#  833: 'issues',
#  834: 'gets',
#  835: 'strong',
#  836: 'racist',
#  837: 'gate',
#  838: 'german',
#  839: 'fact',
#  840: 'websites',
#  841: 'russian',
#  842: 'advantages',
#  843: 'baby',
#  844: 'intelligence',
#  845: 'personality',
#  846: '000',
#  847: 'developer',
#  848: 'recommend',
#  849: 'ms',
#  850: 'room',
#  851: 'teacher',
#  852: 'created',
#  853: 'branch',
#  854: 'characteristics',
#  855: 'pressure',
#  856: 'rich',
#  857: 'hindi',
#  858: 'please',
#  859: 'heart',
#  860: 'near',
#  861: 'meet',
#  862: 'pregnant',
#  863: 'credit',
#  864: 'dark',
#  865: 'fat',
#  866: 'currently',
#  867: 'hyderabad',
#  868: 'sites',
#  869: 'marry',
#  870: 'inside',
#  871: 'doctor',
#  872: 'pass',
#  873: 'laws',
#  874: 'source',
#  875: 'startup',
#  876: 'economy',
#  877: 'obama',
#  878: 'apple',
#  879: 'west',
#  880: 'bring',
#  881: 'positive',
#  882: 'pursue',
#  883: 'whole',
#  884: 'structure',
#  885: 'scope',
#  886: 'building',
#  887: 'early',
#  888: 'charge',
#  889: 'son',
#  890: 'spend',
#  891: 'solve',
#  892: 'maths',
#  893: 'ok',
#  894: 'windows',
#  895: 'partner',
#  896: 'ca',
#  897: 'network',
#  898: 'works',
#  899: 'videos',
#  900: 'crush',
#  901: 'alone',
#  902: 'smart',
#  903: 'numbers',
#  904: 'completely',
#  905: 'topics',
#  906: 'bitcoin',
#  907: 'views',
#  908: 'christians',
#  909: 'gas',
#  910: 'officer',
#  911: 'certain',
#  912: 'among',
#  913: 'ones',
#  914: 'content',
#  915: 'cbse',
#  916: 'text',
#  917: 'film',
#  918: 'art',
#  919: 'talking',
#  920: 'especially',
#  921: 'practice',
#  922: 'africa',
#  923: 'factors',
#  924: 'according',
#  925: 'd',
#  926: 'global',
#  927: 'iq',
#  928: 'cell',
#  929: 'religious',
#  930: 'reduce',
#  931: 'asian',
#  932: 'christian',
#  933: 'needed',
#  934: 'complete',
#  935: 'teach',
#  936: 'healthy',
#  937: 'pune',
#  938: 'treatment',
#  939: 'dogs',
#  940: 'exactly',
#  941: 'stupid',
#  942: 'written',
#  943: 'ago',
#  944: 'race',
#  945: 'save',
#  946: 'buying',
#  947: 'yes',
#  948: 'file',
#  949: 'mom',
#  950: 'distance',
#  951: 'cs',
#  952: 'advanced',
#  953: 'coming',
#  954: 'cold',
#  955: 'simple',
#  956: 'eyes',
#  957: 'novel',
#  958: 'minimum',
#  959: 'east',
#  960: 'electrical',
#  961: 'songs',
#  962: 'hurt',
#  963: 'train',
#  964: 'attack',
#  965: 'color',
#  966: 'democrats',
#  967: 'whatâ\x80\x99s',
#  968: 'method',
#  969: 'thought',
#  970: 'fear',
#  971: 'community',
#  972: 'policy',
#  973: 'multiple',
#  974: 'insurance',
#  975: 'playing',
#  976: 'dead',
#  977: 'mathematics',
#  978: 'giving',
#  979: 'football',
#  980: 'analysis',
#  981: 'easily',
#  982: 'african',
#  983: 'procedure',
#  984: 'eye',
#  985: 'clear',
#  986: 'lead',
#  987: 'result',
#  988: 'abroad',
#  989: 'letter',
#  990: 'transfer',
#  991: 'fix',
#  992: 'lower',
#  993: 'anxiety',
#  994: 'almost',
#  995: 'cannot',
#  996: 'opportunities',
#  997: 'hindu',
#  998: 'green',
#  999: 'economic',
#  1000: 'react',
#  ...}

# %%
vocab_len=len(tok.index_word.keys())

# %%
vocab_len
# Out:
# 196220

# %%
sequences_matrix_train = sequence.pad_sequences(sequences_train,maxlen=max_quant_len)

# %%
sequences_matrix_train
# Out:
# array([[   0,    0,    0, ..., 5916,   44,  242],
#        [   0,    0,    0, ...,    5, 1602, 3144],
#        [   0,    0,    0, ...,  136,   18,  296],
#        ...,
#        [   0,    0,    0, ...,  392,    7,  678],
#        [   0,    0,    0, ...,    6,   28,  560],
#        [   0,    0,    0, ..., 5472,    6,  142]], dtype=int32)

# %% [markdown]
# **Loading data from google drive**

# %%
# !pip install -U -q PyDrive

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
file_list = drive.ListFile({'q': "'root' in parents and trashed=false"}).GetList()
for file1 in file_list:
  print('title: %s, id: %s' % (file1['title'], file1['id']))
# Out:
# title: stacksample.zip, id: 12vawrfGZCl3CWFDSV7_6OTzwOKckcvSR
# title: glove.6B.100d.txt.zip, id: 1UuFu2iM81r-zCTELWKcT4zY2QRTpijCo
# title: train.csv, id: 1h_QAPLzFre6QVRZ7Bu7DIel6yaArAKNh
# title: Colab Notebooks, id: 1ATgDoTZH_i3iMLX3Cs56sBZ0rAkqiPbg
# title: New folder, id: 1Mgd5DdBB1b0kJ02Q7WARnxcD3tpDrR8K
# title: Python_basics_class_assign.ipynb, id: 0B139lAmq78gnbGZaSElPaFNRRkFiRFd4UXIzTEVzXy1oRk5z
# title: diabetes.csv, id: 0B139lAmq78gnOC1SQ3NxVkZJcWR3aXltU3IzYk04YXUyR0Rv
# title: Untitled presentation, id: 18wTMHUG4aHkXQNshqC4QEUFrbh4dfos7dQuopy2ubDo
# title: icicijulytodecember, id: 1xuo0sljCGw3LlM2-8GVWK-wee7uGFPrBmgPaUUjl60U
# title: DEEPTHI Resume2, id: 1SR4_8wBTdeuWHCiTHoNt668XBYHOuHlk_RtYc2veR_A
# title: Untitled document, id: 1jfbe_2mfK7ktxIhckuzCnAJ7z_W0vWfzN7b0xfx7XsU
# title: summary, id: 1oXCb8J6hUX_JCLeDw58zuiYctsoNVH1Kn1J3NkdtjRs
# title: Digit Per Minute(DPM) (1), id: 1H8oLNZAKMdZpvmKeOQKSgxP6UUG_4j24JryoG7Yvf8o
# title: 12day shudule children video, id: 1f8SCzRlgrNnvvL_hbiYG665pZxuUSeDS0eooM5rT_WE
# title: Abacus Syllabus, id: 1SgaXGrOlk5r9XmpKBZHFdLUvUMajp3XfAceofIEOYP4
# title: Updated 1 Flowchart for whole ERP, id: 1F9HcJutwOT_pZmNCnmB_s-sm0rwuNwg0c_JTlS2KpQE
# title: CONTACT INFO MMTPL, id: 1ynBIPr9X5J44EKHwZ7YonubxUtbOj4mGdpywEgH3kf8
# title: PFO PRESENTATION, id: 1PefrsjOmr5CUlj5s-NElcYdxaFDzxg3rHhg-XFOhggE
# title: Untitled form, id: 1A9BO6sOItWLEBhT-z6RDJa7iTRNB7vRpmAuvX1S9R10
# title: divya insurance twowheeler.pdf, id: 0B139lAmq78gnWHFQaWZDdXhKZ1k
# title: STATEMENT OF PURPOSE, id: 16HoPqxfnJl8TNiWJehO_sWuJtgs_Q34kVu4mm34zQH0
# title: divya_vatti(825014).docx, id: 13Zsr0bkQKKYTxySIaUaQbJe37r7n-gReg9fMmA8LYRk
# title: divya_vatti(825014).docx, id: 0B139lAmq78gnZlBPN0xvRGxyQldsMHpYdkQtT05MUUo5Njdj
# title: mahe, id: 0B139lAmq78gnZnh5TmphV3JWNGM
# title: 530180.pdf, id: 0B139lAmq78gnRm1waW5VUW5pQnc
# title: Finalized Telugu Stories.rar, id: 0B139lAmq78gncmhVMVlsVUlRQVNDOXVsQ0Zaa1ZlYUxETUJr
# title: IMG-20150911-WA0002.jpg, id: 0B139lAmq78gnMlpiYTg4R1NlUEc1ZTk5RjhmdWN3OXZBQW9v
# title: IMG_20150110_141814509.jpg, id: 0B139lAmq78gna2N2bktsdzZtZEU
# title: IMG_20150110_141834969.jpg, id: 0B139lAmq78gncnZJdERqZ2dDNGc
# title: IMG_20150110_141823480.jpg, id: 0B139lAmq78gnQnZydUZrNTVZTTA
# title: IMG_20150110_141902743.jpg, id: 0B139lAmq78gnMzg4b09EQWpJUm8
# title: IMG_20150110_141913943.jpg, id: 0B139lAmq78gnUUZZMDRBUkVNZGM
# title: IMG_20150110_141919652.jpg, id: 0B139lAmq78gnZy1UWlhpUlVndDg
# title: IMG_20150110_141935994.jpg, id: 0B139lAmq78gnT3dSa2tZY2VYVTA
# title: IMG_20150110_141949139.jpg, id: 0B139lAmq78gnOThuRS1vdnk3cms
# title: IMG_20150110_142028117.jpg, id: 0B139lAmq78gnMWdyVElhemZrU0k
# title: IMG_20150110_142017029.jpg, id: 0B139lAmq78gnNWhvalFRRUptQWc
# title: IMG_20150110_142219248.jpg, id: 0B139lAmq78gnNkNBd3drbXJGZ00
# title: IMG_20150110_142237860.jpg, id: 0B139lAmq78gnT1ZUV3BDMHNxVk0
# title: IMG_20150110_142038337.jpg, id: 0B139lAmq78gnQVIxbnZicUNuUG8
# title: IMG_20150110_142257875.jpg, id: 0B139lAmq78gnQzkzVEZhRklDNFk
# title: IMG_20150110_142332999.jpg, id: 0B139lAmq78gnYlduLWFxMFA2SHc
# title: IMG_20150110_142324429.jpg, id: 0B139lAmq78gneEdZMGJNWGZIUzg
# title: IMG_20150110_142350937.jpg, id: 0B139lAmq78gnaVJZSjJkZ1BJQTA
# title: IMG_20150110_142429436.jpg, id: 0B139lAmq78gnZlRqQzJsYklqTFE
# title: IMG_20150110_142542949.jpg, id: 0B139lAmq78gnMVNpSzRLa1o5ZDg
# title: IMG_20150110_143209650.jpg, id: 0B139lAmq78gnWWVZemJ3allfTzA
# title: IMG_20150110_142813359.jpg, id: 0B139lAmq78gncTd4Qm82QWxtMEE
# title: IMG_20150110_143038475.jpg, id: 0B139lAmq78gndVlTS3dsY2tjWm8
# title: IMG_20150110_143225698.jpg, id: 0B139lAmq78gnenA1NmgtS3JHQlE
# title: IMG_20150110_143230575.jpg, id: 0B139lAmq78gnQlpVRmxyUlFUdm8
# title: IMG_20150110_143302288.jpg, id: 0B139lAmq78gnZm82TTdNWGEtLUE
# title: IMG_20150110_143312346.jpg, id: 0B139lAmq78gneHlFRjNZdEEtdm8
# title: IMG_20150110_143317027.jpg, id: 0B139lAmq78gnOTRBX3MzZFdwSU0
# title: IMG_20150110_143420491.jpg, id: 0B139lAmq78gnSl9kc1c1dU9iNUk
# title: IMG_20150110_143435085.jpg, id: 0B139lAmq78gnU00xaEVyRWFSV0E
# title: IMG_20150110_143455898.jpg, id: 0B139lAmq78gnY0h4SWdxVWlkTlE
# title: IMG_20150110_143645459.jpg, id: 0B139lAmq78gnSW1LcTNkbmpLVEE
# title: IMG_20150110_143813474.jpg, id: 0B139lAmq78gnckFqaXBrM292QUU
# title: IMG_20150110_143815057.jpg, id: 0B139lAmq78gnT0tsem8wSTlId2s
# title: IMG_20150110_143819798.jpg, id: 0B139lAmq78gnMUlXTElkMTJ0Zkk
# title: IMG_20150110_143821835.jpg, id: 0B139lAmq78gnSFVSTjk0ZzJ1dW8
# title: IMG_20150110_143836160.jpg, id: 0B139lAmq78gndHNGeElqVVlGb3M
# title: IMG_20150110_143839838.jpg, id: 0B139lAmq78gnOUFlalM4X2h5SW8
# title: IMG_20150110_151009407.jpg, id: 0B139lAmq78gnaF80LXR4eFNSdnc
# title: IMG_20150110_151039997.jpg, id: 0B139lAmq78gnbTJfQWZGNVRpLVU
# title: IMG_20150110_151048281.jpg, id: 0B139lAmq78gnVER3blR3cmFaU2c
# title: IMG_20150110_151508287.jpg, id: 0B139lAmq78gnNlB5ZDhLSWl0U0k
# title: IMG_20150110_151659461_HDR.jpg, id: 0B139lAmq78gneVl6d25NNFFtOWs
# title: IMG_20150110_153756952.jpg, id: 0B139lAmq78gnRXBzUTZEc2pUS1U
# title: IMG_20150110_154304774_HDR.jpg, id: 0B139lAmq78gnZzItcFVOWVNQdTg
# title: IMG_20150110_154243690.jpg, id: 0B139lAmq78gnd0Y0Y2hadzJzV1k
# title: IMG_20150110_154947185.jpg, id: 0B139lAmq78gnNHh6YVdyUE1BQk0
# title: IMG_20150110_155005090.jpg, id: 0B139lAmq78gnSEM1X0RodnY3bXc
# title: IMG_20150110_154541528.jpg, id: 0B139lAmq78gncWZMb2tLT0tJYnM
# title: IMG_20150110_155031426.jpg, id: 0B139lAmq78gnZjg1Ukd5VFl6Qms
# title: IMG_20150110_155034261.jpg, id: 0B139lAmq78gnNk9jejhLLVBONFU
# title: IMG_20150110_155714860.jpg, id: 0B139lAmq78gnOEdHMk9TVVlwbjQ
# title: IMG_20150110_155722026.jpg, id: 0B139lAmq78gnR1I3ZWRGM3BoYmM
# title: IMG_20150110_155800683.jpg, id: 0B139lAmq78gnMmZWMmZ4MFlOZlk
# title: IMG_20150110_160302691.jpg, id: 0B139lAmq78gnQ0xRQ0pZdGlyQTg
# title: IMG_20150110_170353816_HDR.jpg, id: 0B139lAmq78gnVEo2LUdtaDJnZ3c
# title: IMG_20150110_170412806.jpg, id: 0B139lAmq78gnQm9KQVI2a1FERlE
# title: IMG_20150110_170931775_HDR.jpg, id: 0B139lAmq78gnSWUyLVJYZFd4SFU
# title: IMG_20150110_170551780.jpg, id: 0B139lAmq78gnUWNTVnJMUXlha00
# title: IMG_20150110_170854799.jpg, id: 0B139lAmq78gnMDFHSVNqQTZkeFE
# title: IMG_20150110_171100669_HDR.jpg, id: 0B139lAmq78gnTXFLUURpdUhkQjg
# title: IMG_20150110_170938226_HDR.jpg, id: 0B139lAmq78gnQnRVcmprck1VNmc
# title: IMG_20150110_171239734_HDR.jpg, id: 0B139lAmq78gnX0dWdDVad0ZmMEE
# title: IMG_20150110_171255624.jpg, id: 0B139lAmq78gnY0R5cmFiWW1Tcmc
# title: IMG_20150110_171458275_HDR.jpg, id: 0B139lAmq78gnVmxGZDJxRHp5TUk
# title: IMG_20150110_173949946_HDR.jpg, id: 0B139lAmq78gnb1pWWUtBaDRTLVE
# title: IMG_20150110_174053374_HDR.jpg, id: 0B139lAmq78gnOE9PVmx2WXpPaG8
# title: IMG_20150110_175034219_HDR.jpg, id: 0B139lAmq78gnSXBSLURBbWo0MlU
# title: IMG_20150110_175155473_HDR.jpg, id: 0B139lAmq78gnc2oyS1J6VmUxS2M
# title: IMG_20150110_175106512_HDR.jpg, id: 0B139lAmq78gnbHM3eVlCNEpCR0U
# title: IMG_20150110_175220582_HDR.jpg, id: 0B139lAmq78gnenQ5aVQweDBPd00
# title: IMG_20150110_175842306_HDR.jpg, id: 0B139lAmq78gnMm55Wi0zclQtWm8
# title: IMG_20150110_175450466_HDR.jpg, id: 0B139lAmq78gnQ2hudVRkRTFyTjA
# title: IMG_20150110_175848304_HDR.jpg, id: 0B139lAmq78gnazF1NUdKd1BmZm8
# title: IMG_20150110_180339065_HDR.jpg, id: 0B139lAmq78gnLWYwelIwZE9pS1E
# title: IMG_20150110_180359717_HDR.jpg, id: 0B139lAmq78gnVm4wZ2s3aTlkb1U
# title: IMG_20150110_180419318_HDR.jpg, id: 0B139lAmq78gnZTJTS20zWndoQUE
# title: IMG_20150110_180538326_HDR.jpg, id: 0B139lAmq78gnTzN5dnRJUlZoLVE
# title: IMG_20150110_180546387.jpg, id: 0B139lAmq78gnd2JiQTNqTURWT3M
# title: IMG_20150110_180557017.jpg, id: 0B139lAmq78gnVzRsLUlvdjBnbnM
# title: IMG_20150110_180701322_HDR.jpg, id: 0B139lAmq78gncjJhSFdiYVh5aUE
# title: IMG_20150110_180721054_HDR.jpg, id: 0B139lAmq78gnSXhIMTBkOU9TUUU
# title: IMG_20150110_180748816_HDR.jpg, id: 0B139lAmq78gneHo0eHFTODNnejQ
# title: IMG_20150110_180805775_HDR.jpg, id: 0B139lAmq78gndDZrYjNNNmIxNkE
# title: IMG_20150110_180812910_HDR.jpg, id: 0B139lAmq78gnb1pxc2NYb2laMjA
# title: IMG_20150110_180829242_HDR.jpg, id: 0B139lAmq78gnYzg0MTNaRVB2NVU
# title: IMG_20150110_180909019_HDR.jpg, id: 0B139lAmq78gnNjE3VG1nT00zRU0
# title: IMG_20150110_180920861_HDR.jpg, id: 0B139lAmq78gnWklHb29MOUdFVE0
# title: IMG_20150110_180927976_HDR.jpg, id: 0B139lAmq78gnalJYS2FFWnBYRU0
# title: IMG_20150110_181001521_HDR.jpg, id: 0B139lAmq78gnSHVYY0Y5NjY1ZlU
# title: IMG_20150110_181008530_HDR.jpg, id: 0B139lAmq78gnNjJ5Si16dUFObWM
# title: IMG_20150314_145208609.jpg, id: 0B139lAmq78gnMGZNVUcwdmM1V0U
# title: IMG_20150209_102146.jpg, id: 0B139lAmq78gnODFTNjNkVHVxSWs
# title: IMG_20150329_200748668_HDR.jpg, id: 0B139lAmq78gnOFJlRGxYc1lLdW8
# title: IMG_20150209_102125142.jpg, id: 0B139lAmq78gnMnRtQzVrLUUtWUk
# title: IMG_20150308_163735204.jpg, id: 0B139lAmq78gnN1g3dzRBai1nSlk
# title: IMG_20150401_125657940.jpg, id: 0B139lAmq78gnSVlKXzQ3MzBxNWM
# title: IMG_20150209_102221.jpg, id: 0B139lAmq78gnUDZ4eU1CeTBRclE
# title: IMG_20150209_101914.jpg, id: 0B139lAmq78gnZHFuNDh4OEVvVG8
# title: IMG_20150209_102030.jpg, id: 0B139lAmq78gnVjdzc195SDd3ejA
# title: IMG_20150209_102227399.jpg, id: 0B139lAmq78gnR0l2eVFlQWhLOWs
# title: IMG_20150314_145206218.jpg, id: 0B139lAmq78gnOExKY3RDR2dpRXM
# title: IMG_20150209_102209366.jpg, id: 0B139lAmq78gndlpqRE1vdDd1M2c
# title: IMG_20150209_102020930.jpg, id: 0B139lAmq78gnMllvZzlldkhvck0
# title: IMG_20150314_145157290.jpg, id: 0B139lAmq78gnam94QmViYmNjWFU
# title: IMG_20150329_200745150_HDR.jpg, id: 0B139lAmq78gnTnBMOHY4NFhqd0k
# title: pregnancytest.docx, id: 0B139lAmq78gnb0ctbUtZWkhzYzQ
# title: pregnancytest, id: 0B139lAmq78gnc2ppejlrRVlGOEk
# title: images (1).jpg, id: 0B139lAmq78gnQkMyZDV0dU01bVVGQUVIWnl6ZHpRa1RPODU0
# title: TCS_Offer_CT20100228351.pdf, id: 0B139lAmq78gnWXhDQ3JYM0ZFdTA
# title: CT20100228351-joningletter2.pdf, id: 0B139lAmq78gna21vd3lTOFRNWEU
# title: Citibank Account Statement-20141101 TO 20141201.pdf, id: 0B139lAmq78gnN3dteDh5QXBSVzI2cmlLdmwzclVhamd5Z2M4
# title: CITIBANK REWARDS PLATINUM CARD.pdf, id: 0B139lAmq78gnMzFpbG9fS2Y1R3ZoWWFVcUMyTHNiVUpNbGxR
# title: Citibank Account Statement-20141101 TO 20141117.pdf, id: 0B139lAmq78gnSVdkb2F5NDU1SjFJWWl1SjVNZlYzREYtblpV
# title: Savings_Stmt_17111421381.xls, id: 0B139lAmq78gnbjE5OVpFbVlsTWhOVVVuNDN2YnN0eE1MVThV
# title: medbillvenkat.pdf, id: 0B139lAmq78gnQXp1d1JlQlhJbnc
# title: div resum.pdf, id: 0B139lAmq78gnV2hMQjVOdV9ldkVGUGRSSFhhOFFpSGhQRi1F

# %%
downloaded = drive.CreateFile({'id': '1UuFu2iM81r-zCTELWKcT4zY2QRTpijCo'})
downloaded.GetContentFile('glove6b100dtxt.zip')

# %%
# !unzip glove6b100dtxt.zip
# Out:
# Archive:  glove6b100dtxt.zip
#   inflating: glove.6B.100d.txt

# %%
from __future__ import print_function

import os
import sys
import numpy as np
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.layers import Dense, Input, GlobalMaxPooling1D
from keras.layers import Conv1D, MaxPooling1D, Embedding
from keras.models import Model
from keras.initializers import Constant
from keras.layers import Conv2D
from keras.layers import MaxPooling2D

 
BASE_DIR = ''
GLOVE_DIR = os.path.join(BASE_DIR, 'glove.6B')

# %%
embeddings_index = {}
f = open('glove.6B.100d.txt',encoding='utf-8')
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Found 400000 word vectors.

# %%
word_index=tok.word_index
len(word_index)
# Out:
# 196220

# %%
embedding_matrix = np.zeros((len(word_index)+1,100))
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector

# %%
embedding_matrix
# Out:
# array([[ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.038194  , -0.24487001,  0.72812003, ..., -0.1459    ,
#          0.82779998,  0.27061999],
#        [-0.15180001,  0.38409001,  0.89340001, ..., -0.27123001,
#          0.22157   ,  0.92111999],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.067863  , -0.26969001, -0.36182001, ...,  0.16723999,
#         -0.08863   ,  0.17496   ],
#        [ 0.046097  ,  0.45210001,  0.1778    , ...,  0.10402   ,
#          0.029458  ,  0.52072001]])

# %%
tok = Tokenizer(char_level=False,split=' ')
tok.fit_on_texts(x_test)
sequences_test = tok.texts_to_sequences(x_test)

# %%
sequences_test
# Out:
# [[9, 26, 4199, 5469, 2528, 122, 10, 345, 27, 3345, 140, 141, 61, 94, 4200],
#  [2, 288, 14, 118, 28, 142],
#  [76, 481, 47, 1787, 145, 54, 193, 162, 121, 194, 3, 64, 888],
#  [2,
#   3,
#   33,
#   791,
#   13,
#   4,
#   14841,
#   357,
#   1694,
#   184,
#   3377,
#   279,
#   6,
#   70,
#   6663,
#   5171,
#   1619,
#   42952,
#   1619,
#   42953,
#   13,
#   4013,
#   265],
#  [2, 12, 1, 33, 841, 5, 307, 748, 22, 458, 1351],
#  [30, 3, 1, 33, 13225, 392, 3305, 13, 122],
#  [3,
#   17,
#   111,
#   19,
#   1,
#   893,
#   7,
#   414,
#   758,
#   24,
#   894,
#   462,
#   190,
#   1,
#   279,
#   7,
#   1,
#   680,
#   74,
#   19,
#   50,
#   758,
#   1663,
#   1397,
#   45,
#   1,
#   1283,
#   267],
#  [120, 28, 86, 22, 1, 5470, 70, 1378, 2207, 10, 17065, 7, 851],
#  [2,
#   3,
#   1,
#   809,
#   127,
#   70,
#   2847,
#   5381,
#   42954,
#   679,
#   3638,
#   6822,
#   1415,
#   19,
#   288,
#   1,
#   1089,
#   60,
#   293,
#   561],
#  [9, 3, 1, 1788, 7, 42955],
#  [30, 410, 58, 1, 1220, 811, 581, 13, 2568, 3404],
#  [9,
#   10,
#   63,
#   758,
#   8,
#   530,
#   6267,
#   2819,
#   10,
#   31775,
#   46,
#   54,
#   21,
#   18,
#   186,
#   1136,
#   195],
#  [2, 1053, 31, 8, 75, 59, 3250],
#  [15, 14, 610, 5, 54, 2, 875, 712, 10, 2, 875, 700],
#  [99, 14, 880, 4, 155, 19, 9241, 54, 22, 753, 1, 1248],
#  [2, 12, 1, 33, 212, 5, 459, 1, 3935, 7, 18, 324, 20311, 2641],
#  [9, 1077, 3, 4, 215, 10, 2235, 42956, 3614],
#  [2, 26, 1, 2268, 2269, 42, 38, 296, 7, 42957, 6, 12029, 116],
#  [2, 3, 1, 107, 1090, 10, 500, 7, 4, 31776, 1149, 1677],
#  [16,
#   11,
#   50,
#   925,
#   4014,
#   43,
#   4597,
#   8,
#   352,
#   4014,
#   43,
#   232,
#   4597,
#   62,
#   8,
#   96,
#   81,
#   1,
#   2166,
#   390,
#   3,
#   39,
#   51,
#   846,
#   390,
#   5,
#   4014,
#   43,
#   232,
#   4597],
#  [9,
#   31,
#   8,
#   372,
#   21,
#   18,
#   474,
#   40,
#   3,
#   1410,
#   557,
#   5,
#   3201,
#   12580,
#   7,
#   18492,
#   1000,
#   10,
#   6050,
#   1314,
#   13,
#   3251,
#   54,
#   587,
#   5,
#   330,
#   1,
#   240],
#  [2, 11, 232, 66, 45, 165, 19, 12, 18493, 45, 22750],
#  [2, 12, 1, 1451, 2157, 6, 42958, 418, 1139],
#  [12, 39, 51, 8024, 3429, 4201],
#  [9, 49, 1, 656, 19, 2513, 153, 1, 31777, 640, 3095],
#  [20, 14, 12, 563, 5, 75, 92, 56, 486, 270, 30, 56, 41, 19, 25, 10, 16],
#  [9, 72, 3, 1, 500, 7, 4, 3680, 2107, 6, 605],
#  [50,
#   67,
#   81,
#   19,
#   50,
#   207,
#   156,
#   554,
#   1,
#   1217,
#   6413,
#   178,
#   9,
#   11,
#   50,
#   81,
#   19,
#   51,
#   294,
#   3345,
#   1,
#   1217,
#   6413,
#   41,
#   7122,
#   26226],
#  [3, 17, 158, 5, 6970, 298, 20, 28, 273, 2376, 26227, 5, 1, 4712, 1182, 1192],
#  [9, 11, 50, 61, 1, 952, 6529, 106, 231],
#  [3, 126, 18, 142, 836, 5, 181, 1271, 780, 1292, 23, 1588, 10208, 23, 12030],
#  [9, 15, 67, 1, 321, 10, 2713, 7, 535, 25, 7264],
#  [15, 8, 32, 102, 7820, 20, 18, 554, 3, 44, 53],
#  [9, 26, 214, 32, 415, 21, 9850],
#  [2, 3, 1827, 1171, 4598, 13, 324, 427, 395, 1492, 22751, 5033],
#  [2, 12, 1, 1312, 1352, 5, 517, 134, 10209, 18494, 13, 4, 2494, 516],
#  [30, 12, 1, 9851, 1203, 6, 57, 5, 106],
#  [9, 11, 8, 460, 1, 590, 8025, 10, 4655, 731, 4, 584, 271],
#  [20, 8, 1760, 285, 4, 377, 9546, 26, 17, 541, 23, 787, 9852],
#  [3, 11060, 4, 2800, 13, 357, 6823],
#  [34, 49, 14, 9242, 4, 243],
#  [2, 3, 42959, 689],
#  [49, 477, 123, 133, 3405, 5870, 5101, 18495, 79, 7, 373, 598],
#  [2, 12, 788, 10, 2146, 4772, 4060, 3252],
#  [2, 48, 1, 354, 3681, 744, 703],
#  [9,
#   11,
#   8,
#   1035,
#   18,
#   9853,
#   1645,
#   30,
#   3770,
#   942,
#   8,
#   124,
#   9854,
#   895,
#   350,
#   54,
#   1070,
#   422,
#   3130,
#   30,
#   15873,
#   22752,
#   178,
#   8,
#   5102,
#   8,
#   124,
#   163,
#   42960],
#  [30,
#   3,
#   1,
#   33,
#   1136,
#   685,
#   26228,
#   5296,
#   13,
#   1253,
#   75,
#   6,
#   1,
#   1367,
#   7,
#   622,
#   6971,
#   4146],
#  [15, 8, 1268, 13, 2868, 761, 27, 17066, 13, 67, 1395, 1237],
#  [30, 58, 1, 65, 956, 744, 1, 11521, 6530, 23, 1, 8026],
#  [2, 3, 29, 778, 2082, 689, 45, 164, 5, 1, 265, 1828, 2059, 3456],
#  [16, 3, 1, 115, 672, 1484, 52, 31778],
#  [11, 14, 24, 151, 2182, 2108, 3771, 4896, 2890, 205],
#  [41, 4, 860, 436, 279, 6, 1619, 414, 149, 6, 568, 13, 946, 6, 414, 6, 539],
#  [24, 14, 90, 2282, 4, 26229, 146],
#  [2, 12, 38, 53, 8438, 943, 6, 12581],
#  [2,
#   3,
#   1,
#   689,
#   451,
#   2236,
#   773,
#   16,
#   3,
#   17,
#   1789,
#   13,
#   8704,
#   1,
#   267,
#   7,
#   29,
#   1249,
#   10,
#   876,
#   9,
#   1789,
#   3,
#   17],
#  [9, 15, 56, 493, 3157, 148, 34, 712, 454],
#  [9, 49, 14, 32, 1209, 6, 582, 2594, 10, 9, 15, 8],
#  [80, 8, 456, 5, 2694, 1, 686, 1036, 146, 1497, 5, 1426, 756, 36, 4, 1652],
#  [2, 3, 28, 588, 22, 3253, 13, 794, 2196, 26230, 42961, 23, 2959, 193, 6, 70],
#  [26, 857, 2656, 109, 42962, 2746, 37],
#  [9,
#   11,
#   8,
#   372,
#   21,
#   4,
#   1254,
#   21,
#   1467,
#   14,
#   524,
#   1,
#   346,
#   10,
#   77,
#   58,
#   4,
#   2820,
#   7,
#   1498,
#   10,
#   288,
#   1,
#   960,
#   43,
#   234,
#   1486],
#  [15, 50, 167, 1, 1039, 7, 2714, 13978, 9855, 6, 4, 1257],
#  [9, 11, 14, 75, 694, 7123, 1960, 5, 28, 1420, 5, 32, 77, 33, 4834],
#  [16, 26, 5471, 106, 1408, 22, 802, 21, 20312, 2257],
#  [16,
#   3,
#   1,
#   416,
#   52,
#   22753,
#   6,
#   1,
#   2415,
#   19,
#   3306,
#   15,
#   1625,
#   1,
#   2543,
#   31779,
#   13,
#   159,
#   5233,
#   5,
#   1315,
#   87,
#   27,
#   6972,
#   9243,
#   3061,
#   2480,
#   1,
#   5382,
#   2821,
#   8964],
#  [2, 20, 4, 3222, 310, 14, 5, 75, 28, 275, 6, 312],
#  [2, 3, 1337, 10, 2, 3, 1284],
#  [9, 15, 8, 1240, 4, 1551, 5, 253, 8965, 1635, 6, 1, 94],
#  [9, 11, 8, 7265, 1320, 374, 22, 55, 847, 6, 847, 79, 68],
#  [9, 35, 14, 61, 4, 1846, 1051, 3581, 311],
#  [2, 3, 1, 566, 2747, 716, 90, 562, 23, 1078, 45],
#  [9, 15, 8, 310, 13, 7124],
#  [2, 58, 114, 1, 779, 7, 472, 6, 1, 31780, 881],
#  [2, 12, 1, 2569, 5, 95, 4, 4102],
#  [2,
#   58,
#   123,
#   2514,
#   6051,
#   1620,
#   15874,
#   10,
#   877,
#   4835,
#   10,
#   348,
#   4,
#   4487,
#   7,
#   1314],
#  [2, 3, 1906, 43, 6664],
#  [26,
#   19,
#   116,
#   19,
#   123,
#   4324,
#   4324,
#   11061,
#   12,
#   208,
#   16,
#   606,
#   35,
#   123,
#   25,
#   52,
#   22754,
#   21,
#   17],
#  [9, 26, 4, 1379, 7, 15875, 32, 4, 506, 5, 2570, 6, 2220],
#  [9, 15, 8, 26231, 18, 3041, 6824, 5, 1914, 1137, 22755, 1790],
#  [16, 26, 1664, 5948, 1120, 24, 202, 4, 163, 107, 974, 581, 9244],
#  [2, 3, 1, 2011, 1, 15876, 45],
#  [6, 471, 1972, 16, 512, 1626, 22756, 432, 160, 4, 18496],
#  [2, 3, 1, 390, 451, 957, 436, 217, 6, 539, 884, 263, 1778],
#  [9, 11, 14, 5568, 4, 12031],
#  [9, 3, 1, 323, 211, 170, 4897, 4, 42963, 10210, 31781, 7, 31782],
#  [2, 12, 1, 1158, 258, 1158, 1487, 6, 57],
#  [3, 39, 51, 1260, 23, 1698, 374, 982, 279, 6, 57, 13, 115, 2400],
#  [9, 26, 1, 2270, 68, 3772, 1, 10639, 7, 12032, 4488],
#  [9, 11, 14, 1138, 28, 10640, 190, 4287, 8231, 7821],
#  [12, 1538, 6, 1, 527, 744, 795, 462, 13, 1, 82, 47, 11],
#  [16, 12, 38, 37, 52, 2060, 19, 47, 96, 81, 19, 1, 334, 3, 44, 1338],
#  [203,
#   7822,
#   7,
#   12033,
#   4898,
#   6,
#   825,
#   12,
#   2714,
#   21,
#   736,
#   7822,
#   7,
#   2695,
#   8027,
#   5,
#   381,
#   4,
#   18497,
#   1165,
#   9,
#   69,
#   7822,
#   7,
#   1165,
#   41,
#   25,
#   1533],
#  [2, 12, 42964, 1247, 10, 16, 47, 12, 645, 2, 12, 55, 4431],
#  [8, 96, 42, 122, 6, 449, 80, 8, 4, 5383],
#  [15, 4, 104, 40, 7823, 21, 238, 1004, 95, 4, 542, 2325],
#  [64,
#   1277,
#   42,
#   4,
#   113,
#   589,
#   47,
#   650,
#   5,
#   75,
#   4,
#   2122,
#   7,
#   42965,
#   6973,
#   10,
#   238,
#   368,
#   374,
#   7640,
#   2,
#   11,
#   14,
#   573,
#   66],
#  [12,
#   1320,
#   7,
#   4147,
#   6531,
#   246,
#   1344,
#   26232,
#   7,
#   223,
#   12,
#   1166,
#   5,
#   1559,
#   223,
#   1320,
#   3,
#   39,
#   51,
#   127],
#  [3, 68, 3854, 6, 130, 236, 132],
#  [3,
#   4,
#   341,
#   404,
#   3274,
#   10,
#   22757,
#   4325,
#   2237,
#   5,
#   4,
#   341,
#   7641,
#   5,
#   1,
#   615,
#   9,
#   110,
#   12582,
#   260,
#   4,
#   8028,
#   3430,
#   5,
#   1,
#   717],
#  [2, 3, 1, 33, 2061, 13, 345, 6, 2570],
#  [35, 1, 1174, 7, 843, 3515, 3810, 1744, 1, 1636, 528],
#  [2, 3, 1, 7266, 1388, 1368, 6, 1025],
#  [6, 64, 1907, 487, 1779, 6, 1, 337, 286, 9, 15, 37, 372, 21, 55, 12583],
#  [9, 11, 8, 2183, 4, 754, 7, 67, 3893, 21, 301, 358, 6, 4, 324, 2611, 1434],
#  [16, 12, 1426, 9245],
#  [2, 3, 4, 1598, 7, 551, 19, 894, 28, 74],
#  [16, 26, 1, 3307, 507, 519, 5, 1818, 257, 61, 17, 102, 4, 4773, 9246],
#  [12, 382, 6, 57, 2642, 636, 5, 382, 40, 179, 983],
#  [2, 48, 1, 60, 4836, 640, 7, 298, 82, 6, 28, 74],
#  [9, 15, 8, 42966, 193, 22, 7267],
#  [2, 12, 38, 53, 11062, 225, 22, 938, 1109, 3308, 22, 436, 463, 10, 191, 938],
#  [2, 26, 409, 42967, 116],
#  [15, 8, 1140, 3378, 13, 2294, 6, 686, 718, 414],
#  [2, 12, 38, 1097, 21, 65, 71, 433, 2786, 10, 4, 957, 31783, 10, 3811],
#  [2, 12034, 3, 42968, 697, 1589, 22],
#  [15, 8, 32, 1770, 533, 6, 18498, 42969, 20, 8, 80, 1961, 5, 322],
#  [42970, 251, 766, 1, 618, 21, 6414],
#  [3, 6052, 4, 727, 141],
#  [17,
#   958,
#   42,
#   1,
#   1468,
#   6532,
#   84,
#   1,
#   397,
#   44,
#   5,
#   1167,
#   4,
#   372,
#   21,
#   1,
#   1460,
#   16,
#   3,
#   64,
#   1,
#   632,
#   734,
#   47,
#   3062,
#   17,
#   35,
#   25,
#   42971,
#   4148],
#  [2,
#   35,
#   25,
#   1,
#   331,
#   919,
#   7,
#   4,
#   1791,
#   1972,
#   108,
#   19,
#   35,
#   117,
#   5,
#   25,
#   2801,
#   20,
#   1,
#   275,
#   92,
#   1546,
#   1761,
#   261,
#   10,
#   3615],
#  [16,
#   11,
#   13979,
#   814,
#   5,
#   1140,
#   1,
#   1248,
#   162,
#   17,
#   3,
#   4656,
#   409,
#   548,
#   178,
#   1241,
#   13,
#   1819,
#   10,
#   29,
#   137,
#   334,
#   404,
#   6,
#   1,
#   97,
#   30,
#   3,
#   4656,
#   3096],
#  [2, 12, 1, 33, 388, 13, 2911, 3202, 2822, 36, 29, 2434],
#  [9, 41, 8, 444, 18, 6825, 2467],
#  [2, 12, 1021, 255],
#  [2, 12, 1, 2715, 1091, 7, 2012, 18499],
#  [30, 3, 1, 33, 683, 545, 661, 6, 57],
#  [2, 12, 1, 4381, 1949, 46, 4, 311, 6053, 12035],
#  [9, 49, 7642, 10, 31784, 536],
#  [16, 31, 8, 98, 158, 45, 13226, 20313],
#  [63, 15, 8, 681, 1, 6054, 1552, 3309, 203, 187, 12584, 20314],
#  [3,
#   39,
#   4,
#   78,
#   36,
#   29,
#   1726,
#   4288,
#   5,
#   91,
#   79,
#   16,
#   4,
#   2612,
#   1627,
#   14,
#   4,
#   454,
#   3551],
#  [30, 305, 7, 222, 172, 4432, 31, 8, 181, 13, 29, 4657, 2257],
#  [9, 15, 8, 2083, 21, 1, 882, 19, 8, 207, 32, 1123, 21, 18, 1242, 1086],
#  [63, 15, 8, 32, 196, 578, 147, 3346, 317, 42972, 13, 805, 210],
#  [6, 42973, 10211, 18500, 49, 10212, 11522, 88, 786],
#  [20, 9856, 4326, 17067, 159, 12585, 419, 26, 17, 95, 65, 6665],
#  [34,
#   1778,
#   3379,
#   38,
#   7,
#   1,
#   18501,
#   7,
#   4656,
#   3096,
#   15,
#   47,
#   1082,
#   17,
#   36,
#   83,
#   55,
#   1059,
#   1247],
#  [40, 12, 38, 7, 1, 53, 6666, 11523, 27, 1646, 101, 6, 17068, 4433],
#  [2, 3, 31785, 14842],
#  [9, 5384, 3, 74],
#  [11, 14, 517, 9857, 3275, 36, 1, 11524, 42974, 3310, 1116],
#  [20,
#   4,
#   5385,
#   1159,
#   5,
#   99,
#   154,
#   181,
#   4,
#   3310,
#   13,
#   4,
#   2787,
#   2726,
#   2029,
#   13,
#   55,
#   234,
#   2468],
#  [34,
#   1316,
#   826,
#   857,
#   26,
#   19,
#   116,
#   14,
#   105,
#   1049,
#   186,
#   17,
#   10,
#   159,
#   19,
#   128,
#   3019,
#   857,
#   135,
#   23,
#   3,
#   17,
#   131,
#   866,
#   10,
#   3516,
#   46,
#   14,
#   10,
#   20,
#   52,
#   15,
#   14,
#   530,
#   17,
#   5,
#   996,
#   37],
#  [3020, 48, 710, 39, 4103, 47, 3, 64, 637, 4489, 301],
#  [9, 132, 26, 17, 86, 4, 17069, 5569, 5, 3063, 20, 14, 24, 4658],
#  [40, 12, 4490, 2208, 6, 1079],
#  [4,
#   3682,
#   3,
#   15877,
#   774,
#   7125,
#   7,
#   5949,
#   513,
#   558,
#   43,
#   4,
#   525,
#   7,
#   1762,
#   513,
#   13227,
#   1699,
#   2,
#   3,
#   1,
#   11063,
#   538,
#   22,
#   1,
#   3682],
#  [63, 15, 8, 32, 1, 1960, 7, 238, 368, 8705, 10, 811, 1134],
#  [9, 15, 8, 664, 100, 10, 788, 4015, 20, 8, 3639, 664, 287, 36, 4, 2147],
#  [2, 3, 12, 1, 1284, 286, 7, 15878, 2912, 68],
#  [9, 11, 14, 98, 45, 2495, 13228, 83, 15879],
#  [63, 15, 8, 91, 1, 33, 26233, 10, 2595, 5472, 7, 57],
#  [30, 218, 7, 371, 768, 6, 2727, 1898],
#  [11, 250, 81, 47, 12, 2934, 1678, 1771, 18502, 15880],
#  [3, 17, 4, 53, 23, 158, 405, 5, 166, 3936],
#  [12,
#   14,
#   313,
#   5,
#   3377,
#   4,
#   416,
#   6268,
#   130,
#   853,
#   1,
#   130,
#   3855,
#   14,
#   179,
#   6,
#   6,
#   1061],
#  [9, 72, 358, 947, 22758, 5, 32, 3724, 6, 3773],
#  [16,
#   31,
#   8,
#   361,
#   2455,
#   641,
#   5,
#   4104,
#   641,
#   34,
#   1,
#   1220,
#   1708,
#   6,
#   4104,
#   3,
#   65,
#   71,
#   1,
#   1220,
#   1708,
#   6,
#   2455],
#  [6,
#   211,
#   200,
#   120,
#   1,
#   1368,
#   13,
#   160,
#   21,
#   6,
#   252,
#   7,
#   46,
#   363,
#   984,
#   18,
#   1520,
#   124,
#   114,
#   22754,
#   46,
#   1,
#   632],
#  [9, 8, 15, 32, 8232, 4713, 3552, 1029, 2387, 1997, 5034, 149],
#  [9, 11, 8, 847, 20, 2013, 3, 268, 23, 44],
#  [9, 11, 8, 1048, 18, 2848],
#  [16,
#   3,
#   10213,
#   8439,
#   1,
#   1476,
#   7268,
#   1158,
#   1180,
#   1127,
#   182,
#   20315,
#   100,
#   22,
#   7268,
#   71,
#   11064,
#   22,
#   4774,
#   6,
#   1,
#   1001,
#   112,
#   247,
#   19,
#   297,
#   1171,
#   1604,
#   7,
#   1210,
#   13,
#   1,
#   9247,
#   10,
#   88,
#   2641,
#   6,
#   6826,
#   535],
#  [8,
#   124,
#   1,
#   125,
#   4714,
#   21,
#   18,
#   483,
#   62,
#   154,
#   512,
#   206,
#   79,
#   21,
#   51,
#   604,
#   3,
#   154,
#   2247,
#   5,
#   54,
#   23,
#   11,
#   38,
#   232,
#   96,
#   206,
#   79,
#   21,
#   51,
#   604],
#  [40, 3, 1, 60, 1197, 104, 6, 1, 13980, 10, 16, 390],
#  [34, 26, 4, 1321, 4715, 102, 1, 428, 24, 1, 60, 1062, 425],
#  [9, 15, 8, 32, 629, 7, 2992, 6415],
#  [2, 502, 6, 728, 6, 22759],
#  [2, 12, 1, 33, 333, 1398, 13, 472, 5, 1792, 1962, 10, 2311, 9858, 6],
#  [16, 11, 3131, 42975, 3683, 36, 20, 47, 24, 4, 319, 62, 327, 5668, 5, 1461],
#  [3, 503, 467, 953, 37, 6, 673, 2271, 420, 1309, 189],
#  [30, 3, 1, 33, 1790, 6667, 169, 6, 1285, 10, 16],
#  [16,
#   52,
#   69,
#   37,
#   310,
#   370,
#   198,
#   42976,
#   36,
#   42977,
#   214,
#   58,
#   6533,
#   42978,
#   80,
#   52,
#   42979,
#   5,
#   429,
#   5,
#   214,
#   42980,
#   12,
#   306,
#   38,
#   6974,
#   198,
#   734,
#   14,
#   81,
#   328,
#   45,
#   214],
#  [9, 11, 14, 91, 537, 93, 1813, 28, 240, 5, 1608, 17, 79],
#  [16, 26, 290, 1021, 789, 66, 555, 3, 4, 504, 23, 29, 1043],
#  [12, 1, 6827, 43, 31786, 188, 5, 149, 31787, 37],
#  [16,
#   11,
#   165,
#   40,
#   12,
#   611,
#   6,
#   4,
#   240,
#   95,
#   2283,
#   34,
#   76,
#   606,
#   5035,
#   124,
#   4,
#   889,
#   22,
#   3,
#   1209,
#   21,
#   76,
#   606,
#   10,
#   44,
#   87],
#  [9, 494, 5, 1183, 14843, 185, 9, 3, 4, 9248, 14843, 129],
#  [2, 3, 1, 4382, 408, 7, 1448, 549, 13, 1029],
#  [63, 15, 8, 91, 2098, 12036, 6, 1727],
#  [2, 3, 1, 320, 7, 15881],
#  [2, 11, 37, 408, 65, 2184, 23, 848],
#  [35,
#   115,
#   165,
#   6,
#   6668,
#   814,
#   5,
#   854,
#   4,
#   122,
#   6,
#   110,
#   6668,
#   40,
#   3,
#   2748,
#   53,
#   126,
#   62,
#   44,
#   13981,
#   462,
#   6,
#   9859,
#   540],
#  [2, 11, 3582, 156, 190, 1, 22760, 7, 29, 2030, 2935, 428],
#  [9, 26, 31788, 17070, 1568, 974],
#  [9, 72, 68, 26, 6416, 86, 5, 362, 13, 1998, 4434, 59, 1839, 1233, 1408],
#  [3, 1, 97, 792, 65, 22761],
#  [2, 12, 38, 212, 5, 1012, 1847, 4775, 3725],
#  [2,
#   12,
#   1,
#   239,
#   793,
#   496,
#   13,
#   201,
#   182,
#   928,
#   10,
#   1025,
#   6,
#   218,
#   433,
#   15,
#   50,
#   385,
#   13,
#   274,
#   1189,
#   1025],
#  [16, 3, 1, 4243, 42981, 18503, 4, 3097],
#  [34,
#   1679,
#   12,
#   3517,
#   475,
#   811,
#   2,
#   31,
#   56,
#   651,
#   6,
#   1973,
#   1665,
#   36,
#   47,
#   5669,
#   136,
#   974],
#  [30, 225, 49, 1185, 4383, 268, 1141, 77, 48, 867],
#  [2, 3, 1, 105, 2496, 7269],
#  [9, 11, 14, 167, 1, 643, 625, 214, 46, 2167, 5, 214, 23, 193, 606],
#  [9, 72, 26, 290, 3684, 13, 197, 1416, 393, 293],
#  [3,
#   39,
#   51,
#   5570,
#   40,
#   3,
#   885,
#   378,
#   2031,
#   10,
#   658,
#   542,
#   5,
#   5234,
#   505,
#   20316,
#   27,
#   674,
#   2869],
#  [9, 15, 14, 1190, 1, 4959, 4061, 831, 7, 13229],
#  [2, 4105, 1, 355, 890, 119, 6, 1, 155, 473, 1, 905, 4016, 46, 3132, 1207],
#  [36, 4, 2168, 341, 2, 11, 14, 1128, 165, 6417],
#  [30, 56, 3, 100, 4599, 42982, 23, 4017, 31789],
#  [16, 26, 1, 411, 163, 42983, 1268, 2185, 1, 753, 3, 45, 4, 939, 284],
#  [30, 2544, 3, 33, 13, 7643, 618],
#  [2,
#   12,
#   38,
#   53,
#   669,
#   13,
#   4,
#   687,
#   1709,
#   5,
#   847,
#   79,
#   153,
#   4,
#   1599,
#   5,
#   728,
#   2295,
#   5235,
#   126,
#   3,
#   29,
#   1249,
#   52,
#   121,
#   44,
#   521,
#   13,
#   76,
#   5,
#   31790,
#   1,
#   17071,
#   2296],
#  [31,
#   8,
#   2802,
#   18,
#   4542,
#   2186,
#   59,
#   442,
#   6,
#   4,
#   274,
#   130,
#   568,
#   2,
#   779,
#   41,
#   17,
#   24,
#   832,
#   23,
#   662],
#  [2, 12, 38, 342, 7, 2993, 1662],
#  [3, 17, 208, 19, 20, 14, 145, 4, 222, 4, 3985, 77, 41, 297, 88, 208, 392],
#  [16, 48, 319, 188, 5, 509, 9547],
#  [3, 17, 380, 1493, 18, 68, 10, 126, 22, 418, 7, 349, 613, 5, 4491, 54],
#  [3, 4018, 4, 4776, 23, 3064],
#  [30, 4062, 3, 65, 1404, 26234, 23, 292, 2312, 1047, 23, 2123],
#  [9, 11, 8, 601, 6534, 769, 27, 31791, 18, 2388, 7, 1016],
#  [24,
#   14,
#   90,
#   124,
#   4,
#   1860,
#   40,
#   481,
#   47,
#   89,
#   11065,
#   6,
#   55,
#   554,
#   1361,
#   10,
#   178,
#   14,
#   404,
#   79,
#   47,
#   4103,
#   59,
#   3986,
#   87],
#  [26, 1, 367, 281, 24, 4, 846, 811, 13, 2297, 257, 44, 5, 95, 4, 954, 2187],
#  [31, 2960, 1469, 25, 3482, 46, 1, 136, 893, 19, 422, 619, 1269],
#  [2, 12, 38, 7, 1, 662, 676, 27, 3553, 7, 1371],
#  [2, 26, 4435, 14844, 26235, 6, 687, 20317, 4106],
#  [9, 11, 8, 7644, 14845, 42984, 8233],
#  [2, 3, 1, 612, 68, 42985, 14, 24, 563, 102, 28, 74],
#  [9, 26, 618, 167, 36, 14, 267],
#  [2, 948, 33, 6418, 14],
#  [26, 1, 1049, 1772, 7, 657, 6, 844, 992, 6, 65, 5473, 71, 200, 6, 4, 5950],
#  [40, 3, 1, 60, 2237, 333, 104, 6, 1, 97],
#  [2, 3, 1, 725, 7, 7126, 2803, 42986, 2803, 10, 15882, 2803],
#  [40, 288, 1, 2625, 3133],
#  [15, 14, 434, 4384, 59, 28, 979, 24, 114, 4327, 5, 5474, 202, 36, 26236],
#  [2, 12, 38, 33, 1221, 5386],
#  [16, 35, 29, 137, 770, 297, 85, 6, 2571, 10641, 36, 4, 113, 770],
#  [15, 50, 219, 31792, 36, 42987],
#  [9, 26, 1, 13230, 6669, 217, 149, 280],
#  [9, 132, 11, 4543, 235, 2657, 13, 1330, 8029],
#  [779, 7, 5236, 10, 2626, 22, 142],
#  [48, 1, 2728, 10642, 5764],
#  [53,
#   42988,
#   13,
#   4436,
#   438,
#   20,
#   14,
#   84,
#   4,
#   239,
#   6,
#   1,
#   674,
#   316,
#   13,
#   54,
#   4436,
#   3,
#   5,
#   1191],
#  [2, 12, 1, 574, 943, 496, 22, 1688, 13231, 1679, 13, 599, 697, 1047],
#  [30, 3, 1, 3042, 192, 7, 140, 294],
#  [248,
#   1293,
#   40,
#   11525,
#   1,
#   659,
#   5,
#   187,
#   2,
#   11,
#   14,
#   11,
#   10,
#   9,
#   49,
#   14,
#   32,
#   5,
#   63,
#   14,
#   12,
#   135],
#  [479,
#   17,
#   3223,
#   19,
#   430,
#   223,
#   5951,
#   2188,
#   1134,
#   42,
#   2416,
#   13232,
#   31793,
#   363,
#   15883,
#   10,
#   65,
#   12,
#   188,
#   5,
#   20318,
#   87,
#   430,
#   223,
#   5,
#   787,
#   422,
#   138,
#   55,
#   777,
#   299,
#   10,
#   223,
#   46,
#   31794,
#   1,
#   37],
#  [2, 12, 1, 706, 379, 4019, 1278, 6, 57],
#  [9, 11, 8, 91, 67, 363, 2013, 7270, 19, 12, 3311, 5, 18, 195],
#  [2, 295, 59, 4, 56, 514, 1095],
#  [63,
#   15,
#   50,
#   181,
#   23,
#   906,
#   142,
#   569,
#   667,
#   13,
#   29,
#   151,
#   3987,
#   50,
#   1159,
#   5,
#   118,
#   6,
#   6156,
#   6535,
#   302],
#  [63,
#   15,
#   1,
#   6828,
#   329,
#   1598,
#   7,
#   8234,
#   4,
#   3457,
#   8235,
#   27,
#   20319,
#   20320,
#   18504,
#   25,
#   3583,
#   379,
#   3,
#   17,
#   6,
#   4,
#   7271,
#   3312],
#  [9, 129, 12, 397, 9548, 636, 5, 94, 9548, 120, 42989, 1840, 6, 283],
#  [120, 1, 4063, 263, 525, 17072, 46, 4, 18505],
#  [40, 12, 1, 263, 31795, 6, 57],
#  [11,
#   14,
#   24,
#   51,
#   6157,
#   13,
#   4,
#   435,
#   1222,
#   45,
#   2936,
#   737,
#   6,
#   826,
#   223,
#   8,
#   81,
#   19,
#   17,
#   3,
#   236,
#   8966,
#   2272,
#   4328,
#   8,
#   117,
#   28,
#   3179,
#   818,
#   5,
#   7645,
#   17,
#   285],
#  [16, 11, 194, 37, 42, 5, 10214, 998],
#  [9, 15, 8, 538, 352, 5, 339, 43, 230, 3134],
#  [9, 72, 68, 3, 133, 929, 5, 144, 5172, 3640, 16],
#  [63, 15, 8, 144, 458, 43, 7824],
#  [12, 39, 65, 2596, 6, 1, 680, 71, 2109],
#  [40, 3, 42990, 10215, 42991],
#  [3, 39, 51, 305, 7, 147, 318, 19, 99, 25, 1521, 5, 21, 6829],
#  [9, 12, 704, 2030, 5475, 10216, 2, 10643, 12, 119],
#  [16, 12, 1, 215, 1013, 131, 42992],
#  [16, 31, 8, 106, 13, 442, 10, 44, 13, 4, 4107, 1030, 121, 4, 698, 147, 1680],
#  [12,
#   626,
#   138,
#   2613,
#   19,
#   47,
#   12,
#   52,
#   22762,
#   46,
#   31796,
#   548,
#   71,
#   92,
#   552,
#   123,
#   209,
#   88,
#   107],
#  [3, 188, 5, 130, 13, 377, 1369, 380, 17],
#  [2, 3, 1, 3042, 331, 7, 1, 4544, 18506, 8967],
#  [2, 31, 8, 81, 146, 1493, 6, 2594],
#  [2, 3, 1, 33, 78, 5, 1375, 132, 381, 1522, 831, 5, 1063, 6536, 7, 29, 2658],
#  [2, 12, 38, 561, 212, 5, 3774, 6537, 5, 1340, 85, 4, 1609],
#  [6,
#   1,
#   258,
#   485,
#   39,
#   705,
#   25,
#   722,
#   70,
#   1,
#   822,
#   10,
#   1,
#   727,
#   52,
#   17,
#   3,
#   2674,
#   5,
#   3380,
#   4,
#   4773,
#   485,
#   23,
#   4,
#   2197,
#   485,
#   22,
#   1,
#   1380,
#   7,
#   258,
#   3,
#   19,
#   173],
#  [41, 531, 90, 24, 4, 341, 325],
#  [9, 49, 1, 129, 532, 7, 18507, 7127, 3894],
#  [9, 72, 26, 17, 293, 13, 3937, 163, 630, 1780, 1044, 21, 4777, 4108],
#  [2, 12, 1, 803, 7, 250, 232],
#  [2, 12, 1, 353, 5, 898, 6, 1, 473, 108, 433, 5173, 42993],
#  [2, 3, 31797, 591, 557, 5, 454, 42994],
#  [2, 12, 38, 1045, 342, 7, 68, 400, 19, 149, 987, 1628],
#  [2, 3, 1, 516, 7, 42995, 26237],
#  [40, 3, 1, 33, 363, 764, 1165, 895, 6, 4778],
#  [9, 287, 99, 14, 179, 22, 774, 796, 4, 476],
#  [40, 3, 2020, 71, 1, 37, 7, 487, 1039, 10, 1, 37, 7, 487, 3065],
#  [2, 141, 58, 1, 784, 621, 7, 2976, 37],
#  [16, 49, 3641, 3938, 11, 2, 77, 49],
#  [2, 3, 2417, 10644, 23, 11066],
#  [11, 170, 8706, 1645, 366, 1, 267, 50, 854, 10, 24, 345],
#  [41, 1, 11526, 42996, 90, 25, 404],
#  [2,
#   288,
#   472,
#   52,
#   4492,
#   27,
#   3203,
#   5,
#   1678,
#   347,
#   10,
#   954,
#   189,
#   12586,
#   3939,
#   656,
#   42,
#   47,
#   96,
#   98,
#   546,
#   50,
#   24,
#   114,
#   17073,
#   67,
#   1123],
#  [6, 30, 960, 8440, 41, 25, 31798, 6, 632, 7, 116, 10, 2284],
#  [2,
#   12,
#   1,
#   1341,
#   10,
#   1305,
#   7,
#   4020,
#   8441,
#   18508,
#   42997,
#   3,
#   17,
#   53,
#   13,
#   406,
#   4149],
#  [40, 48, 26238, 31799],
#  [9, 11, 952, 1988, 1048, 5, 181, 1292, 30, 47, 207, 2870, 21, 55, 500],
#  [42998, 2182, 3, 9, 69, 17074],
#  [2, 3, 1, 2913, 7, 42999, 1142],
#  [16, 26, 1, 844, 223, 44, 448, 45, 1, 712, 7, 3276, 37],
#  [16,
#   3,
#   492,
#   85,
#   6,
#   2515,
#   45,
#   1,
#   113,
#   3381,
#   672,
#   4150,
#   938,
#   34,
#   1,
#   1435,
#   12,
#   1320,
#   7,
#   1,
#   2696,
#   40,
#   2209,
#   5,
#   15884,
#   64],
#  [48, 17, 3856, 34, 2469, 701, 481, 19, 50, 12, 12587, 17],
#  [15, 14, 818, 720, 28, 643, 22, 43000, 547, 6158],
#  [63, 11, 8, 91, 4, 4244, 3429, 13, 18, 868],
#  [2, 3, 1, 545, 640, 10, 252, 7, 545, 13, 4, 3204, 401, 6, 5036],
#  [2, 4437, 26, 1899, 726, 75],
#  [40, 12, 1, 33, 122, 5952],
#  [2, 3, 1, 129, 70, 590, 580, 10, 408, 2099, 580],
#  [16, 3254, 43001, 6, 703, 34, 2148, 6, 2695, 4898, 825],
#  [9, 3, 22763, 168, 13, 1124, 6, 22764],
#  [9, 11, 14, 378, 985, 5, 25, 4, 3066, 1233],
#  [2, 3, 43002],
#  [2,
#   35,
#   185,
#   20,
#   122,
#   92,
#   481,
#   43003,
#   7,
#   1238,
#   140,
#   345,
#   83,
#   17075,
#   3726,
#   10,
#   663,
#   10217,
#   7646,
#   10,
#   8707],
#  [9,
#   26,
#   1,
#   115,
#   1621,
#   217,
#   1054,
#   21,
#   1,
#   43004,
#   217,
#   7,
#   3812,
#   12588,
#   8030,
#   6,
#   386,
#   823],
#  [2, 295, 34, 14, 2122, 11527, 21, 2695, 22765],
#  [9,
#   26,
#   961,
#   1048,
#   55,
#   1595,
#   1734,
#   2545,
#   6,
#   1421,
#   11528,
#   17,
#   705,
#   25,
#   1534,
#   6,
#   408,
#   3554,
#   7,
#   1560,
#   1488,
#   148,
#   43,
#   109,
#   128,
#   6,
#   811],
#  [2, 15, 61, 4, 3158, 6055],
#  [20,
#   1,
#   2937,
#   325,
#   6670,
#   1,
#   744,
#   2418,
#   77,
#   4385,
#   75,
#   17,
#   5,
#   1818,
#   67,
#   88,
#   5765,
#   10,
#   95,
#   4659],
#  [16,
#   11,
#   573,
#   66,
#   256,
#   901,
#   13,
#   87,
#   5,
#   356,
#   515,
#   21,
#   4,
#   175,
#   62,
#   20,
#   154,
#   2221,
#   877,
#   110,
#   186,
#   515,
#   164,
#   22,
#   176,
#   77,
#   902,
#   2546],
#  [24,
#   14,
#   6269,
#   76,
#   19,
#   1745,
#   14,
#   10,
#   9,
#   49,
#   14,
#   2083,
#   21,
#   1,
#   690,
#   19,
#   14,
#   933,
#   87],
#  [16, 26, 598, 214, 10, 728, 24, 613, 216],
#  [9,
#   206,
#   1223,
#   1861,
#   15,
#   75,
#   43005,
#   18509,
#   6,
#   1,
#   2435,
#   7,
#   1,
#   2210,
#   311,
#   10,
#   131,
#   44,
#   32,
#   2456,
#   46,
#   1,
#   7128],
#  [63, 3, 1, 33, 681, 589, 63, 105, 43006, 3, 456],
#  [2, 12, 1, 33, 1862, 5, 149, 14, 1035, 43007],
#  [26,
#   4,
#   6671,
#   101,
#   137,
#   9249,
#   9549,
#   24,
#   5,
#   25,
#   26239,
#   5,
#   4,
#   5571,
#   2062,
#   6,
#   113,
#   1294],
#  [2,
#   3,
#   1,
#   347,
#   988,
#   19,
#   1353,
#   705,
#   25,
#   11067,
#   134,
#   2419,
#   13,
#   55,
#   2914,
#   338,
#   7,
#   38,
#   1820],
#  [2, 3, 1, 60, 119, 2572, 6, 51, 453, 216],
#  [8,
#   48,
#   886,
#   22,
#   4109,
#   3382,
#   12037,
#   6,
#   423,
#   43,
#   43008,
#   638,
#   36,
#   513,
#   22766,
#   18,
#   152,
#   224,
#   3,
#   497,
#   10,
#   74,
#   1746,
#   3,
#   395,
#   15,
#   8,
#   131,
#   106,
#   102,
#   962,
#   1143],
#  [16,
#   12,
#   1553,
#   10,
#   1022,
#   31800,
#   129,
#   1629,
#   14846,
#   16,
#   828,
#   472,
#   129,
#   1629,
#   731,
#   564,
#   20,
#   47,
#   362,
#   431,
#   13233,
#   138,
#   4,
#   1569,
#   948],
#  [2, 3, 1, 60, 213, 702, 7, 4, 53, 949],
#  [2, 31, 29, 4438, 11, 5, 32, 79, 7, 1, 2820],
#  [9, 15, 8, 166, 18, 17076, 264, 4493, 27, 18, 500],
#  [36, 4, 420, 11, 14, 24, 65, 1210, 13, 4, 510, 104, 23, 4, 1322, 7, 2198],
#  [16, 12, 22767, 748, 52, 20321],
#  [3857, 486, 169, 2258, 30, 141],
#  [30, 12, 1, 33, 826, 445, 608, 6, 57],
#  [9,
#   49,
#   17,
#   98,
#   42,
#   5,
#   553,
#   1,
#   667,
#   10,
#   1298,
#   45,
#   3382,
#   726,
#   605,
#   932,
#   36,
#   29,
#   211],
#  [15885, 4, 101, 59, 4, 5297],
#  [2, 3, 1, 15886, 43009, 4837, 7],
#  [9, 15, 1, 797, 7, 948, 25, 17077],
#  [9,
#   49,
#   1828,
#   43010,
#   1048,
#   5,
#   43011,
#   129,
#   2357,
#   102,
#   1,
#   60,
#   8236,
#   2124,
#   6,
#   1,
#   1006,
#   1,
#   31801,
#   482],
#  [2, 12, 1, 8968, 14, 15, 1020, 6, 1, 1101, 43012, 26240, 135, 3858],
#  [9, 12, 1, 31802, 1299, 7, 1, 26241, 9250, 6268, 130, 42],
#  [20,
#   50,
#   9550,
#   1805,
#   7,
#   322,
#   46,
#   55,
#   469,
#   580,
#   13234,
#   35,
#   37,
#   98,
#   100,
#   45,
#   1215,
#   1600],
#  [2, 12, 38, 2529, 762, 45, 2012, 1469],
#  [11,
#   50,
#   24,
#   5,
#   1793,
#   67,
#   137,
#   5387,
#   8442,
#   6,
#   1,
#   2389,
#   2189,
#   3098,
#   7,
#   1781,
#   1515,
#   2573,
#   568],
#  [2, 3, 1, 33, 78, 5, 541, 2470, 5871, 6, 108, 441],
#  [2, 12, 1, 239, 3727, 13, 253, 10, 4064, 201],
#  [120, 28, 588, 22, 11068, 13235],
#  [16, 12, 60, 7, 1, 37, 42, 1098, 1581],
#  [2, 11, 5037, 84],
#  [9,
#   1989,
#   10,
#   4065,
#   3,
#   43013,
#   449,
#   2326,
#   3895,
#   20322,
#   602,
#   13,
#   9,
#   5,
#   444,
#   10,
#   3095,
#   1,
#   4600,
#   5298,
#   138,
#   68],
#  [3, 18510, 6672, 6, 17078],
#  [9, 58, 1, 1630, 320, 7, 31803, 43014, 3725, 3988, 336, 17, 48, 2110],
#  [15,
#   8,
#   32,
#   102,
#   4,
#   53,
#   442,
#   139,
#   20,
#   8,
#   145,
#   8443,
#   259,
#   5,
#   25,
#   2282,
#   6,
#   758,
#   210],
#  [8708, 3, 1, 1221, 7, 4289],
#  [40, 41, 1735, 46, 884, 128, 101, 8709, 22, 633, 6, 5766],
#  [2, 3, 1, 33, 846, 1554, 13, 6975, 13, 4838, 2574, 7, 68, 6, 129, 7272],
#  [2, 3, 1, 226, 4110, 6, 57, 513, 152],
#  [16, 2327, 6419, 959, 5, 1203],
#  [2, 12, 38, 645, 608, 13, 792, 4, 9251, 5299],
#  [2, 12, 1, 15887, 1255, 7, 214],
#  [2, 3, 591, 7, 12589, 70, 5476, 22, 1, 22768, 10, 17079],
#  [35,
#   12038,
#   1293,
#   2729,
#   576,
#   484,
#   2716,
#   36,
#   65,
#   1014,
#   23,
#   44,
#   2729,
#   17,
#   43,
#   67],
#  [2,
#   12,
#   745,
#   540,
#   456,
#   5,
#   32,
#   4,
#   107,
#   13,
#   3775,
#   217,
#   401,
#   6,
#   3813,
#   23,
#   1963,
#   169],
#  [8,
#   260,
#   4021,
#   6,
#   218,
#   686,
#   6,
#   1462,
#   135,
#   8,
#   80,
#   6,
#   125,
#   101,
#   7,
#   274,
#   1189,
#   15,
#   8,
#   145,
#   686,
#   259,
#   495,
#   27,
#   582,
#   5,
#   460,
#   815],
#  [9, 15, 8, 1315, 1, 906, 634, 7, 4, 1331, 270],
#  [9, 15, 50, 1234, 76, 6, 1390],
#  [20,
#   4,
#   43015,
#   3,
#   188,
#   1734,
#   2994,
#   513,
#   1488,
#   22,
#   4,
#   13236,
#   35,
#   4,
#   7825,
#   4779,
#   273,
#   22,
#   1,
#   560,
#   7,
#   1,
#   1372,
#   1694,
#   5,
#   855],
#  [36, 4, 6056, 31804, 2, 48, 28, 586, 500, 10, 2, 3, 17, 135],
#  [16, 89, 1344, 1247, 7, 2849, 10, 4716, 119, 13, 129, 1134, 7, 37],
#  [9, 11, 14, 5670, 28, 797, 10, 460, 28, 2184, 427],
#  [40, 6270, 1029],
#  [5, 3255, 36, 4, 786, 2, 815, 7, 448, 35, 14, 26242],
#  [3, 214, 1, 353, 257],
#  [2, 35, 25, 1, 60, 43016, 576, 191, 6, 1, 353, 4601],
#  [35, 4, 486, 13982, 142, 25, 4, 53, 405, 6, 3041],
#  [31, 37, 166, 6534, 45, 1085, 10, 118, 6534, 45, 1867, 455],
#  [49, 7129, 43017, 26243, 1, 18511, 7, 1, 527, 1452],
#  [9, 11, 14, 42, 31805],
#  [2, 12, 38, 342, 7, 163, 630, 13, 1561, 756, 6, 1, 94],
#  [8,
#   1666,
#   4,
#   4013,
#   2659,
#   19,
#   14847,
#   85,
#   1,
#   3021,
#   134,
#   1172,
#   234,
#   43,
#   514,
#   17,
#   48,
#   204,
#   499,
#   10,
#   512,
#   61,
#   4,
#   682,
#   2,
#   99,
#   17,
#   24,
#   114],
#  [9, 3, 15888, 139, 13, 4839],
#  [30, 6271, 3, 456, 22, 5767, 2222, 411],
#  [2, 12, 1, 5477, 6159, 22, 4, 10645, 11529],
#  [4386,
#   12,
#   1,
#   1288,
#   13,
#   4,
#   175,
#   40,
#   58,
#   170,
#   21,
#   110,
#   474,
#   43,
#   1,
#   267,
#   7,
#   736],
#  [63, 15, 8, 205, 4, 3021, 417, 7, 2109, 43, 514],
#  [16, 18, 17080, 12, 44, 3180, 6, 43018, 6],
#  [20,
#   8,
#   519,
#   5,
#   157,
#   3584,
#   14,
#   6,
#   3728,
#   216,
#   43,
#   4,
#   3728,
#   9860,
#   41,
#   37,
#   3313,
#   43,
#   54],
#  [26, 1, 3940, 167, 4494, 27, 101, 5, 101],
#  [2, 48, 9861, 42, 13, 3205, 10646],
#  [2, 3, 1, 127, 70, 18512, 10, 461, 737, 839],
#  [9,
#   35,
#   14,
#   934,
#   20,
#   28,
#   2660,
#   1153,
#   9862,
#   2977,
#   162,
#   154,
#   247,
#   24,
#   245,
#   43,
#   130],
#  [592,
#   114,
#   1990,
#   2530,
#   5,
#   64,
#   801,
#   62,
#   1000,
#   8,
#   24,
#   663,
#   5,
#   42,
#   176,
#   9,
#   15,
#   8,
#   32,
#   88,
#   1520,
#   6,
#   4,
#   832,
#   78],
#  [16, 18, 43019, 5953, 44, 82, 62, 2978, 1376, 3, 1841],
#  [2, 26, 4602, 4, 5038, 21, 4, 31806, 717, 116],
#  [2, 89, 38, 7, 1, 60, 31807, 7, 1, 43020, 1080, 19, 1909, 79],
#  [30, 225, 12, 33, 13, 633, 26244],
#  [3, 17, 111, 13, 4, 5954, 5, 145, 4202, 11069],
#  [16,
#   26,
#   1,
#   211,
#   368,
#   519,
#   5,
#   61,
#   37,
#   7,
#   948,
#   2420,
#   1848,
#   9551,
#   394,
#   199,
#   158],
#  [2, 12, 1, 6160, 7, 6538, 8969, 10218, 13, 1535, 435],
#  [3, 17, 4, 173, 1002, 5, 11, 442, 173, 59, 147],
#  [15, 966, 5388, 25, 3941, 4022, 21, 4, 423, 168, 139],
#  [26, 4439, 950, 58, 4840, 23, 1173, 950],
#  [22,
#   30,
#   13983,
#   31808,
#   7,
#   4717,
#   58,
#   5,
#   25,
#   6539,
#   6,
#   4290,
#   11530,
#   1271,
#   43021,
#   23,
#   330,
#   398,
#   23,
#   128,
#   2210,
#   1772,
#   7,
#   4960],
#  [9,
#   631,
#   3,
#   17,
#   379,
#   5,
#   61,
#   29,
#   2169,
#   6420,
#   1182,
#   93,
#   160,
#   29,
#   2169,
#   6420,
#   1182],
#  [16, 49, 7454, 26245, 4245, 27, 1, 2313, 297, 1, 2495, 10, 687, 7454, 297],
#  [34,
#   8,
#   1332,
#   27,
#   236,
#   4013,
#   5,
#   236,
#   905,
#   8,
#   32,
#   31809,
#   9252,
#   16,
#   26,
#   19,
#   185,
#   10,
#   2,
#   3,
#   1,
#   6673,
#   825,
#   13,
#   17],
#  [120, 1906, 6, 43022, 6830],
#  [8,
#   276,
#   6540,
#   10,
#   4961,
#   85,
#   122,
#   3,
#   1720,
#   10,
#   277,
#   11,
#   14,
#   276,
#   1,
#   136,
#   8,
#   66,
#   165,
#   31,
#   306,
#   1035,
#   55,
#   22769,
#   2,
#   11,
#   14,
#   66],
#  [9,
#   729,
#   11,
#   14,
#   66,
#   14,
#   35,
#   25,
#   5,
#   1238,
#   2401,
#   466,
#   10,
#   377,
#   6,
#   2084,
#   1317,
#   10,
#   9,
#   11,
#   14,
#   156,
#   17,
#   82,
#   8710],
#  [15, 4, 2344, 3277, 25, 4, 238, 22770, 67, 88, 74, 21, 105, 78, 7, 9552, 37],
#  [2, 26, 1, 9863, 436, 5389, 438, 7826, 6, 163, 130],
#  [15, 50, 852, 8711],
#  [9, 11, 8, 43023, 18, 2210, 1043, 1721],
#  [2, 12, 1, 1794, 1198, 119, 6, 1, 155, 1377, 7, 1, 1372, 46, 17081, 26246],
#  [2, 3, 1, 293, 17082],
#  [2, 12, 1, 212, 5, 144, 4, 453, 216],
#  [3, 2125, 4, 2417, 1523, 71, 123, 818, 61, 4, 957, 632, 13, 28, 2531],
#  [16,
#   31,
#   8,
#   181,
#   4,
#   1747,
#   13,
#   65,
#   71,
#   736,
#   20,
#   8,
#   15,
#   2223,
#   1,
#   136,
#   1747,
#   27,
#   2788,
#   606,
#   6,
#   292,
#   71,
#   108],
#  [3, 17, 111, 19, 73, 37, 15, 268, 18, 2611],
#  [11, 50, 131, 24, 9553, 10219, 6, 1, 367, 281, 23, 12, 47, 843],
#  [9,
#   69,
#   37,
#   6,
#   3206,
#   448,
#   19,
#   1,
#   12039,
#   12,
#   6,
#   2468,
#   10,
#   41,
#   6532,
#   2046,
#   13,
#   87],
#  [2, 12, 1, 532, 7, 231, 1, 9864],
#  [2, 26, 4, 163, 4545, 2823, 199, 42, 34, 47, 86, 55, 3985, 231],
#  [3, 2961, 437, 13, 920, 5, 339],
#  [2,
#   3,
#   1,
#   195,
#   7,
#   1,
#   677,
#   19,
#   48,
#   877,
#   6,
#   1,
#   707,
#   10,
#   12590,
#   2248,
#   63,
#   43024,
#   48,
#   21,
#   88,
#   628,
#   6,
#   1,
#   916],
#  [15, 11531, 25, 119, 6, 4546, 1340, 6, 3814, 299, 1381, 13, 4546, 1637],
#  [63, 11, 4899, 3894],
#  [9, 15, 8, 219, 18, 518, 799, 19, 8, 35, 42, 5, 25, 245],
#  [48,
#   1,
#   15889,
#   5300,
#   7,
#   214,
#   3067,
#   46,
#   194,
#   37,
#   162,
#   39,
#   89,
#   194,
#   31810,
#   6,
#   1,
#   18513,
#   7,
#   1,
#   15889,
#   37],
#  [2, 3, 65, 43025, 5, 460, 1193, 912, 23, 6976],
#  [2, 3, 1, 33, 2100, 279, 6, 12591],
#  [30, 3642, 6, 1, 227, 191, 1635, 43, 5955, 221, 12, 1542],
#  [2, 3, 3383, 445, 5237, 10, 16, 3, 17, 792, 11070, 1849],
#  [16, 48, 1, 31811, 1689, 26247, 31812, 43026, 570, 632, 52, 3159],
#  [48, 5238, 2481],
#  [2, 3, 1, 33, 78, 5, 32, 29, 1117, 6, 2675],
#  [2, 3, 4, 53, 195, 13, 4, 18514, 169],
#  [16, 11, 6421, 7, 7827, 12, 44, 5385],
#  [16, 48, 1, 20323, 6977, 962, 389, 43027],
#  [2, 2891, 15, 8, 723, 13, 4, 351, 70, 2421, 3382, 6, 7273, 210],
#  [2, 12, 1, 8966, 1846, 2995, 233, 2915, 124, 5, 144, 23, 131, 117, 5, 144],
#  [30, 12, 1, 10220, 2547],
#  [2,
#   12,
#   12592,
#   1037,
#   6,
#   139,
#   10,
#   9,
#   11,
#   47,
#   82,
#   3,
#   39,
#   4,
#   939,
#   4023,
#   13,
#   87,
#   23,
#   26,
#   17,
#   3776,
#   22,
#   1,
#   318,
#   9,
#   26,
#   17,
#   82,
#   13,
#   29,
#   436,
#   11532,
#   318],
#  [16, 26, 18, 5174, 66, 1, 504, 3, 4780, 67, 1, 68, 282, 1748, 475],
#  [9, 8, 155, 18, 2850, 2108],
#  [15,
#   14,
#   1868,
#   4,
#   662,
#   1142,
#   5,
#   4,
#   3019,
#   136,
#   170,
#   240,
#   23,
#   607,
#   27,
#   4,
#   662,
#   1142,
#   5,
#   1,
#   8970,
#   882,
#   19,
#   4,
#   104,
#   3,
#   4440],
#  [2, 12, 1, 177, 4246, 19, 24, 1, 136, 2199, 7, 604],
#  [9, 49, 177, 37, 812, 146, 39, 89, 17083],
#  [9, 15, 14, 195, 4, 3777, 465],
#  [30, 4151, 24, 3555, 43028, 11071],
#  [31,
#   1700,
#   1524,
#   5239,
#   2014,
#   1582,
#   1,
#   136,
#   78,
#   17,
#   26,
#   2198,
#   1582,
#   336,
#   283,
#   356,
#   4,
#   331,
#   6,
#   1,
#   1174,
#   7,
#   1066],
#  [9, 11, 14, 671, 232, 6, 139],
#  [9, 69, 37, 81, 45, 694, 1915],
#  [16,
#   26,
#   2749,
#   6057,
#   3,
#   3778,
#   6,
#   5872,
#   3314,
#   5,
#   6674,
#   1142,
#   21,
#   5572,
#   6,
#   43029,
#   43030,
#   1142],
#  [2, 12, 324, 445, 1121],
#  [63, 3, 1, 717, 22, 4, 26248],
#  [63,
#   15,
#   8,
#   681,
#   317,
#   410,
#   13,
#   13984,
#   1420,
#   225,
#   10647,
#   7,
#   142,
#   347,
#   4111,
#   2962,
#   46,
#   20324,
#   43031],
#  [9, 15, 8, 32, 4, 196, 15890, 436],
#  [11, 14, 90, 166, 700, 45, 2, 431, 66, 7, 14],
#  [20,
#   4,
#   1160,
#   1370,
#   252,
#   876,
#   22,
#   1,
#   337,
#   286,
#   1426,
#   2436,
#   30,
#   141,
#   35,
#   24,
#   8971],
#  [2, 3, 1, 1829, 7, 8444],
#  [2, 3, 1, 500, 7, 129, 7828, 6, 43032],
#  [34, 31, 8, 9865, 76, 45, 238, 1004],
#  [2, 31, 25, 251, 46, 1, 325, 7, 6052, 5, 987, 293, 7, 333],
#  [3, 17, 437, 5, 642, 7455, 6, 4603, 210, 1127, 1, 667, 7, 111, 10644, 14848],
#  [9, 11, 8, 11, 43033, 652, 3315],
#  [2, 12, 38, 53, 212, 5, 61, 126, 22, 1, 560, 93, 4, 289, 68, 7456],
#  [3, 17, 4, 53, 405, 5, 407, 4, 1551, 6, 17084],
#  [26, 17085, 24, 4, 26249, 6161],
#  [9, 69, 37, 11525, 27, 26250, 4016],
#  [16, 3, 18, 108, 476, 3859, 20325],
#  [1,
#   1248,
#   48,
#   870,
#   138,
#   3554,
#   7,
#   112,
#   46,
#   69,
#   4718,
#   40,
#   67,
#   3347,
#   45,
#   1,
#   136,
#   319,
#   247,
#   19,
#   145,
#   1,
#   1248,
#   38,
#   1889,
#   7,
#   8237],
#  [9, 15, 8, 32, 29, 17086, 712, 13, 5301, 10, 3942, 5301],
#  [3, 17, 695, 5, 14849, 28, 628, 13, 2749, 28, 6831],
#  [9, 3, 74, 59, 1924, 13, 122],
#  [16,
#   11,
#   337,
#   286,
#   8445,
#   7,
#   691,
#   422,
#   1105,
#   22,
#   1,
#   5956,
#   622,
#   305,
#   6058,
#   34,
#   2730,
#   3860,
#   1160,
#   4329,
#   43034,
#   3779,
#   6058,
#   7,
#   67,
#   532,
#   264,
#   13,
#   6422,
#   45,
#   108,
#   7,
#   67,
#   8031,
#   8446],
#  [2, 101, 49, 1026, 118, 182, 547],
#  [3, 39, 51, 53, 151, 196, 1125, 5, 144, 4495],
#  [2, 12, 1, 759, 7, 174, 4, 107, 20, 76, 58, 2211, 55, 43035, 43, 736, 27, 94],
#  [2, 3, 1, 516, 7, 269, 2133, 10, 3043, 6, 4, 6059, 3518, 465],
#  [2, 49, 14, 195, 28, 345, 10, 16],
#  [2, 48, 1, 125, 26251, 14, 7457, 5, 5390],
#  [12, 55, 20326, 6, 402],
#  [2, 3, 1, 60, 213, 31813],
#  [2, 3, 1, 3896, 513, 7829, 7, 1373],
#  [2377,
#   13237,
#   45,
#   1,
#   2851,
#   7647,
#   7830,
#   3,
#   17,
#   1489,
#   19,
#   13238,
#   796,
#   31814,
#   3181,
#   27,
#   1373,
#   89,
#   43036,
#   102,
#   2377,
#   59,
#   1,
#   20323,
#   881,
#   7648,
#   7,
#   3181,
#   13,
#   386,
#   10221,
#   21,
#   6675],
#  [9, 425, 1989, 3, 4, 43037, 11072],
#  [2, 4203, 2224, 12, 2249, 13, 31815],
#  [9, 8, 15, 95, 4, 43038, 27, 5175, 221],
#  [2, 58, 502, 5, 1, 31816, 7130, 6, 43039, 9866],
#  [2, 12, 1, 2357, 7, 1, 1006, 446, 7, 1, 13239, 46, 18515, 22771],
#  [3,
#   1,
#   26252,
#   285,
#   7,
#   1,
#   881,
#   10,
#   1,
#   471,
#   7,
#   2871,
#   700,
#   562,
#   36,
#   4,
#   1312,
#   331,
#   7,
#   1,
#   5573,
#   975,
#   5,
#   940,
#   2963,
#   5,
#   1,
#   806],
#  [49, 43040, 92, 3068, 3, 17, 138],
#  [11,
#   37,
#   459,
#   19,
#   2390,
#   126,
#   22,
#   26253,
#   1099,
#   60,
#   7,
#   17,
#   1328,
#   22,
#   1215,
#   10,
#   545,
#   43041,
#   2238,
#   126,
#   102,
#   484,
#   3,
#   56,
#   78,
#   14,
#   15,
#   145,
#   545,
#   10,
#   384,
#   13,
#   37],
#  [2,
#   11,
#   14,
#   11,
#   34,
#   14,
#   1298,
#   193,
#   788,
#   6,
#   1,
#   673,
#   7,
#   1,
#   514,
#   134,
#   14,
#   12,
#   6,
#   1638],
#  [12, 2328, 7830, 10, 2422, 7830, 129, 189],
#  [2,
#   1352,
#   31,
#   4,
#   175,
#   235,
#   6,
#   501,
#   20,
#   154,
#   593,
#   5,
#   790,
#   36,
#   4,
#   284,
#   134,
#   7131],
#  [2,
#   11,
#   211,
#   1468,
#   66,
#   45,
#   1,
#   4719,
#   341,
#   40,
#   10648,
#   110,
#   878,
#   13,
#   83,
#   510,
#   3,
#   17,
#   29,
#   646,
#   7,
#   989,
#   1371],
#  [2, 12, 38, 7, 1, 33, 688, 7, 8447, 6, 1964],
#  [20,
#   1,
#   6162,
#   969,
#   3,
#   44,
#   2938,
#   5,
#   4,
#   6832,
#   3,
#   19,
#   1,
#   136,
#   36,
#   1,
#   969,
#   229,
#   48,
#   6162,
#   5,
#   1,
#   1570],
#  [2, 3, 9867, 436, 10, 2, 12, 1, 803, 7, 5571, 1562, 550, 9867, 436],
#  [2, 3, 85, 21, 17087, 2804, 5039],
#  [2, 3, 22772, 974],
#  [2, 3, 1, 757, 4496, 7, 1, 22773, 17088],
#  [9, 15, 8, 43042, 700, 7, 1605, 36, 4, 2147],
#  [3, 713, 5957, 204, 387],
#  [24, 14, 90, 1830, 19, 14, 2614, 2788],
#  [15,
#   171,
#   1667,
#   1,
#   68,
#   10,
#   706,
#   19,
#   739,
#   6,
#   1,
#   94,
#   2938,
#   27,
#   5768,
#   2471,
#   22774,
#   374,
#   5,
#   1224,
#   13240],
#  [30, 152, 3, 1, 173, 152, 5, 106, 5, 1722, 7274, 23, 6272],
#  [2, 12, 38, 7, 31817, 43043, 303, 1122, 36, 29, 211, 1092, 1116],
#  [3,
#   2270,
#   22,
#   4,
#   10222,
#   23,
#   1101,
#   10649,
#   853,
#   131,
#   304,
#   13985,
#   23,
#   3,
#   17,
#   22775],
#  [9, 26, 238, 82, 149, 4, 104],
#  [16, 11, 37, 2805, 22, 55, 43044],
#  [2,
#   35,
#   14,
#   11,
#   20,
#   28,
#   483,
#   2770,
#   5,
#   110,
#   243,
#   6,
#   55,
#   1225,
#   216,
#   6,
#   941,
#   7,
#   14],
#  [26,
#   83,
#   8238,
#   1090,
#   56,
#   902,
#   8448,
#   27,
#   8712,
#   10223,
#   938,
#   16,
#   247,
#   103,
#   86,
#   1087,
#   220,
#   103,
#   301,
#   1323,
#   6423,
#   13,
#   348,
#   704,
#   57,
#   1710,
#   22,
#   4441,
#   198],
#  [3, 6541, 1, 8713, 7, 2996, 253],
#  [2, 3, 28, 464, 2248, 27, 1, 18516, 7, 5103, 43045, 31818],
#  [2, 3, 1, 60, 1991, 825, 5, 1910, 999],
#  [2, 12, 19, 1, 12593, 2787, 169, 3224, 5, 1, 962, 528],
#  [9, 3, 17, 5, 183, 2085, 619, 255, 43, 2212, 3685, 168, 7, 1285],
#  [9, 11, 8, 3519, 18, 5478, 10, 32, 4, 107, 1186],
#  [16, 12, 3022, 14850, 119, 6, 776, 26254],
#  [40, 48, 3685, 18517, 6833],
#  [63, 3, 15891, 9868],
#  [12,
#   31819,
#   12594,
#   456,
#   5,
#   7458,
#   75,
#   28,
#   13986,
#   351,
#   23,
#   15,
#   47,
#   517,
#   28,
#   43046,
#   351,
#   36,
#   287],
#  [8, 98, 9554, 46, 546, 36, 18, 1057, 9555, 54, 9, 15, 8, 3063, 64, 5569],
#  [41, 17, 25, 111, 13, 701, 5, 4487, 37, 495, 6, 1477],
#  [2, 12, 1, 490, 7, 403, 4, 1245, 27, 17089, 5, 43047],
#  [12, 1389, 6163, 131, 478, 8449, 6, 1, 337, 286],
#  [9, 15, 8, 385, 13, 2821, 13987],
#  [15,
#   43048,
#   7831,
#   613,
#   5,
#   13988,
#   355,
#   25,
#   9253,
#   36,
#   4,
#   439,
#   2457,
#   619,
#   634,
#   9,
#   41,
#   64,
#   366,
#   2516,
#   525],
#  [31, 8, 86, 241, 2676, 1037, 6, 1506, 1036],
#  [2, 993, 3, 1, 33, 13, 1664, 10, 1630, 147],
#  [16, 11, 37, 66, 1212, 48, 1478, 34, 77, 1016, 77, 48, 209, 53],
#  [9,
#   11,
#   8,
#   868,
#   29,
#   151,
#   2575,
#   169,
#   34,
#   8,
#   24,
#   105,
#   690,
#   205,
#   23,
#   6834,
#   569,
#   5,
#   17],
#  [2, 3, 1, 1017, 5, 95, 5769, 6, 582, 1679],
#  [9, 11, 8, 812, 4, 341, 52, 8, 15, 339, 110, 5176],
#  [2, 207, 920, 339],
#  [9, 69, 7125, 7, 10224, 41, 25, 929, 5, 934, 21, 203, 395, 984, 7, 18518],
#  [16, 12, 18, 979, 6424, 85, 34, 8, 8450],
#  [35, 14, 84, 5, 842, 2200, 21, 477, 123, 10, 2, 11, 14, 66, 19, 35, 25, 42],
#  [34,
#   1,
#   337,
#   286,
#   558,
#   2750,
#   48,
#   870,
#   39,
#   89,
#   105,
#   3686,
#   2847,
#   6058,
#   178,
#   16,
#   31,
#   370,
#   25,
#   3182,
#   46,
#   1,
#   1795],
#  [336,
#   1,
#   113,
#   580,
#   1185,
#   288,
#   1,
#   4660,
#   5,
#   1,
#   822,
#   2170,
#   15,
#   64,
#   90,
#   167,
#   20,
#   1010,
#   32,
#   422,
#   7,
#   1484,
#   23,
#   3,
#   1,
#   580,
#   634,
#   1010,
#   24,
#   5,
#   660,
#   36,
#   287],
#  [2, 1398, 26, 9254, 1315, 56, 27, 1796],
#  [30, 3, 100, 13, 1047, 402, 7459, 23, 18519, 6835],
#  [2,
#   11,
#   4066,
#   6676,
#   156,
#   19,
#   4,
#   1827,
#   4066,
#   2082,
#   41,
#   229,
#   156,
#   34,
#   9556,
#   4,
#   4066,
#   543],
#  [9, 11, 8, 61, 6978, 45, 130, 1916, 13, 6978, 348, 2771],
#  [2, 12, 1, 772, 7, 4, 227, 5177, 279],
#  [9, 11, 14, 61, 1, 330, 4896],
#  [2, 3, 43049, 217, 22776],
#  [16,
#   11,
#   357,
#   4547,
#   2517,
#   322,
#   13,
#   55,
#   4547,
#   43,
#   26255,
#   34,
#   47,
#   15,
#   730,
#   17,
#   564],
#  [2, 12, 38, 150, 5, 11, 22, 4, 3897, 5, 11073, 537],
#  [2, 3, 1, 5671, 331, 6, 273, 2111],
#  [16, 11, 14, 553, 7832, 364, 473],
#  [2, 3, 1, 1006, 1, 11533, 31820, 45],
#  [3, 43050, 697, 4, 331, 7, 20327, 697],
#  [2, 3, 1, 2249, 1821, 5, 987, 2697, 819],
#  [3, 570, 2201, 6273, 7275],
#  [9, 26, 4, 14851, 32, 4067, 59, 12040, 3406, 7, 623],
#  [16, 89, 1, 2012, 18520, 2518, 1842],
#  [382, 11, 14, 308, 28, 824],
#  [2,
#   12,
#   1,
#   33,
#   142,
#   856,
#   6,
#   1908,
#   173,
#   135,
#   21,
#   29,
#   780,
#   7,
#   17090,
#   11534,
#   30,
#   1793,
#   4387,
#   17091,
#   4387,
#   4841,
#   1869,
#   10,
#   43051],
#  [16, 12, 8714, 3099, 7, 1965, 6, 535],
#  [16,
#   11,
#   69,
#   37,
#   276,
#   19,
#   1,
#   367,
#   2939,
#   4388,
#   678,
#   153,
#   1,
#   2134,
#   2576,
#   228,
#   7,
#   10225,
#   34,
#   6,
#   882,
#   2032,
#   2576,
#   4604,
#   124,
#   26256,
#   21,
#   1,
#   527,
#   6,
#   1,
#   22777,
#   8032,
#   10,
#   6,
#   4112],
#  [2, 3, 1, 1701, 7, 5302, 224],
#  [9, 11, 8, 61, 18, 786, 459, 19, 77, 31, 44, 986, 18, 488, 22778, 12595],
#  [2, 12, 1, 1479, 14, 12, 6, 143, 21, 4, 1057],
#  [34, 14, 4024, 108, 8239, 2, 3, 1, 692, 19, 14, 15, 32, 4, 1930, 7, 659],
#  [2, 20, 1, 1411, 48, 128, 6542, 957],
#  [9, 11, 8, 5040],
#  [16,
#   26,
#   17,
#   98,
#   42,
#   1,
#   573,
#   40,
#   327,
#   42,
#   54,
#   12,
#   44,
#   778,
#   10,
#   778,
#   37,
#   1467,
#   8,
#   24,
#   4,
#   889,
#   22,
#   96,
#   42,
#   54,
#   164],
#  [2, 3, 1120, 31821],
#  [2, 3, 1, 33, 78, 5, 480, 4, 7460, 13, 2516, 899, 2577],
#  [2, 26, 289, 195, 1771, 116],
#  [15,
#   50,
#   3780,
#   29,
#   8033,
#   2149,
#   93,
#   1226,
#   159,
#   2239,
#   1367,
#   9,
#   5041,
#   3,
#   17,
#   5,
#   317,
#   22,
#   67,
#   111,
#   8972],
#  [2, 12, 1, 60, 5958, 1227, 7, 1, 216, 119, 46, 6677],
#  [9, 15, 8, 25, 4, 53, 3429, 2126],
#  [58, 1, 3069, 7, 165, 3986, 285, 1279, 4, 97, 3687, 4497, 6, 848],
#  [16, 49, 38, 489, 10, 67, 3643, 7, 87, 3861, 59, 8, 9869, 2032, 198],
#  [9, 15, 8, 595, 85, 2847, 1377, 13, 67, 2298, 1582, 6, 18, 142, 1233],
#  [2, 3, 1, 354, 500, 13, 4, 1870, 6, 9557, 36, 29, 17092, 3278],
#  [9,
#   15,
#   123,
#   61,
#   4,
#   1966,
#   45,
#   1,
#   6060,
#   6,
#   1963,
#   83,
#   1962,
#   2677,
#   34,
#   77,
#   3585,
#   4,
#   1185,
#   26257,
#   4498,
#   22,
#   1,
#   9558,
#   7,
#   1269,
#   5,
#   1,
#   1962,
#   2677],
#  [2,
#   3431,
#   2135,
#   50,
#   723,
#   20,
#   8,
#   660,
#   28,
#   6678,
#   10,
#   26258,
#   1052,
#   1736,
#   1974,
#   1,
#   101],
#  [29, 128, 764, 128, 764, 2, 3, 7833, 43052, 764, 29],
#  [2, 3, 1, 33, 3044, 155, 13, 4, 829, 184],
#  [49, 171, 842, 2200, 10, 113, 112, 67, 963, 11, 14, 98, 3407],
#  [9, 15, 50, 32, 26259, 6, 43053, 84, 5, 81, 944, 320],
#  [2, 3, 29, 22779, 43054],
#  [9, 48, 22780, 1668],
#  [11, 14, 66, 1, 373, 211, 5303, 41, 25, 2979, 102, 69, 1499, 56, 152],
#  [9,
#   10,
#   2,
#   78,
#   15,
#   4,
#   184,
#   10,
#   1571,
#   2482,
#   5,
#   61,
#   1,
#   130,
#   751,
#   1,
#   184,
#   6,
#   1,
#   130,
#   217,
#   36,
#   4,
#   829],
#  [2, 12, 38, 31822, 4152, 2124, 19, 61, 1468, 3183],
#  [2, 351, 5042, 3, 456, 5, 351, 4, 2112, 2891, 6, 13989, 57],
#  [11,
#   14,
#   66,
#   341,
#   48,
#   172,
#   935,
#   13,
#   222,
#   2,
#   846,
#   1227,
#   26,
#   341,
#   24,
#   2295,
#   13,
#   222,
#   19,
#   11535,
#   13,
#   4,
#   903],
#  [3, 511, 220, 7649],
#  [2,
#   11,
#   14,
#   42,
#   45,
#   1110,
#   19,
#   5391,
#   8973,
#   2852,
#   5770,
#   3898,
#   1087,
#   6543,
#   7276,
#   3943,
#   3811,
#   4442,
#   394],
#  [2, 15, 8, 11, 20, 18, 227, 3, 236, 1760],
#  [16, 26, 1, 302, 1412, 67, 370, 189, 16, 207, 370, 189, 86, 448, 7, 564],
#  [89, 1, 527, 3100, 59, 1, 228, 7, 17093],
#  [26, 43055, 43056, 17094, 24, 29, 12585, 419],
#  [48, 913, 4, 184, 27, 4, 15892, 1300, 34, 77, 6425, 139],
#  [2, 12, 1, 60, 778, 1110, 27, 1, 180, 1171, 1183, 4720],
#  [2, 698, 13241, 369, 2940, 1129],
#  [3, 17, 437, 5, 1005, 226, 27, 15893, 5771, 226, 1625],
#  [9, 26, 4, 4389, 81, 39, 3, 272, 4389, 282],
#  [2, 2789, 12, 43057],
#  [30, 683, 1037, 12, 1, 33, 6, 861, 13, 8451],
#  [9, 3, 56, 11074, 2578, 10, 1, 73, 609, 82, 92, 1975],
#  [2, 3, 188, 22, 6, 1871, 70, 1373, 10, 257],
#  [49,
#   1,
#   18521,
#   711,
#   24,
#   29,
#   7132,
#   8240,
#   59,
#   22781,
#   10,
#   20,
#   52,
#   2,
#   48,
#   19,
#   1093],
#  [35,
#   14,
#   25,
#   17095,
#   20,
#   76,
#   1050,
#   564,
#   173,
#   6,
#   941,
#   7,
#   14,
#   22,
#   28,
#   26260,
#   59,
#   14,
#   92,
#   4842,
#   17],
#  [9, 15, 14, 616, 13990, 22, 28, 392],
#  [2, 15, 8, 2122, 21, 43058],
#  [2, 12, 53, 1647, 13, 499, 440, 142, 2437, 6, 5240, 20328, 4962],
#  [11, 17096, 26261, 933],
#  [15, 8, 95, 4, 4113, 21, 9559, 109],
#  [2, 15, 8, 11, 5, 909, 43059, 455],
#  [2, 12, 38, 2314, 329, 762, 45, 43060, 43061, 1355],
#  [8,
#   35,
#   42,
#   5,
#   81,
#   1144,
#   140,
#   1250,
#   1606,
#   701,
#   26262,
#   6,
#   3862,
#   5,
#   181,
#   13991,
#   18522,
#   380,
#   203,
#   108,
#   2545,
#   21,
#   31823,
#   2030,
#   169,
#   1258,
#   26263,
#   2273,
#   9255,
#   3065,
#   10,
#   2391,
#   5043,
#   2273,
#   6158],
#  [3, 2657, 19, 3, 17097, 1012],
#  [3, 4605, 790, 667, 23, 204, 790, 667],
#  [9, 49, 43062, 95, 3815],
#  [40, 3, 65, 1027, 5, 24, 170, 21, 4, 5392, 23, 4, 3458, 56],
#  [2, 48, 1, 60, 14, 5772, 4247, 59, 1031, 112, 137],
#  [9, 53, 12, 250, 122, 6, 1638],
#  [2, 3, 1, 2824, 13, 8241, 15894, 43063, 2101, 101, 18523, 381],
#  [16, 3, 18, 224, 44, 2806, 6, 88, 275],
#  [3, 17, 44, 65, 213, 5, 25, 4, 1577, 115, 71, 5, 25, 4, 2472, 115],
#  [9, 15, 8, 32, 629, 7, 9870, 22, 18, 2047, 1198],
#  [2, 3, 1, 930, 7, 266],
#  [138,
#   1,
#   3644,
#   4,
#   426,
#   7,
#   12596,
#   24,
#   114,
#   1601,
#   1,
#   104,
#   6,
#   817,
#   3,
#   2171,
#   5,
#   320,
#   20,
#   14,
#   12,
#   1,
#   675,
#   1523,
#   9,
#   35,
#   14,
#   1137,
#   17],
#  [16, 26, 18, 504, 235, 8974, 604],
#  [15, 609, 3944, 75, 1868, 5178, 10, 503, 1333],
#  [16, 3, 17, 2249, 13, 14, 5, 751, 11536, 27, 28, 618],
#  [31,
#   8,
#   235,
#   4,
#   107,
#   19,
#   26264,
#   54,
#   13,
#   1,
#   5241,
#   7,
#   6274,
#   18,
#   2790,
#   8,
#   80,
#   1728,
#   5479,
#   62,
#   117,
#   1,
#   126],
#  [2, 12, 1, 449, 3816, 7, 43064, 26265, 2063],
#  [2, 3, 4, 2006, 8452, 6, 1120],
#  [20,
#   14,
#   1773,
#   2470,
#   1289,
#   59,
#   580,
#   22,
#   1,
#   4204,
#   35,
#   17,
#   25,
#   2892,
#   17098,
#   5,
#   181,
#   4,
#   234,
#   13,
#   583,
#   23,
#   1256,
#   1289,
#   10,
#   35,
#   17,
#   25,
#   100,
#   5,
#   322,
#   1421,
#   23,
#   1047,
#   4,
#   4606],
#  [2, 288, 17, 43065, 19, 4, 184, 58, 4, 889, 22, 55, 840, 9, 26, 1, 840, 81],
#  [16, 11, 122, 105, 1049, 508, 6267],
#  [12, 14, 510, 10, 4, 3781],
#  [24, 14, 114, 4781, 6, 941, 7, 28, 907, 23, 1439, 2853, 23, 9871],
#  [15,
#   1,
#   1931,
#   2678,
#   28,
#   10650,
#   568,
#   6,
#   416,
#   1747,
#   72,
#   146,
#   17,
#   9256,
#   10,
#   65,
#   52,
#   34,
#   14,
#   306,
#   82,
#   6,
#   1,
#   136,
#   1931,
#   27,
#   30,
#   544,
#   3,
#   12041],
#  [20,
#   4,
#   184,
#   260,
#   326,
#   246,
#   8453,
#   6,
#   300,
#   1014,
#   180,
#   2772,
#   19,
#   77,
#   48,
#   7650,
#   22782,
#   46,
#   1,
#   5033,
#   358,
#   9,
#   72,
#   88,
#   326,
#   1306,
#   22,
#   22783],
#  [40, 3, 1, 4607, 222, 7, 14852, 1317, 23, 4782],
#  [9, 15, 50, 2402, 43066, 1, 547, 5, 12042, 547, 22784],
#  [2, 3, 4, 12597, 8454, 6, 1318],
#  [9, 61, 28, 907, 24, 170, 21, 14],
#  [4,
#   3729,
#   243,
#   7,
#   2183,
#   665,
#   481,
#   5,
#   54,
#   19,
#   1,
#   680,
#   3,
#   5393,
#   731,
#   5393,
#   2,
#   26,
#   77,
#   116,
#   46,
#   19],
#  [2, 3, 1, 127, 70, 43067, 10, 43068, 6, 1102],
#  [9, 35, 14, 721, 1, 698, 831, 7, 4661, 22785],
#  [9, 69, 1543, 19, 2980, 3520, 2048, 46, 1314],
#  [9, 26, 1, 273, 1137, 34, 4, 8975, 18524, 79, 43, 525, 22, 1, 13236],
#  [2, 12, 1, 43069, 13242, 329, 13],
#  [49, 1155, 143, 3685, 26266],
#  [30, 3, 1, 33, 155, 13, 43070, 43071, 6, 453, 529, 13, 3070],
#  [3, 17, 1077, 5, 24, 170, 21, 4, 17099, 9],
#  [9, 72, 11, 608, 61, 1561, 2854, 4, 4835, 303],
#  [9, 3, 4608, 3730, 172],
#  [2, 12, 1, 2569, 6, 4, 1523, 11, 710, 2548, 32, 1463, 5],
#  [9, 11, 8, 166, 18, 43072, 27, 1382, 564],
#  [2, 11, 8, 157, 34, 431, 219, 54, 19, 121, 44, 53, 462],
#  [2, 3, 4, 2916, 2274, 14, 24, 2031, 19, 2751, 85, 83, 14853, 645],
#  [2, 3, 1, 3896, 7, 1528, 513, 7829, 180],
#  [9, 15, 76, 6426, 28, 2345, 1349],
#  [2, 3, 1, 1522, 19, 8, 24, 795, 18, 4291, 1487, 6, 1, 168, 7, 43073],
#  [58, 8976, 90, 304, 5, 2497, 1356, 1694, 9257, 10226],
#  [2, 198, 15, 25, 648, 22, 1, 1222, 881, 6, 1, 17100, 1025, 218, 686],
#  [9, 15, 8, 1453, 18, 128, 3645, 1186],
#  [2, 3, 1, 445, 1168, 2122, 975, 119, 6, 914, 436],
#  [2, 12, 1, 212, 31824, 15, 25, 2498],
#  [16, 11, 60, 11537, 2893, 21, 56, 2997],
#  [2, 12, 38, 225, 13, 371, 9258, 31825],
#  [9,
#   11,
#   8,
#   81,
#   30,
#   1747,
#   121,
#   752,
#   6,
#   13,
#   4,
#   435,
#   574,
#   23,
#   783,
#   121,
#   2627,
#   20329,
#   46,
#   43074,
#   62,
#   256,
#   52,
#   631,
#   5,
#   361,
#   51,
#   56,
#   1648,
#   1222],
#  [2, 12, 1, 1288, 1949, 46, 694],
#  [30, 139, 23, 168, 3, 33, 13, 2628, 147, 6, 57],
#  [2, 3, 43075, 43076, 670, 2423, 4205],
#  [63, 15, 8, 91, 4, 53, 2296, 13, 255, 31826, 6, 6679],
#  [30, 6427, 4390, 1639, 1932, 1, 33, 372],
#  [2, 12, 1, 3945, 27, 1, 1223, 7651, 2275, 1464, 19, 14, 66, 1095, 79, 60],
#  [9, 11, 8, 144, 5, 61, 1850, 3946, 27, 1, 7652],
#  [2, 3, 1, 223, 7, 2086, 42],
#  [1183,
#   6164,
#   541,
#   12598,
#   4114,
#   34,
#   47,
#   32,
#   1098,
#   16,
#   96,
#   47,
#   24,
#   5773,
#   1072,
#   22,
#   1,
#   164,
#   560],
#  [3, 17, 695, 13, 54, 5, 14854, 4, 702, 1590, 1013, 3, 729, 129, 27, 18, 186],
#  [2, 12, 38, 2329, 762, 45, 43077, 2941],
#  [2, 12, 1, 759, 7, 492, 22, 1, 97, 15895, 43, 665],
#  [2, 12, 1, 75, 7, 1, 5672],
#  [9, 15, 8, 610, 1, 14855, 10651, 5, 18, 243, 40, 2033, 256, 1264],
#  [2, 12, 1, 127, 70, 31827, 1174, 10, 15896, 1174, 7, 22786, 1378],
#  [2, 73, 794, 463, 1398, 12, 6, 20330, 36, 2940],
#  [40, 1668, 1, 31828, 4068],
#  [41, 539, 392, 4, 303, 881, 2615],
#  [2, 35, 185, 20, 334, 124, 14856, 9872],
#  [16, 163, 2643, 881, 6, 1079, 4206, 10, 9560],
# ...
#   19,
#   1284,
#   27,
#   3071,
#   387,
#   142,
#   3688,
#   23,
#   223,
#   5481,
#   374,
#   22,
#   1075,
#   10,
#   1013],
#  [63, 31, 56, 2917, 1, 396, 7, 74],
#  [9,
#   72,
#   11,
#   14,
#   1280,
#   21,
#   1,
#   1702,
#   19,
#   8457,
#   708,
#   3,
#   4,
#   2082,
#   2050,
#   7,
#   5875,
#   65,
#   71,
#   4,
#   511,
#   7,
#   3135],
#  [12, 39, 51, 416, 1711, 18530, 13, 255, 3483],
#  [16, 48, 13993, 17102, 2283],
#  [8,
#   98,
#   39,
#   31,
#   25,
#   272,
#   26277,
#   17103,
#   311,
#   20,
#   14,
#   124,
#   5,
#   145,
#   29,
#   405,
#   13,
#   1,
#   22791,
#   2804,
#   2,
#   99,
#   14,
#   206,
#   85,
#   21],
#  [9, 49, 26278, 43100, 1440, 52, 834],
#  [15, 1, 43101, 168, 74, 149, 14, 1190, 2, 14, 84, 6, 4, 239],
#  [2, 26, 17, 116, 34, 4, 5960, 2698, 14, 5, 721, 28, 11541, 10231, 6, 1, 316],
#  [16, 3, 56, 11074, 2257, 2753, 56, 215, 22, 4, 177, 5297],
#  [41, 43102, 18, 704, 1004, 3253, 149, 54, 450, 5, 18, 889, 1729],
#  [2,
#   1300,
#   1681,
#   12,
#   158,
#   13,
#   15900,
#   9565,
#   8,
#   363,
#   902,
#   7461,
#   1040,
#   2629,
#   4549,
#   231,
#   394],
#  [2,
#   3,
#   1,
#   33,
#   11078,
#   13,
#   4,
#   4016,
#   19,
#   15,
#   1229,
#   4,
#   426,
#   7,
#   556,
#   43,
#   1,
#   263,
#   134,
#   83,
#   1989,
#   21,
#   1681],
#  [16, 1572, 626, 4292, 1, 1646, 2750],
#  [9, 12, 1, 129, 10232, 7, 1703, 3689],
#  [34,
#   4,
#   368,
#   1608,
#   42,
#   17104,
#   31837,
#   7835,
#   5104,
#   6428,
#   15901,
#   2416,
#   17105,
#   23,
#   1185,
#   11079,
#   3,
#   2378,
#   21,
#   23,
#   6166,
#   7,
#   735,
#   43103,
#   31,
#   55,
#   368,
#   3899,
#   25,
#   2347,
#   11542],
#  [2, 3, 2597, 43104],
#  [9, 72, 49, 4, 883, 293, 22, 354, 6, 2012, 443],
#  [2, 3, 2895, 7, 1, 22792, 172, 7],
#  [9, 11, 14, 81, 14, 12, 4, 53, 104, 40, 5778, 1, 1377],
#  [2,
#   12,
#   38,
#   212,
#   5,
#   31838,
#   1,
#   82,
#   3103,
#   2516,
#   68,
#   13,
#   539,
#   8,
#   48,
#   2225,
#   29,
#   6429,
#   516,
#   6,
#   4,
#   1892,
#   868,
#   6,
#   13994],
#  [2, 3, 1, 26279, 685],
#  [617, 1976, 1962, 10, 617, 6, 5779, 117, 13, 149, 2, 11, 8, 11],
#  [16, 12, 43105, 31839, 36, 12602, 10, 3818, 656],
#  [16, 11, 1, 1161, 84, 4, 2728, 220, 1, 6430],
#  [16,
#   11,
#   14,
#   32,
#   1,
#   136,
#   4610,
#   1085,
#   138,
#   29,
#   137,
#   889,
#   148,
#   620,
#   28,
#   6,
#   143,
#   21,
#   76,
#   606],
#  [30, 532, 7, 37, 86, 1049, 5, 730, 85, 71, 1, 354, 881],
#  [2, 3, 127, 70, 2572, 10, 3556],
#  [2, 3, 4, 5961, 5180],
#  [2, 3, 28, 612, 4783, 34, 348, 4, 746, 17, 1388],
#  [40, 35, 340, 6, 4, 543, 70, 3521, 8458, 10, 4, 31840],
#  [9, 15, 8, 32, 629, 7, 115, 489, 22, 103],
#  [58, 399, 2874, 1, 13995, 7, 74],
#  [2, 11, 43106, 66, 7, 31841, 22793],
#  [2, 3, 1, 75, 7, 217, 3646],
#  [2, 516, 26, 26280, 4902, 356, 6, 1, 364, 297, 895, 40],
#  [9, 3, 8036, 43107],
#  [12, 1, 1591, 43108, 43109, 10, 43110, 43111, 26281, 6838],
#  [11, 2000, 142, 675, 897, 1525, 82, 2, 12, 38, 342],
#  [12, 140, 4207, 3557, 5, 66, 7, 1, 97, 36, 177, 43112],
#  [3, 976, 188, 5, 24, 43113, 13, 921, 1454, 218, 433, 36, 287],
#  [41,
#   8,
#   131,
#   25,
#   313,
#   5,
#   3226,
#   6,
#   1,
#   130,
#   26282,
#   148,
#   20,
#   8,
#   24,
#   2066,
#   218,
#   153,
#   19,
#   640],
#  [2,
#   41,
#   14,
#   11,
#   34,
#   14,
#   156,
#   38,
#   165,
#   587,
#   5,
#   538,
#   564,
#   22,
#   4,
#   175,
#   131,
#   1226,
#   1,
#   882,
#   19,
#   14,
#   12,
#   236,
#   1763,
#   5,
#   883,
#   110],
#  [30, 141, 58, 65, 357, 2315],
#  [8,
#   124,
#   4,
#   31842,
#   5482,
#   46,
#   7279,
#   14860,
#   17,
#   48,
#   2961,
#   62,
#   971,
#   4,
#   18531,
#   42,
#   12603,
#   26,
#   171,
#   81,
#   9,
#   5,
#   61,
#   202,
#   4,
#   20335,
#   192],
#  [2, 11, 113, 13249, 66, 7, 4445],
#  [9, 15, 8, 32, 629, 7, 738, 93, 5044],
#  [30, 56, 31, 8, 1388, 4446, 43114, 23, 4446, 9566, 7836, 21, 4550, 6682],
#  [11, 67, 13250, 308, 230, 211, 162, 7, 1, 228, 6, 55, 141],
#  [16, 80, 8, 236, 1763, 5, 509, 352],
#  [2, 11, 5037, 10, 2276, 66, 7, 1465, 10, 11543, 37],
#  [9, 11, 14, 830, 31843, 108, 43115],
#  [16, 35, 4, 4501, 104, 92, 118, 800, 15902],
#  [8,
#   80,
#   5574,
#   1334,
#   4,
#   789,
#   63,
#   8,
#   80,
#   83,
#   17106,
#   46,
#   4,
#   1242,
#   341,
#   10,
#   8,
#   80,
#   912,
#   415,
#   27,
#   110,
#   2,
#   99,
#   17,
#   116],
#  [40, 43116, 43117, 359, 377, 13, 3227, 285],
#  [9,
#   15,
#   8,
#   81,
#   876,
#   9,
#   72,
#   7,
#   1,
#   621,
#   8,
#   755,
#   1,
#   7462,
#   6,
#   2807,
#   41,
#   32,
#   59,
#   67,
#   1,
#   1481,
#   34,
#   160,
#   3558],
#  [35, 14, 157, 1, 17107, 6, 3317, 3, 3900, 1279, 46, 18532],
#  [16, 31, 50, 1315, 9874],
#  [16, 38, 37, 519, 44, 5, 2316, 10, 26283, 4293],
#  [11, 14, 2534, 81, 76, 40, 3, 4, 1322, 7, 1, 6275],
#  [16, 165, 12, 4610, 170, 236, 72, 9, 5, 422, 735, 1085, 631, 5, 422, 1085],
#  [9, 132, 26, 17, 86, 5, 24, 28, 103, 301, 3586],
#  [2, 3, 1, 127, 70, 757, 20336, 10, 13251, 20336],
#  [2,
#   3,
#   1,
#   747,
#   2050,
#   19,
#   20337,
#   5,
#   340,
#   1,
#   9261,
#   7,
#   1806,
#   6839,
#   2550,
#   5875,
#   6840,
#   7126],
#  [2, 12, 1, 490, 7, 3783, 21, 966],
#  [9, 11, 14, 98, 45, 1, 383, 679, 173, 4331, 6, 1, 281, 379],
#  [2, 41, 185, 6, 1, 680, 153, 1, 289, 11080],
#  [30, 3, 33, 289, 254, 23, 1711, 2945, 13, 4, 237, 17, 184],
#  [2,
#   3,
#   4,
#   1426,
#   1941,
#   2,
#   12,
#   1,
#   33,
#   719,
#   1941,
#   2579,
#   151,
#   4721,
#   196,
#   23,
#   795,
#   8,
#   117,
#   56,
#   5,
#   118,
#   1497,
#   13,
#   384,
#   1807,
#   3581,
#   6,
#   3348],
#  [9, 15, 8, 95, 65, 561, 43, 2467],
#  [9,
#   15,
#   50,
#   61,
#   1102,
#   1942,
#   10,
#   9875,
#   1105,
#   65,
#   22,
#   728,
#   316,
#   10,
#   292,
#   22,
#   214,
#   316],
#  [3, 851, 3, 437, 780],
#  [9,
#   3,
#   17,
#   19,
#   38,
#   37,
#   1048,
#   5,
#   32,
#   1209,
#   21,
#   233,
#   1361,
#   12604,
#   23,
#   4069,
#   62,
#   96,
#   32,
#   3559],
#  [2, 3, 1, 825, 7, 1, 2644, 634, 622, 6, 4250, 187, 238, 2050],
#  [35,
#   4,
#   204,
#   989,
#   420,
#   341,
#   363,
#   984,
#   40,
#   26284,
#   187,
#   443,
#   513,
#   152,
#   145,
#   4,
#   9262,
#   10,
#   6276],
#  [40, 5045, 1, 4844],
#  [9, 15, 8, 156, 40, 3, 7280, 18, 1700, 1044],
#  [16,
#   89,
#   130,
#   4842,
#   10,
#   131,
#   47,
#   12,
#   4842,
#   16,
#   818,
#   335,
#   21,
#   4,
#   6546,
#   8244,
#   2392],
#  [26, 13996, 2063, 82, 13, 37, 1976, 27, 5181],
#  [16,
#   15,
#   18,
#   324,
#   245,
#   156,
#   18,
#   1851,
#   6,
#   55,
#   7463,
#   148,
#   620,
#   18,
#   1851,
#   3,
#   6431,
#   36,
#   582],
#  [2,
#   12,
#   1,
#   263,
#   4551,
#   4,
#   1000,
#   4722,
#   868,
#   15,
#   297,
#   2208,
#   19,
#   41,
#   61,
#   87,
#   84,
#   5,
#   651,
#   36,
#   1573,
#   36,
#   111],
#  [2, 11, 2731, 11544, 362, 269, 560, 7, 4, 2731],
#  [16, 49, 8459, 43118, 5243, 855, 4, 239, 6, 1143],
#  [20,
#   1,
#   18533,
#   49,
#   600,
#   6,
#   535,
#   40,
#   3516,
#   5780,
#   7,
#   1560,
#   3482,
#   1679,
#   36,
#   964,
#   5,
#   55,
#   1355,
#   16,
#   49,
#   47,
#   1391,
#   5,
#   601,
#   1,
#   2728,
#   162,
#   126,
#   3,
#   299,
#   23,
#   17,
#   3,
#   92,
#   4,
#   4782],
#  [3, 17, 111, 13, 54, 5, 91, 10, 11, 1067, 138, 1067, 1143, 856, 46, 18, 713],
#  [9, 4, 499, 440, 780, 43119, 151, 279, 15, 25, 251],
#  [9, 11, 8, 86, 4502, 10, 178, 1441, 1495, 3733, 6, 458, 22794, 21, 290],
#  [16, 41, 14, 361, 748, 13, 28, 4845, 835],
#  [9, 69, 638, 7, 1821, 11, 8, 117, 269, 714, 20, 8, 84, 4, 2732, 11081],
#  [9, 15, 50, 2067, 1046, 5575, 11545, 428],
#  [34, 48, 1, 291, 68, 716, 14861, 4, 5471, 16, 16, 58, 17, 114, 4, 134],
#  [9, 15, 8, 32, 4, 847, 1466, 22, 724],
#  [3, 14862, 6, 237, 6547, 976, 4, 53, 815],
#  [49,
#   14,
#   90,
#   1167,
#   1,
#   15903,
#   424,
#   134,
#   209,
#   22795,
#   1427,
#   9,
#   5,
#   1060,
#   17,
#   10,
#   32,
#   100,
#   326],
#  [15, 558, 821, 2439, 5674, 4, 18534, 6277],
#  [18, 243, 13997, 285, 162, 7, 1004, 10, 10233, 9, 15, 8, 149, 110],
#  [3, 4503, 23, 31844, 100, 13, 14],
#  [16,
#   12,
#   7277,
#   52,
#   158,
#   43,
#   371,
#   23,
#   1943,
#   19,
#   47,
#   96,
#   501,
#   4,
#   846,
#   1765,
#   7,
#   6278,
#   988,
#   29,
#   1249,
#   15,
#   2137,
#   5,
#   1448,
#   43,
#   454,
#   2173,
#   92,
#   46,
#   2419,
#   132,
#   462],
#  [2, 3, 1, 195, 7, 67, 1, 612, 2213, 7837, 4432],
#  [26, 1794, 3522, 933, 23, 149, 1, 5962],
#  [34, 89, 1, 877, 1409, 1668],
#  [9, 15, 8, 95, 4, 298, 3432, 36, 8, 119, 5, 25, 10, 3774, 65, 22, 18, 839],
#  [2, 150, 14, 3045, 27, 1, 554, 19, 12, 105, 1049, 39],
#  [16, 11, 60, 822, 37, 96, 179, 6, 4153, 3072, 62, 548, 6, 3228, 890, 3072],
#  [31, 56, 183, 27, 1041, 225, 23, 683, 1083, 13, 4611, 10, 805, 6, 498, 147],
#  [338,
#   7,
#   2068,
#   21,
#   1,
#   368,
#   45,
#   9263,
#   16,
#   2150,
#   477,
#   123,
#   434,
#   9567,
#   1877,
#   6,
#   2699,
#   42,
#   913,
#   49],
#  [2,
#   3,
#   3256,
#   10,
#   1265,
#   1109,
#   22,
#   17108,
#   11082,
#   13,
#   132,
#   440,
#   1493,
#   6,
#   674,
#   316,
#   6,
#   57,
#   6548,
#   10,
#   8460],
#  [11, 155, 9568, 6, 3348, 505, 462, 5, 32, 46],
#  [3, 17, 111, 6, 1727, 5, 517, 2551, 36, 4, 5244, 791, 13, 122],
#  [11, 211, 37, 42, 5, 339, 11083, 14863, 27, 972, 189, 23, 92, 1, 250, 42, 87],
#  [2, 3, 1, 60, 561, 3229, 7, 1, 4504, 15904, 2679],
#  [15,
#   8,
#   36,
#   4,
#   1156,
#   101,
#   137,
#   95,
#   5483,
#   6,
#   4495,
#   20,
#   8,
#   519,
#   298,
#   5,
#   183,
#   17,
#   46,
#   1,
#   68,
#   121,
#   583],
#  [63,
#   99,
#   8,
#   91,
#   4,
#   1878,
#   21,
#   807,
#   3523,
#   7,
#   4,
#   746,
#   224,
#   7,
#   280,
#   6,
#   4,
#   1045,
#   141],
#  [9, 11, 8, 235, 4444, 17109, 359],
#  [9, 15, 8, 166, 352, 27, 17110, 382],
#  [41, 8461, 41, 330, 1, 2700, 1641, 384],
#  [9,
#   69,
#   37,
#   276,
#   19,
#   4965,
#   2424,
#   85,
#   31,
#   25,
#   3136,
#   6,
#   177,
#   23,
#   609,
#   1170,
#   13,
#   100,
#   418],
#  [31, 8, 1332, 27, 418, 1032, 5, 142, 418, 1233],
#  [30, 3, 1, 33, 1592, 6, 7459],
#  [2, 3, 20338, 6, 359],
#  [2, 12, 38, 7, 14864, 1471, 3939, 10234],
#  [9, 11, 14, 378, 144, 17111],
#  [9, 49, 15905, 1508],
#  [20,
#   14,
#   99,
#   361,
#   5,
#   1818,
#   56,
#   104,
#   192,
#   10,
#   252,
#   40,
#   2,
#   10,
#   63,
#   35,
#   17,
#   25,
#   10,
#   16],
#  [2, 3, 31845],
#  [9, 11, 50, 81, 2, 3, 2480, 140, 1183, 217, 20, 140, 13998, 828, 19, 1014],
#  [2, 12, 38, 7, 1, 60, 12041, 59, 238, 540],
#  [9,
#   49,
#   542,
#   4903,
#   37,
#   5670,
#   1,
#   413,
#   6,
#   55,
#   3386,
#   271,
#   34,
#   47,
#   124,
#   105,
#   56,
#   740,
#   5,
#   86,
#   448,
#   34,
#   47,
#   4154,
#   2677,
#   23,
#   5,
#   1709],
#  [27,
#   63,
#   15,
#   8,
#   144,
#   1427,
#   27,
#   1,
#   3587,
#   8,
#   80,
#   27,
#   4,
#   1286,
#   1383,
#   333,
#   6,
#   1472,
#   57],
#  [2, 31, 8, 723, 6, 1, 94, 1669],
#  [35, 14, 548, 25, 1792, 5305, 23, 2311, 5305],
#  [16, 11, 18, 2330, 5576, 134, 8, 80, 236, 3230],
#  [9, 15, 1808, 810, 532, 90, 32, 1123],
#  [2,
#   837,
#   12,
#   39,
#   6,
#   30,
#   2774,
#   469,
#   55,
#   5675,
#   443,
#   121,
#   587,
#   5,
#   11,
#   29,
#   3734,
#   7,
#   912,
#   6,
#   887,
#   679,
#   1340,
#   10,
#   80,
#   1933,
#   72,
#   3560,
#   4723,
#   443],
#  [2, 3, 43120, 10, 2, 12, 159, 836],
#  [16,
#   49,
#   7133,
#   1667,
#   64,
#   222,
#   36,
#   420,
#   34,
#   77,
#   48,
#   4612,
#   506,
#   62,
#   115,
#   34,
#   77,
#   48,
#   3046,
#   13,
#   735,
#   1544],
#  [2, 3, 1, 60, 43121, 192, 14, 24, 90, 1078],
#  [24, 14, 90, 1424, 4, 7838, 20, 52, 2, 502],
#  [2, 502, 6, 1, 337, 286, 8462, 6, 22796],
#  [2, 49, 14, 106, 190, 6, 28, 10235, 14865],
#  [30, 1383, 31, 8, 361, 6, 218, 726, 13, 227, 191],
#  [9, 3, 4, 5484, 718, 636, 5, 4, 11084, 718],
#  [9, 11, 4251, 722, 10, 4784, 366, 1, 1033, 974, 7, 1, 1749],
#  [16, 512, 13999, 43122, 67, 1, 223, 1635, 92, 42, 2680, 1554, 935, 615],
#  [3, 39, 4, 240, 70, 403, 31846, 1593, 10, 2645, 546, 27, 7464, 6, 1, 7465],
#  [16, 12, 39, 52, 69, 37, 31847, 55, 26285],
#  [11, 4060, 200, 14866, 66, 6, 43123],
#  [2, 295, 5, 4, 17112, 22, 1455],
#  [2, 11, 14, 11, 59, 28, 2184, 58, 114, 13252],
#  [980,
#   1,
#   33,
#   142,
#   405,
#   14,
#   145,
#   5,
#   4,
#   248,
#   401,
#   40,
#   593,
#   5,
#   118,
#   88,
#   186,
#   142],
#  [3, 39, 4, 78, 5, 1441, 18, 903, 1822, 264],
#  [9,
#   15,
#   4785,
#   2424,
#   416,
#   5670,
#   1,
#   846,
#   1261,
#   960,
#   34,
#   17,
#   3,
#   83,
#   26286,
#   46,
#   1,
#   1213,
#   487,
#   2069,
#   10,
#   1,
#   1161,
#   30,
#   507,
#   31,
#   25,
#   4388,
#   46,
#   1,
#   416,
#   138,
#   64,
#   960],
#  [2, 3, 1, 75, 7, 31848, 1, 18535, 7, 2331],
#  [3, 39, 133, 4, 2699, 13, 3387, 37],
#  [20, 14, 89, 4, 785, 2, 35, 14, 25, 16],
#  [2, 12, 1, 33, 196, 7134, 1126, 841],
#  [6,
#   18,
#   1490,
#   568,
#   13,
#   2102,
#   1024,
#   8,
#   2853,
#   1495,
#   764,
#   63,
#   17,
#   648,
#   20,
#   1879,
#   13,
#   237,
#   15906,
#   1187,
#   9,
#   15,
#   8,
#   167,
#   19,
#   5,
#   1096],
#  [9, 15, 8, 43124, 18, 243, 22, 1, 1327, 301],
#  [16,
#   49,
#   60,
#   7,
#   1,
#   10654,
#   3524,
#   1450,
#   4552,
#   10,
#   517,
#   1450,
#   5245,
#   36,
#   29,
#   2896],
#  [2, 3, 1, 2999, 451, 7135, 83, 3137, 36, 1, 3901, 22797, 7, 85],
#  [6279, 12, 1, 3690, 7, 227, 191],
#  [12, 39, 51, 3280, 19, 35, 6549, 4, 746, 1175, 21, 105, 3138],
#  [15, 1778, 610, 1, 14000, 8025, 7, 1029, 6, 1, 757, 3207],
#  [9, 11, 8, 6280, 18, 3409],
#  [16, 11, 8, 788, 6, 143, 21, 13253, 37],
#  [2, 3, 1, 8025, 7, 1, 128, 187, 17113, 3691, 2235, 3647, 8037],
#  [6,
#   5485,
#   5,
#   1,
#   1112,
#   7,
#   57,
#   10,
#   60,
#   73,
#   454,
#   725,
#   189,
#   26,
#   43125,
#   1028,
#   436,
#   10,
#   463,
#   43,
#   1645,
#   19,
#   12,
#   22,
#   7839,
#   21,
#   1,
#   806],
#  [26, 187, 43126, 22798, 31849, 375, 20339],
#  [3,
#   17,
#   478,
#   6,
#   312,
#   13,
#   4,
#   582,
#   130,
#   5,
#   871,
#   4,
#   4786,
#   152,
#   109,
#   20,
#   14,
#   3948],
#  [3, 4, 5954, 10, 15907, 44, 1849, 6, 14867, 46, 2754, 5963, 6, 633],
#  [11, 43127, 10, 43128, 308, 269, 73],
#  [9, 72, 126, 11, 3073, 1653, 22799, 32, 795, 46, 8980],
#  [16, 12, 9264, 1, 109, 399, 19, 229, 1023],
#  [2, 12, 38, 150, 5, 11, 34, 14, 12, 3388, 6, 218],
#  [2,
#   31,
#   8,
#   11,
#   20,
#   18,
#   474,
#   26,
#   44,
#   145,
#   54,
#   68,
#   1750,
#   88,
#   142,
#   22,
#   3645,
#   10,
#   77,
#   26,
#   44,
#   42,
#   20,
#   8,
#   842,
#   18,
#   68,
#   21,
#   18,
#   245],
#  [20,
#   8,
#   7840,
#   922,
#   203,
#   22,
#   18,
#   137,
#   227,
#   10,
#   2070,
#   17,
#   22,
#   18,
#   113,
#   227,
#   2,
#   41,
#   1456,
#   817,
#   54],
#  [2, 3, 28, 1401, 7, 43129, 10, 15908, 919, 1, 123, 194, 31850],
#  [2, 12, 38, 387, 150, 19, 50, 36, 4, 258, 15, 11, 282, 1, 234, 5, 444, 1139],
#  [12, 944, 31851, 65, 11085, 71, 944, 6281, 2961],
#  [2, 3, 1, 1827, 152, 7, 4, 227, 191, 829],
#  [2, 3, 1, 428, 12605, 43, 203, 796, 6063],
#  [16, 12, 17114, 5964, 5, 37],
#  [2, 3, 1, 1581, 6, 6683, 329, 13],
#  [30, 3525, 169, 674, 496, 43, 6548],
#  [9,
#   132,
#   26,
#   17,
#   86,
#   5,
#   91,
#   985,
#   10,
#   12606,
#   113,
#   319,
#   7,
#   5577,
#   59,
#   1,
#   137,
#   56,
#   3561],
#  [2,
#   31,
#   8,
#   11,
#   5,
#   830,
#   1,
#   291,
#   3562,
#   7,
#   20340,
#   4294,
#   1226,
#   19,
#   8,
#   207,
#   91,
#   51,
#   5578,
#   2755,
#   6,
#   256,
#   173,
#   252],
#  [2, 3, 1, 265, 863, 22, 29, 1197, 346],
#  [2, 12, 1, 930, 7, 725, 11546, 7, 1509, 5, 1, 223],
#  [2, 3, 8463, 43130, 329, 13],
#  [20,
#   39,
#   12,
#   1256,
#   526,
#   201,
#   10,
#   622,
#   488,
#   201,
#   6,
#   28,
#   218,
#   2,
#   7841,
#   7,
#   1,
#   218,
#   3,
#   526],
#  [2, 4105, 43131, 43132, 1143, 890],
#  [16, 11, 8, 2943, 5394, 21, 37, 22, 238, 368],
#  [9, 11, 8, 406, 4, 6978, 46, 352, 23, 1467, 5, 1184, 13, 1, 136],
#  [9, 89, 31852, 43133, 3047],
#  [2, 3, 1, 127, 70, 2939, 10, 1452],
#  [34, 76, 2698, 4, 301, 22, 103, 9, 11, 14, 156, 40, 17, 3],
#  [9, 69, 757, 898, 292, 71, 203, 497, 12, 39, 1930, 7, 5105, 1166, 5, 475],
#  [15, 7842, 25, 31853, 79, 22, 3687, 1321],
#  [120, 28, 588, 22, 3228, 359],
#  [9,
#   49,
#   37,
#   10236,
#   61,
#   11547,
#   6,
#   1,
#   9874,
#   23,
#   73,
#   7272,
#   21,
#   105,
#   23,
#   765,
#   496,
#   3484],
#  [2, 58, 114, 28, 205, 21, 43134],
#  [26, 1, 9265, 14001, 131, 1368, 1, 3021],
#  [2, 4332, 2726, 677, 35, 14, 44, 501, 3318, 6, 416],
#  [9, 3, 5046, 6841, 877, 18536, 64, 1180, 17, 48, 327, 6, 8, 1362, 173],
#  [2, 12, 1, 1038, 669, 13, 14868, 6, 12607, 10, 31854],
#  [16, 11, 250, 488, 14002, 14003, 310, 13, 1, 10237, 713, 13, 196],
#  [15, 47, 24, 170, 43, 203],
#  [2, 3, 1, 825, 5, 64, 3616, 413, 3863, 43135, 128, 244, 187],
#  [16, 3, 123, 83, 4115, 7, 12608, 512, 123, 2729, 3692, 36, 9569, 1281],
#  [11, 14, 66, 37, 15, 32, 462, 1952, 22, 4, 2946, 1053],
#  [31, 8, 766, 1774, 79, 7, 18, 1053, 885, 6, 797, 7, 174, 3349, 10, 188, 2259],
#  [16, 26, 458, 497, 24, 455, 6, 8981, 2127],
#  [9, 72, 15, 56, 351, 6, 1454, 46, 209, 3378, 7, 1454, 109],
#  [2, 58, 43136, 461, 286, 4, 2701, 6, 1, 2897, 528],
#  [11, 115, 3582, 505, 65, 71, 7281],
#  [63, 49, 4613, 2173, 206, 27],
#  [2, 11, 14, 66, 7, 13254, 12609, 26287],
#  [9, 15, 14, 32, 4, 107, 36, 29, 2403, 4295],
#  [2, 12, 1, 53, 10, 158, 2474, 7, 43137, 386, 598],
#  [26, 35, 4, 2098, 227, 14869, 632, 1315, 1, 3281, 919, 27, 29, 12610, 9570],
#  [2, 3, 1, 1181, 7, 31855, 418, 6, 1, 6167],
#  [30, 499, 1110, 24, 1, 60, 6684, 23, 6685, 2804, 20341],
#  [16,
#   11,
#   237,
#   321,
#   814,
#   5,
#   32,
#   55,
#   690,
#   45,
#   708,
#   27,
#   1,
#   3557,
#   368,
#   2,
#   6282,
#   87,
#   27,
#   3563,
#   1,
#   1397,
#   27,
#   1,
#   2367],
#  [2, 12, 1, 33, 225, 30, 14, 15, 268, 6, 56, 152],
#  [16, 31, 8, 75, 26288, 138, 26289],
#  [20,
#   50,
#   2051,
#   4,
#   5870,
#   215,
#   1704,
#   6540,
#   140,
#   1183,
#   217,
#   99,
#   50,
#   14870,
#   5,
#   29,
#   43138,
#   10,
#   30,
#   35,
#   50,
#   106,
#   5],
#  ...]

# %%
sequences_matrix_test = sequence.pad_sequences(sequences_test,maxlen=max_quant_len)

# %%
sequences_matrix_test
# Out:
# array([[   0,    0,    0, ...,   61,   94, 4200],
#        [   0,    0,    0, ...,  118,   28,  142],
#        [   0,    0,    0, ...,    3,   64,  888],
#        ...,
#        [   0,    0,    0, ...,  215, 5927, 6025],
#        [   0,    0,    0, ...,  395,  128, 1193],
#        [ 124,  114,    1, ..., 3896, 7377, 1418]], dtype=int32)

# %%
x_train=sequence.pad_sequences(sequences_train,maxlen=max_quant_len)

# %%
x_test=sequence.pad_sequences(sequences_test,maxlen=max_quant_len)

# %%
from keras.layers import Embedding

# %%
from keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding

# %%
def RNN():
    inputs = Input(name='inputs',shape=[max_len], dtype='float32')
    layer = Embedding(len(word_index)+1,100,input_length=max_len,weights=[embedding_matrix],mask_zero=True,trainable=False)(inputs)
    layer = LSTM(64)(layer)
    layer = Dense(256,name='FC1')(layer)
    layer = Activation('relu')(layer)
    layer = Dropout(0.5)(layer)

    layer = Dense(128,name='FC2')(layer)
    layer = Activation('tanh')(layer)
    layer = Dropout(0.5)(layer)

    layer = Dense(256,name='FC3')(layer)
    layer = Activation('tanh')(layer)
    layer = Dropout(0.5)(layer)
    #layer=BatchNormalization()(layer)
    
    layer = Dense(1,name='out_layer')(layer)
    layer = Activation('sigmoid')(layer)
    model = Model(inputs=inputs,outputs=layer)
    return model

# %%
model = RNN()
model.summary()
model.compile(loss='binary_crossentropy',optimizer='adam',
              metrics=['accuracy'])
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 30.0)              0
# _________________________________________________________________
# embedding_3 (Embedding)      (None, 30.0, 100)         19622100
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 64)                42240
# _________________________________________________________________
# FC1 (Dense)                  (None, 256)               16640
# _________________________________________________________________
# activation_6 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# FC2 (Dense)                  (None, 128)               32896
# _________________________________________________________________
# activation_7 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# FC3 (Dense)                  (None, 256)               33024
# _________________________________________________________________
# activation_8 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# out_layer (Dense)            (None, 1)                 257
# _________________________________________________________________
# activation_9 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 19,747,157
# Trainable params: 125,057
# Non-trainable params: 19,622,100
# _________________________________________________________________

# %%
model.fit(x_train, y_train,
          batch_size=10000,
          epochs=15,
          validation_data=(x_test, y_test))
# Out:
# Train on 1044897 samples, validate on 261225 samples
# Epoch 1/15
# 1044897/1044897 [==============================] - 372s 356us/step - loss: 0.1184 - acc: 0.9535 - val_loss: 0.2684 - val_acc: 0.9348
# Epoch 2/15
# 1044897/1044897 [==============================] - 368s 352us/step - loss: 0.1165 - acc: 0.9542 - val_loss: 0.2487 - val_acc: 0.9288
# Epoch 3/15
# 1044897/1044897 [==============================] - 364s 348us/step - loss: 0.1150 - acc: 0.9549 - val_loss: 0.2491 - val_acc: 0.9323
# Epoch 4/15
# 1044897/1044897 [==============================] - 364s 348us/step - loss: 0.1134 - acc: 0.9554 - val_loss: 0.2578 - val_acc: 0.9322
# Epoch 5/15
# 1044897/1044897 [==============================] - 362s 347us/step - loss: 0.1118 - acc: 0.9559 - val_loss: 0.2552 - val_acc: 0.9288
# Epoch 6/15
# 1044897/1044897 [==============================] - 364s 348us/step - loss: 0.1110 - acc: 0.9562 - val_loss: 0.2709 - val_acc: 0.9336
# Epoch 7/15
# 1044897/1044897 [==============================] - 365s 349us/step - loss: 0.1101 - acc: 0.9565 - val_loss: 0.2602 - val_acc: 0.9277
# Epoch 8/15
# 1044897/1044897 [==============================] - 365s 349us/step - loss: 0.1088 - acc: 0.9570 - val_loss: 0.2631 - val_acc: 0.9286
# Epoch 9/15
# 1044897/1044897 [==============================] - 366s 351us/step - loss: 0.1078 - acc: 0.9574 - val_loss: 0.2588 - val_acc: 0.9232
# Epoch 10/15
# 1044897/1044897 [==============================] - 362s 347us/step - loss: 0.1073 - acc: 0.9575 - val_loss: 0.2600 - val_acc: 0.9290
# Epoch 11/15
# 1044897/1044897 [==============================] - 362s 346us/step - loss: 0.1062 - acc: 0.9580 - val_loss: 0.2647 - val_acc: 0.9267
# Epoch 12/15
# 1044897/1044897 [==============================] - 363s 348us/step - loss: 0.1054 - acc: 0.9583 - val_loss: 0.2669 - val_acc: 0.9260
# Epoch 13/15
# 1044897/1044897 [==============================] - 364s 348us/step - loss: 0.1051 - acc: 0.9583 - val_loss: 0.2624 - val_acc: 0.9255
# Epoch 14/15
# 1044897/1044897 [==============================] - 364s 348us/step - loss: 0.1041 - acc: 0.9587 - val_loss: 0.2688 - val_acc: 0.9276
# Epoch 15/15
# 1044897/1044897 [==============================] - 365s 350us/step - loss: 0.1032 - acc: 0.9589 - val_loss: 0.2783 - val_acc: 0.9291

# %%
predictions=model.predict(sequences_matrix_test)

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test,predictions)
# Out:
# 0.7182648653158381

# %%
#Obseravations:
#when epochs=10000 roc_auc_score is 0.7173321158355012 but the model is overfitting (val_acc<acc)
#when only 1 dense layer is used roc_auc_score 0.7292734137923427 
#when 3 dense layers are used roc_auc_score 0.7271602252073571
#as the loss is decreasing it implies the model is learning so i increased no of epochs to 15 but val_loss increased
